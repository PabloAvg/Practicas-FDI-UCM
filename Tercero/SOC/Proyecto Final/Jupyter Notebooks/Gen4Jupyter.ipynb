# %%
import networkx as nx
import itertools as it

# %%
# Importo Beautiful Soup
from bs4 import BeautifulSoup
# Importo requests para pillar el código html de donde quiera
import requests

# Cogemos la Pokédex
webDex = requests.get('https://pokemondb.net/pokedex/national')
dexSoup  = BeautifulSoup(webDex.content, 'html.parser')

# %%
pokedex = {}
G= nx.Graph()
types = [['itype', 'grass'], ['itype', 'poison'], ['itype', 'fire'], ['itype', 'flying'], ['itype', 'water'], 
         ['itype', 'bug'], ['itype', 'normal'], ['itype', 'electric'], ['itype', 'ground'], ['itype', 'fairy'], 
         ['itype', 'fighting'], ['itype', 'psychic'], ['itype', 'rock'], ['itype', 'steel'], 
         ['itype', 'ice'], ['itype', 'ghost'], ['itype', 'dark'], ['itype', 'dragon']]

for name in dexSoup.find_all('a'):
    if name.get('class') == ['ent-name']:
        pok = name.get_text()
        pokedex[pok] = {'type1' : 'None', 'type2' : 'None'}
    if name.get('class') in types:
        if pokedex[pok]['type1'] == 'None':
            pokedex[pok]['type1'] = name.get_text()
        else:
            pokedex[pok]['type2'] = name.get_text()

# %%
print(pokedex)
# Out:
# {'Bulbasaur': {'type1': 'Grass', 'type2': 'Poison'}, 'Ivysaur': {'type1': 'Grass', 'type2': 'Poison'}, 'Venusaur': {'type1': 'Grass', 'type2': 'Poison'}, 'Charmander': {'type1': 'Fire', 'type2': 'None'}, 'Charmeleon': {'type1': 'Fire', 'type2': 'None'}, 'Charizard': {'type1': 'Fire', 'type2': 'Flying'}, 'Squirtle': {'type1': 'Water', 'type2': 'None'}, 'Wartortle': {'type1': 'Water', 'type2': 'None'}, 'Blastoise': {'type1': 'Water', 'type2': 'None'}, 'Caterpie': {'type1': 'Bug', 'type2': 'None'}, 'Metapod': {'type1': 'Bug', 'type2': 'None'}, 'Butterfree': {'type1': 'Bug', 'type2': 'Flying'}, 'Weedle': {'type1': 'Bug', 'type2': 'Poison'}, 'Kakuna': {'type1': 'Bug', 'type2': 'Poison'}, 'Beedrill': {'type1': 'Bug', 'type2': 'Poison'}, 'Pidgey': {'type1': 'Normal', 'type2': 'Flying'}, 'Pidgeotto': {'type1': 'Normal', 'type2': 'Flying'}, 'Pidgeot': {'type1': 'Normal', 'type2': 'Flying'}, 'Rattata': {'type1': 'Normal', 'type2': 'None'}, 'Raticate': {'type1': 'Normal', 'type2': 'None'}, 'Spe
# ...

# %%
apariciones={}
teams=[]

team1 = []
team1.append('Hippowdon')
team1.append('Infernape')
team1.append('Zapdos')
teams.append(team1)


team2 = []
team2.append('Tyranitar')
team2.append('Slowbro')
team2.append('Rotom')
teams.append(team2)


team3 =[]
team3.append('Umbreon')
team3.append('Tangrowth')
team3.append('Starmie')
teams.append(team3)



team4 = []
team4.append('Entei')
team4.append('Shaymin')
team4.append('Tyranitar')
teams.append(team4)


team5 = []
team5.append('Gastly')
team5.append('Munchlax')
team5.append('Duskull')
team5.append('Chinchou')
team5.append('Houndour')
team5.append('Gligar') 
teams.append(team5)


team6 = []
team6.append('Gligar')
team6.append('Duskull')
team6.append('Chinchou')
team6.append('Munchlax')
team6.append('Houndour')
team6.append('Drifloon') 
teams.append(team6)



team7 = []
team7.append('Gastly')
team7.append('Gligar')
team7.append('Munchlax')
team7.append('Chinchou')
team7.append('Mantyke')
team7.append('Houndour')
teams.append(team7)


team8 = []
team8.append('Machop')
team8.append('Munchlax')
team8.append('Duskull')
team8.append('Chinchou')
team8.append('Houndour')
team8.append('Gligar')
teams.append(team8)

team9 = []
team9.append('Gligar')
team9.append('Elekid')
team9.append('Munchlax')
team9.append('Duskull')
team9.append('Chinchou')
team9.append('Snover')
teams.append(team9)

team10 = []
team10.append('Qwilfish')
team10.append('Starmie')
team10.append('Empoleon')
team10.append('Sharpedo')
team10.append('Suicune')
team10.append('Swampert')
teams.append(team10)

team11 = []
team11.append('Bronzong')
team11.append('Heatran')
team11.append('Skarmory')
team11.append('Empoleon')
team11.append('Scizor')
team11.append('Jirachi')
teams.append(team11)

team12 = []
team12.append('Azelf')
team12.append('Celebi')
team12.append('Latias')
team12.append('Jirachi')
team12.append('Metagross')
team12.append('Medicham')
teams.append(team12)


team13 = []
team13.append('Aerodactyl')
team13.append('Zapdos')
team13.append('Dragonite')
team13.append('Gyarados')
team13.append('Skarmory')
team13.append('Moltres')
teams.append(team13)

team14 = []
team14.append('Heatran')
team14.append('Houndoom')
team14.append('Infernape')
team14.append('Charizard')
team14.append('Torkoal')
team14.append('Blaziken')
teams.append(team14)

team15 = []
team15.append('Rotom')
team15.append('Electrode')
team15.append('Charizard')
team15.append('Magnezone')
team15.append('Luxray')
team15.append('Moltres')
teams.append(team15)


team16 = []
team16.append('Venusaur')
team16.append('Roserade')
team16.append('Celebi')
team16.append('Breloom')
team16.append('Torterra')
team16.append('Exeggutor')
teams.append(team16)
             
team17 = []
team17.append('Jynx')
team17.append('Haunter')
team17.append('Manectric')
team17.append('Regirock')
team17.append('Tauros')
team17.append('Slowking')
teams.append(team17)

team18 = []
team18.append('Jynx')
team18.append('Regirock')
team18.append('Haunter')
team18.append('Manectric')
team18.append('Hitmonchan')
team18.append('Skuntank')
teams.append(team18)

team19 = []
team19.append('Piloswine')
team19.append('Magneton')
team19.append('Politoed')
team19.append('Haunter')
team19.append('Magmortar')
team19.append('Jynx')
teams.append(team19)

team20 = []
team20.append('Regirock')
team20.append('Skuntank')
team20.append('Hitmonchan')
team20.append('Whiscash')
team20.append('Charizard')
team20.append('Magmortar')
teams.append(team20)

team21 = []
team21.append('Floatzel')
team21.append('Gardevoir')
team21.append('Sandslash')
team21.append('Skuntank')
team21.append('Charizard')
team21.append('Vileplume')
teams.append(team21)


team22 = []
team22.append('Medicham')
team22.append('Gligar')
team22.append('Hypno')
team22.append('Magneton')
team22.append('Tauros')
team22.append('Hitmonchan')
teams.append(team22)

team23 = []
team23.append('Machoke')
team23.append('Sandslash')
team23.append('Charizard')
team23.append('Manectric')
team23.append('Whiscash')
team23.append('Jumpluff')
teams.append(team23)

team24 = []
team24.append('Solrock')
team24.append('Marowak')
team24.append('Camerupt')
team24.append('Medicham')
team24.append('Tauros')
team24.append('Gardevoir')
teams.append(team24)

team25 = []
team25.append('Charizard')
team25.append('Jumpluff')
team25.append('Sandslash')
team25.append('Grumpig')
team25.append('Poliwrath')
team25.append('Tauros')
teams.append(team25)


team26 = []
team26.append('Persian')
team26.append('Hypno')
team26.append('Regirock')
team26.append('Victreebel')
team26.append('Shiftry')
team26.append('Typhlosion')
teams.append(team26)


team27 = []
team27.append('Azelf')
team27.append('Tyranitar')
team27.append('Breloom')
team27.append('Jirachi')
team27.append('Gyarados')
team27.append('Rotom')
teams.append(team27) 

 
team28 = []
team28.append('Zapdos')
team28.append('Tyranitar')
team28.append('Breloom')
team28.append('Starmie')
team28.append('Heatran')
team28.append('Metagross')
teams.append(team28) 


team29 = []
team29.append('Zapdos')
team29.append('Heatran')
team29.append('Latias')
team29.append('Suicune')
team29.append('Metagross')
team29.append('Flygon')
teams.append(team29)

team30 = []
team30.append('Empoleon')
team30.append('Jirachi')
team30.append('Starmie')
team30.append('Bronzong')
team30.append('Tyranitar')
team30.append('Dragonite')
teams.append(team30)

team31 = []
team31.append('Roserade')
team31.append('Swampert')
team31.append('Latias')
team31.append('Tyranitar')
team31.append('Heatran')
team31.append('Rotom')
teams.append(team31)


team32 = []
team32.append('Jirachi')
team32.append('Raikou')
team32.append('Charizard')
team32.append('Suicune')
team32.append('Tyranitar')
team32.append('Latias')
teams.append(team32)

team33 = []
team33.append('Metagross')
team33.append('Scizor')
team33.append('Tyranitar')
team33.append('Infernape')
team33.append('Rotom')
team33.append('Latias')
teams.append(team33)


team34 = []
team34.append('Skarmory')
team34.append('Flygon')
team34.append('Tyranitar')
team34.append('Gyarados')
team34.append('Lucario')
team34.append('Rotom')
teams.append(team34)

team35 = []
team35.append('Hippowdon')
team35.append('Skarmory')
team35.append('Clefable')
team35.append('Starmie')
team35.append('Gliscor')
team35.append('Jirachi')
teams.append(team35)

team36 = []
team36.append('Tyranitar')
team36.append('Nidoqueen')
team36.append('Skarmory')
team36.append('Heatran')
team36.append('Milotic')
team36.append('Gliscor')
teams.append(team36)


team37 = []
team37.append('Purugly')
team37.append('Bellossom')
team37.append('Politoed')
team37.append('Electabuzz')
team37.append('Armaldo')
team37.append('Whiscash')
teams.append(team17)

team38 = []
team38.append('Relicanth')
team38.append('Rhydon')
team38.append('Bellossom')
team38.append('Pelipper')
team38.append('Zangoose')
team38.append('Xatu')
teams.append(team38)

team39 = []
team39.append('Kadabra')
team39.append('Purugly')
team39.append('Golduck')
team39.append('Victreebel')
team39.append('Gabite')
team39.append('Metang')
teams.append(team39)

team40 = []
team40.append('Glalie')
team40.append('Murkrow')
team40.append('Purugly')
team40.append('Bellossom')
team40.append('Relicanth')
team40.append('Xatu')
teams.append(team40)

team41 = []
team41.append('Rhydon')
team41.append('Misdreavus')
team41.append('Bellossom')
team41.append('Metang')
team41.append('Golduck')
team41.append('Purugly')
teams.append(team41)



team42 = []
team42.append('Purugly')
team42.append('Mantine')
team42.append('Victreebel')
team42.append('Rhydon')
team42.append('Ampharos')
team42.append('Xatu')
teams.append(team42)

team43 = []
team43.append('Glalie')
team43.append('Mantine')
team43.append('Camerupt')
team43.append('Purugly')
team43.append('Misdreavus')
team43.append('Pinsir')
teams.append(team43)

team44 = []
team44.append('Purugly')
team44.append('Rhydon')
team44.append('Politoed')
team44.append('Victreebel')
team44.append('Monferno')
team44.append('Golbat')
teams.append(team44)

team45 = []
team45.append('Rayquaza')
team45.append('Dialga')
team45.append('Scizor')
team45.append('Palkia')
team45.append('Groudon')
team45.append('Mewtwo')
teams.append(team45)


team46 = []
team46.append('Ho-oh')
team46.append('Groudon')
team46.append('Forretress')
team46.append('Giratina')
team46.append('Palkia')
team46.append('Darkrai')
teams.append(team46)

team47 = []
team47.append('Cloyster')
team47.append('Dialga')
team47.append('Giratina')
team47.append('Scizor')
team47.append('Palkia')
team47.append('Kyogre')
teams.append(team47)

team48 = []
team48.append('Deoxys')
team48.append('Latios')
team48.append('Groudon')
team48.append('Heatran')
team48.append('Giratina')
team48.append('Garchomp')
teams.append(team48)

team49 = []
team49.append('Tyranitar')
team49.append('Groudon')
team49.append('Skarmory')
team49.append('Mewtwo')
team49.append('Latios')
team49.append('Dialga')
teams.append(team49)

team50 = []
team50.append('Cloyster')
team50.append('Groudon')
team50.append('Palkia')
team50.append('Lugia')
team50.append('Heatran')
team50.append('Giratina')
teams.append(team50)

team51 = []
team51.append('Froslass')
team51.append('Groudon')
team51.append('Kyogre')
team51.append('Kabutops')
team51.append('Dialga')
team51.append('Giratina')
teams.append(team51)

team52 = []
team52.append('Tentacruel')
team52.append('Dialga')
team52.append('Giratina')
team52.append('Shaymin')
team52.append('Jirachi')
team52.append('Kyogre')
teams.append(team52)

team53 = []
team53.append('Tyranitar')
team53.append('Kyogre')
team53.append('Darkrai')
team53.append('Latios')
team53.append('Skarmory')
team53.append('Dialga')
teams.append(team53)

team54 = []
team54.append('Lairon')
team54.append('Gastly')
team54.append('Quagsire')
team54.append('Tangela')
team54.append('Flareon')
team54.append('Swalot')
teams.append(team54)
 
team55 = []
team55.append('Solrock')
team55.append('Banette')
team55.append('Seviper')
team55.append('Quagsire')
team55.append('Raticate')
team55.append('Pikachu')
teams.append(team55)

team56 = []
team56.append('Onix')
team56.append('Tangela')
team56.append('Magmar')
team56.append('Weepinbell')
team56.append('Persian')
team56.append('Abra')
teams.append(team56)

team57 = []
team57.append('Lairon')
team57.append('Gastly')
team57.append('Quagsire')
team57.append('Tangela')
team57.append('Flareon')
team57.append('Swalot')
teams.append(team57)
    
team58 = []
team58.append('Solrock')
team58.append('Banette')
team58.append('Seviper')
team58.append('Quagsire')
team58.append('Raticate')
team58.append('Pikachu')
teams.append(team58)


team59 = []
team59.append('Onix')
team59.append('Tangela')
team59.append('Magmar')
team59.append('Weepinbell')
team59.append('Persian')
team59.append('Abra')
teams.append(team59)

team60 = []
team60.append('Uxie')
team60.append('Feraligatr')
team60.append('Moltres')
team60.append('Donphan')
team60.append('Venusaur')
team60.append('Toxicroak')
teams.append(team60)

team61 = []
team61.append('Uxie')
team61.append('Qwilfish')
team61.append('Mismagius')
team61.append('Ursaring')
team61.append('Hitmonlee')
team61.append('Rotom')
teams.append(team61)

team62 = []
team62.append('Steelix')
team62.append('Altaria')
team62.append('Leafeon')
team62.append('Dugtrio')
team62.append('Kabutops')
team62.append('Toxicroak')
teams.append(team62)

team63 = []
team63.append('Drapion')
team63.append('Uxie')
team63.append('Blaziken')
team63.append('Miltank')
team63.append('Mismagius')
team63.append('Kabutops')
teams.append(team63)

team64 = []
team64.append('Clefable')
team64.append('Venusaur')
team64.append('Blaziken')
team64.append('Absol')
team64.append('Mismagius')
team64.append('Alakazam')
teams.append(team64)

team65 = []
team65.append('Mesprit')
team65.append('Leafeon')
team65.append('Swellow')
team65.append('Dugtrio')
team65.append('Kabutops')
team65.append('Arcanine')
teams.append(team65)

team66 = []
team66.append('Uxie')
team66.append('Ludicolo')
team66.append('Kabutops')
team66.append('Dugtrio')
team66.append('Toxicroak')
team66.append('Registeel')
teams.append(team66)  

team67 = []
team67.append('Moltres')
team67.append('Venusaur')
team67.append('Aggron')
team67.append('Donphan')
team67.append('Milotic')
team67.append('Clefable')
teams.append(team67) 

team68 = []
team68.append('Mismagius')
team68.append('Arcanine')
team68.append('Kabutops')
team68.append('Sceptile')
team68.append('Donphan')
team68.append('Registeel')
teams.append(team68) 

team69 = []
team69.append('Mismagius')
team69.append('Registeel')
team69.append('Venusaur')
team69.append('Milotic')
team69.append('Houndoom')
team69.append('Primeape')
teams.append(team69) 

team70 = []
team70.append('Jynx')
team70.append('Clefable')
team70.append('Feraligatr')
team70.append('Rhyperior')
team70.append('Milotic')
team70.append('Toxicroak')
teams.append(team70)

# %%
print(teams)
# Out:
# [['Hippowdon', 'Infernape', 'Zapdos'], ['Tyranitar', 'Slowbro', 'Rotom'], ['Umbreon', 'Tangrowth', 'Starmie'], ['Entei', 'Shaymin', 'Tyranitar'], ['Gastly', 'Munchlax', 'Duskull', 'Chinchou', 'Houndour', 'Gligar'], ['Gligar', 'Duskull', 'Chinchou', 'Munchlax', 'Houndour', 'Drifloon'], ['Gastly', 'Gligar', 'Munchlax', 'Chinchou', 'Mantyke', 'Houndour'], ['Machop', 'Munchlax', 'Duskull', 'Chinchou', 'Houndour', 'Gligar'], ['Gligar', 'Elekid', 'Munchlax', 'Duskull', 'Chinchou', 'Snover'], ['Qwilfish', 'Starmie', 'Empoleon', 'Sharpedo', 'Suicune', 'Swampert'], ['Bronzong', 'Heatran', 'Skarmory', 'Empoleon', 'Scizor', 'Jirachi'], ['Azelf', 'Celebi', 'Latias', 'Jirachi', 'Metagross', 'Medicham'], ['Aerodactyl', 'Zapdos', 'Dragonite', 'Gyarados', 'Skarmory', 'Moltres'], ['Heatran', 'Houndoom', 'Infernape', 'Charizard', 'Torkoal', 'Blaziken'], ['Rotom', 'Electrode', 'Charizard', 'Magnezone', 'Luxray', 'Moltres'], ['Venusaur', 'Roserade', 'Celebi', 'Breloom', 'Torterra', 'Exeggutor'], ['Jynx'
# ...

# %%
print(len(teams))
# Out:
# 70

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Hippowdon', 'Infernape', 1), ('Hippowdon', 'Zapdos', 1), ('Hippowdon', 'Skarmory', 1), ('Hippowdon', 'Clefable', 1), ('Hippowdon', 'Starmie', 1), ('Hippowdon', 'Gliscor', 1), ('Hippowdon', 'Jirachi', 1), ('Infernape', 'Zapdos', 1), ('Infernape', 'Heatran', 1), ('Infernape', 'Houndoom', 1), ('Infernape', 'Charizard', 1), ('Infernape', 'Torkoal', 1), ('Infernape', 'Blaziken', 1), ('Infernape', 'Metagross', 1), ('Infernape', 'Scizor', 1), ('Infernape', 'Tyranitar', 1), ('Infernape', 'Rotom', 1), ('Infernape', 'Latias', 1), ('Zapdos', 'Aerodactyl', 1), ('Zapdos', 'Dragonite', 1), ('Zapdos', 'Gyarados', 1), ('Zapdos', 'Skarmory', 1), ('Zapdos', 'Moltres', 1), ('Zapdos', 'Tyranitar', 1), ('Zapdos', 'Breloom', 1), ('Zapdos', 'Starmie', 1), ('Zapdos', 'Heatran', 2), ('Zapdos', 'Metagross', 2), ('Zapdos', 'Latias', 1), ('Zapdos', 'Suicune', 1), ('Zapdos', 'Flygon', 1), ('Tyranitar', 'Slowbro', 1), ('Tyranitar', 'Rotom', 5), ('Tyranitar', 'Entei', 1), ('Tyranitar', 'Shaymin', 1
# ...

# %%
nx.draw(G)

# %%
print(apariciones)
# Out:
# {'Hippowdon': 2, 'Infernape': 3, 'Zapdos': 4, 'Tyranitar': 12, 'Slowbro': 1, 'Rotom': 7, 'Umbreon': 1, 'Tangrowth': 1, 'Starmie': 5, 'Entei': 1, 'Shaymin': 2, 'Gastly': 4, 'Munchlax': 5, 'Duskull': 4, 'Chinchou': 5, 'Houndour': 4, 'Gligar': 6, 'Drifloon': 1, 'Mantyke': 1, 'Machop': 1, 'Elekid': 1, 'Snover': 1, 'Qwilfish': 2, 'Empoleon': 3, 'Sharpedo': 1, 'Suicune': 3, 'Swampert': 2, 'Bronzong': 2, 'Heatran': 8, 'Skarmory': 7, 'Scizor': 4, 'Jirachi': 7, 'Azelf': 2, 'Celebi': 2, 'Latias': 5, 'Metagross': 4, 'Medicham': 3, 'Aerodactyl': 1, 'Dragonite': 2, 'Gyarados': 3, 'Moltres': 4, 'Houndoom': 2, 'Charizard': 7, 'Torkoal': 1, 'Blaziken': 3, 'Electrode': 1, 'Magnezone': 1, 'Luxray': 1, 'Venusaur': 5, 'Roserade': 2, 'Breloom': 3, 'Torterra': 1, 'Exeggutor': 1, 'Jynx': 5, 'Haunter': 4, 'Manectric': 4, 'Regirock': 5, 'Tauros': 5, 'Slowking': 2, 'Hitmonchan': 3, 'Skuntank': 3, 'Piloswine': 1, 'Magneton': 2, 'Politoed': 2, 'Magmortar': 2, 'Whiscash': 2, 'Floatzel': 1, 'Gardevoir': 2, 'Sands
# ...

# %%
for pok in G.nodes :
    G.nodes[pok]['teams'] = apariciones[pok]

# %%
G.nodes.data()
# Out:
# NodeDataView({'Hippowdon': {'type1': 'Ground', 'type2': 'None', 'teams': 2}, 'Infernape': {'type1': 'Fire', 'type2': 'Fighting', 'teams': 3}, 'Zapdos': {'type1': 'Electric', 'type2': 'Flying', 'teams': 4}, 'Tyranitar': {'type1': 'Rock', 'type2': 'Dark', 'teams': 12}, 'Slowbro': {'type1': 'Water', 'type2': 'Psychic', 'teams': 1}, 'Rotom': {'type1': 'Electric', 'type2': 'Ghost', 'teams': 7}, 'Umbreon': {'type1': 'Dark', 'type2': 'None', 'teams': 1}, 'Tangrowth': {'type1': 'Grass', 'type2': 'None', 'teams': 1}, 'Starmie': {'type1': 'Water', 'type2': 'Psychic', 'teams': 5}, 'Entei': {'type1': 'Fire', 'type2': 'None', 'teams': 1}, 'Shaymin': {'type1': 'Grass', 'type2': 'None', 'teams': 2}, 'Gastly': {'type1': 'Ghost', 'type2': 'Poison', 'teams': 4}, 'Munchlax': {'type1': 'Normal', 'type2': 'None', 'teams': 5}, 'Duskull': {'type1': 'Ghost', 'type2': 'None', 'teams': 4}, 'Chinchou': {'type1': 'Water', 'type2': 'Electric', 'teams': 5}, 'Houndour': {'type1': 'Dark', 'type2': 'Fire', 'teams': 
# ...

# %%
for pok in G.nodes :
    G.nodes[pok]['teams'] = apariciones[pok]

# %%
nx.write_gexf(G, "Gen4Graph.gexf", version="1.2draft")
