# %%
import networkx as nx
import itertools as it

# %%
# Importo Beautiful Soup
from bs4 import BeautifulSoup
# Importo requests para pillar el código html de donde quiera
import requests

# Cogemos la Pokédex
webDex = requests.get('https://pokemondb.net/pokedex/national')
dexSoup  = BeautifulSoup(webDex.content, 'html.parser')

# %%
pokedex = {}
G= nx.Graph()
types = [['itype', 'grass'], ['itype', 'poison'], ['itype', 'fire'], ['itype', 'flying'], ['itype', 'water'], 
         ['itype', 'bug'], ['itype', 'normal'], ['itype', 'electric'], ['itype', 'ground'], ['itype', 'fairy'], 
         ['itype', 'fighting'], ['itype', 'psychic'], ['itype', 'rock'], ['itype', 'steel'], 
         ['itype', 'ice'], ['itype', 'ghost'], ['itype', 'dark'], ['itype', 'dragon']]

for name in dexSoup.find_all('a'):
    if name.get('class') == ['ent-name']:
        pok = name.get_text()
        pokedex[pok] = {'type1' : 'None', 'type2' : 'None'}
    if name.get('class') in types:
        if pokedex[pok]['type1'] == 'None':
            pokedex[pok]['type1'] = name.get_text()
        else:
            pokedex[pok]['type2'] = name.get_text()

# %%
print(pokedex)
# Out:
# {'Bulbasaur': {'type1': 'Grass', 'type2': 'Poison'}, 'Ivysaur': {'type1': 'Grass', 'type2': 'Poison'}, 'Venusaur': {'type1': 'Grass', 'type2': 'Poison'}, 'Charmander': {'type1': 'Fire', 'type2': 'None'}, 'Charmeleon': {'type1': 'Fire', 'type2': 'None'}, 'Charizard': {'type1': 'Fire', 'type2': 'Flying'}, 'Squirtle': {'type1': 'Water', 'type2': 'None'}, 'Wartortle': {'type1': 'Water', 'type2': 'None'}, 'Blastoise': {'type1': 'Water', 'type2': 'None'}, 'Caterpie': {'type1': 'Bug', 'type2': 'None'}, 'Metapod': {'type1': 'Bug', 'type2': 'None'}, 'Butterfree': {'type1': 'Bug', 'type2': 'Flying'}, 'Weedle': {'type1': 'Bug', 'type2': 'Poison'}, 'Kakuna': {'type1': 'Bug', 'type2': 'Poison'}, 'Beedrill': {'type1': 'Bug', 'type2': 'Poison'}, 'Pidgey': {'type1': 'Normal', 'type2': 'Flying'}, 'Pidgeotto': {'type1': 'Normal', 'type2': 'Flying'}, 'Pidgeot': {'type1': 'Normal', 'type2': 'Flying'}, 'Rattata': {'type1': 'Normal', 'type2': 'None'}, 'Raticate': {'type1': 'Normal', 'type2': 'None'}, 'Spe
# ...

# %%
teams =[]

apariciones = {}

team1 = []
team1.append('Heracross')
team1.append('Raikou')
team1.append('Starmie')
teams.append(team1)


team2 = []
team2.append('Porygon2')
team2.append('Jumpluff')
team2.append('Raikou')
teams.append(team2)


team3 =[]
team3.append('Blissey')
team3.append('Marowak')
team3.append('Raikou')
teams.append(team3)


team4 = []
team4.append('Diglett')
team4.append('Magby')
team4.append('Chinchou')
team4.append('Exeggcute')
team4.append('Porygon')
team4.append('Houndour')
teams.append(team4)


team5 = []
team5.append('Gastly')
team5.append('Houndour')
team5.append('Staryu')
team5.append('Machop')
team5.append('Elekid')
team5.append('Porygon') 
teams.append(team5)


team6 = []
team6.append('Staryu')
team6.append('Magby')
team6.append('Cubone')
team6.append('Abra')
team6.append('Chansey')
team6.append('Machop') 
teams.append(team6)


team7 = []
team7.append('Exeggcute')
team7.append('Houndour')
team7.append('Chansey')
team7.append('Staryu')
team7.append('Elekid')
team7.append('Machop')
teams.append(team7)


team8 = []
team8.append('Elekid')
team8.append('Doduo')
team8.append('Machop')
team8.append('Drowzee')
team8.append('Poliwag')
team8.append('Sandshrew')
teams.append(team8)

team9 = []
team9.append('Dugtrio')
team9.append('Xatu')
team9.append('Pineco')
team9.append('Fearow')
team9.append('Magnemite')
team9.append('Octillery')
teams.append(team9)

team10 = []
team10.append('Omanyte')
team10.append('Ninetales')
team10.append('Gloom')
team10.append('Hitmonlee')
team10.append('Pineco')
team10.append('Wigglytuff')
teams.append(team10)

team11 = []
team11.append('Dragonair')
team11.append('Xatu')
team11.append('Dewgong')
team11.append('Flareon')
team11.append('Gloom')
team11.append('Magnemite')
teams.append(team11)


team12 = []
team12.append('Rapidash')
team12.append('Pineco')
team12.append('Magmar')
team12.append('Sudowoodo')
team12.append('Exeggcute')
team12.append('Xatu')
teams.append(team12)

team13 = []
team13.append('Sudowoodo')
team13.append('Xatu')
team13.append('Ninetales')
team13.append('Gloom')
team13.append('Slowpoke')
team13.append('Pineco')
teams.append(team13)

team14 = []
team14.append('Rapidash')
team14.append('Weezing')
team14.append('Primeape')
team14.append('Chinchou')
team14.append('Sudowoodo')
team14.append('Xatu')
teams.append(team14)

team15 = []
team15.append('Stantler')
team15.append('Xatu')
team15.append('Pineco')
team15.append('Weezing')
team15.append('Ninetales')
team15.append('Hitmonlee')
teams.append(team15)

team16 = []
team16.append('Stantler')
team16.append('Primeape')
team16.append('Dugtrio')
team16.append('Xatu')
team16.append('Pineco')
team16.append('Rapidash')
teams.append(team16)

team17 = []
team17.append('Zapdos')
team17.append('Snorlax')
team17.append('Exeggutor')
team17.append('Steelix')
team17.append('Cloyster')
team17.append('Machamp')
teams.append(team17)

team18 = []
team18.append('Zapdos')
team18.append('Snorlax')
team18.append('Exeggutor')
team18.append('Steelix')
team18.append('Cloyster')
team18.append('Vaporeon')
teams.append(team18)

team19 = []
team19.append('Nidoking')
team19.append('Cloyster')
team19.append('Zapdos')
team19.append('Machamp')
team19.append('Snorlax')
team19.append('Tyranitar')
teams.append(team19)

team20 = []
team20.append('Raikou')
team20.append('Miltank')
team20.append('Starmie')
team20.append('Snorlax')
team20.append('Skarmory')
team20.append('Marowak')
teams.append(team20)

team21 = []
team21.append('Raikou')
team21.append('Snorlax')
team21.append('Forretress')
team21.append('Suicune')
team21.append('Skarmory')
team21.append('Misdreavus')
teams.append(team21)

team22 = []
team22.append('Exeggutor')
team22.append('Zapdos')
team22.append('Snorlax')
team22.append('Cloyster')
team22.append('Tyranitar')
team22.append('Marowak')
teams.append(team22)

team23 = []
team23.append('Zapdos')
team23.append('Snorlax')
team23.append('Nidoking')
team23.append('Tyranitar')
team23.append('Exeggutor')
team23.append('Cloyster')
teams.append(team23)

team24 = []
team24.append('Raikou')
team24.append('Zapdos')
team24.append('Snorlax')
team24.append('Cloyster')
team24.append('Skarmory')
team24.append('Umbreon')
teams.append(team24)

team25 = []
team25.append('Raikou')
team25.append('Cloyster')
team25.append('Snorlax')
team25.append('Steelix')
team25.append('Gengar')
team25.append('Heracross')
teams.append(team25)

team26 = []
team26.append('Snorlax')
team26.append('Zapdos')
team26.append('Exeggutor')
team26.append('Steelix')
team26.append('Cloyster')
team26.append('Gengar')
teams.append(team26)

team27 = []
team27.append('Snorlax')
team27.append('Raikou')
team27.append('Forretress')
team27.append('Starmie')
team27.append('Skarmory')
team27.append('Umbreon')
teams.append(team27)

team28 = []
team28.append('Snorlax')
team28.append('Raikou')
team28.append('Suicune')
team28.append('Cloyster')
team28.append('Golem')
team28.append('Skarmory')
teams.append(team28)

team29 = []
team29.append('Snorlax')
team29.append('Zapdos')
team29.append('Nidoking')
team29.append('Gengar')
team29.append('Steelix')
team29.append('Cloyster')
teams.append(team29)

team30 = []
team30.append('Mewtwo')
team30.append('Mew')
team30.append('Lugia')
team30.append('Snorlax')
team30.append('Zapdos')
team30.append('Steelix')
teams.append(team30)

team30 = []
team30.append('Mewtwo')
team30.append('Jolteon')
team30.append('Mew')
team30.append('Snorlax')
team30.append('Tyranitar')
team30.append('Cloyster')
teams.append(team30)

team31 = []
team31.append('Forretress')
team31.append('Snorlax')
team31.append('Lugia')
team31.append('Celebi')
team31.append('Steelix')
team31.append('Mew')
teams.append(team31)

team32 = []
team32.append('Snorlax')
team32.append('Zapdos')
team32.append('Forretress')
team32.append('Mew')
team32.append('Mewtwo')
team32.append('Golem')
teams.append(team32)

team33 = []
team33.append('Snorlax')
team33.append('Forretress')
team33.append('Tyranitar')
team33.append('Mewtwo')
team33.append('Zapdos')
team33.append('Mew')
teams.append(team33)

team34 = []
team34.append('Qwilfish')
team34.append('Nidoqueen')
team34.append('Ampharos')
team34.append('Haunter')
team34.append('Dodrio')
team34.append('Slowking')
teams.append(team34)

team35 = []
team35.append('Slowking')
team35.append('Bellossom')
team35.append('Crobat')
team35.append('Nidoqueen')
team35.append('Qwilfish')
team35.append('Slowbro')
teams.append(team35)

team36 = []
team36.append('Mr. Mime')
team36.append('Ampharos')
team36.append('Jumpluff')
team36.append('Qwilfish')
team36.append('Sandslash')
team36.append('Slowbro')
teams.append(team36)


team37 = []
team37.append('Mr. Mime')
team37.append('Bellossom')
team37.append('Kadabra')
team37.append('Nidoqueen')
team37.append('Omastar')
team37.append('Qwilfish')
teams.append(team37)


team38 = []
team38.append('Electrode')
team38.append('Mr. Mime')
team38.append('Quagsire')
team38.append('Poliwrath')
team38.append('Girafarig')
team38.append('Haunter')
teams.append(team38)

team39 = []
team39.append('Weezing')
team39.append('Graveler')
team39.append('Haunter')
team39.append('Electrode')
team39.append('Scyther')
team39.append('Mr. Mime')
teams.append(team39)


team40 = []
team40.append('Slowbro')
team40.append('Qwilfish')
team40.append('Gligar')
team40.append('Chansey')
team40.append('Nidoqueen')
team40.append('Magneton')
teams.append(team40)

team41 = []
team41.append('Hypno')
team41.append('Scyther')
team41.append('Kabutops')
team41.append('Nidoqueen')
team41.append('Gyarados')
team41.append('Bellossom')
teams.append(team41)



team42 = []
team42.append('Hitmonchan')
team42.append('Drowzee')
team42.append('Tangela')
team42.append('Magcargo')
team42.append('Murkrow')
team42.append('Poliwhirl')
teams.append(team42)


team43 = []
team43.append('Venomoth')
team43.append('Seaking')
team43.append('Beedrill')
team43.append('Machoke')
team43.append('Drowzee')
team43.append('Furret')
teams.append(team43)

team44 = []
team44.append('Furret')
team44.append('Omanyte')
team44.append('Drowzee')
team44.append('Flaaffy')
team44.append('Tangela')
team44.append('Venomoth')
teams.append(team44)

team45 = []
team45.append('Murkrow')
team45.append('Abra')
team45.append('Eevee')
team45.append('Elekid')
team45.append('Drowzee')
team45.append('Seadra')
teams.append(team45)

team46 = []
team46.append('Seadra')
team46.append('Cubone')
team46.append('Drowzee')
team46.append('Venomoth')
team46.append('Elekid')
team46.append('Poliwhirl')
teams.append(team46)

team47 = []
team47.append('Furret')
team47.append('Murkrow')
team47.append('Seadra')
team47.append('Abra')
team47.append('Poliwhirl')
team47.append('Hitmonchan')
teams.append(team47)

# %%
print(teams)
# Out:
# [['Heracross', 'Raikou', 'Starmie'], ['Porygon2', 'Jumpluff', 'Raikou'], ['Blissey', 'Marowak', 'Raikou'], ['Diglett', 'Magby', 'Chinchou', 'Exeggcute', 'Porygon', 'Houndour'], ['Gastly', 'Houndour', 'Staryu', 'Machop', 'Elekid', 'Porygon'], ['Staryu', 'Magby', 'Cubone', 'Abra', 'Chansey', 'Machop'], ['Exeggcute', 'Houndour', 'Chansey', 'Staryu', 'Elekid', 'Machop'], ['Elekid', 'Doduo', 'Machop', 'Drowzee', 'Poliwag', 'Sandshrew'], ['Dugtrio', 'Xatu', 'Pineco', 'Fearow', 'Magnemite', 'Octillery'], ['Omanyte', 'Ninetales', 'Gloom', 'Hitmonlee', 'Pineco', 'Wigglytuff'], ['Dragonair', 'Xatu', 'Dewgong', 'Flareon', 'Gloom', 'Magnemite'], ['Rapidash', 'Pineco', 'Magmar', 'Sudowoodo', 'Exeggcute', 'Xatu'], ['Sudowoodo', 'Xatu', 'Ninetales', 'Gloom', 'Slowpoke', 'Pineco'], ['Rapidash', 'Weezing', 'Primeape', 'Chinchou', 'Sudowoodo', 'Xatu'], ['Stantler', 'Xatu', 'Pineco', 'Weezing', 'Ninetales', 'Hitmonlee'], ['Stantler', 'Primeape', 'Dugtrio', 'Xatu', 'Pineco', 'Rapidash'], ['Zapdos', 'Sno
# ...

# %%
print(len(teams))
# Out:
# 48

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Heracross', 'Raikou', 2), ('Heracross', 'Starmie', 1), ('Heracross', 'Cloyster', 1), ('Heracross', 'Snorlax', 1), ('Heracross', 'Steelix', 1), ('Heracross', 'Gengar', 1), ('Raikou', 'Starmie', 3), ('Raikou', 'Porygon2', 1), ('Raikou', 'Jumpluff', 1), ('Raikou', 'Blissey', 1), ('Raikou', 'Marowak', 2), ('Raikou', 'Miltank', 1), ('Raikou', 'Snorlax', 6), ('Raikou', 'Skarmory', 5), ('Raikou', 'Forretress', 2), ('Raikou', 'Suicune', 2), ('Raikou', 'Misdreavus', 1), ('Raikou', 'Zapdos', 1), ('Raikou', 'Cloyster', 3), ('Raikou', 'Umbreon', 2), ('Raikou', 'Steelix', 1), ('Raikou', 'Gengar', 1), ('Raikou', 'Golem', 1), ('Starmie', 'Miltank', 1), ('Starmie', 'Snorlax', 2), ('Starmie', 'Skarmory', 2), ('Starmie', 'Marowak', 1), ('Starmie', 'Forretress', 1), ('Starmie', 'Umbreon', 1), ('Porygon2', 'Jumpluff', 1), ('Jumpluff', 'Mr. Mime', 1), ('Jumpluff', 'Ampharos', 1), ('Jumpluff', 'Qwilfish', 1), ('Jumpluff', 'Sandslash', 1), ('Jumpluff', 'Slowbro', 1), ('Blissey', 'Marowak', 
# ...

# %%
nx.draw(G)

# %%
print(apariciones)
# Out:
# {'Heracross': 2, 'Raikou': 9, 'Starmie': 3, 'Porygon2': 1, 'Jumpluff': 2, 'Blissey': 1, 'Marowak': 3, 'Diglett': 1, 'Magby': 2, 'Chinchou': 2, 'Exeggcute': 3, 'Porygon': 2, 'Houndour': 3, 'Gastly': 1, 'Staryu': 3, 'Machop': 4, 'Elekid': 5, 'Cubone': 2, 'Abra': 3, 'Chansey': 3, 'Doduo': 1, 'Drowzee': 6, 'Poliwag': 1, 'Sandshrew': 1, 'Dugtrio': 2, 'Xatu': 7, 'Pineco': 6, 'Fearow': 1, 'Magnemite': 2, 'Octillery': 1, 'Omanyte': 2, 'Ninetales': 3, 'Gloom': 3, 'Hitmonlee': 2, 'Wigglytuff': 1, 'Dragonair': 1, 'Dewgong': 1, 'Flareon': 1, 'Rapidash': 3, 'Magmar': 1, 'Sudowoodo': 3, 'Slowpoke': 1, 'Weezing': 3, 'Primeape': 2, 'Stantler': 2, 'Zapdos': 11, 'Snorlax': 18, 'Exeggutor': 5, 'Steelix': 7, 'Cloyster': 11, 'Machamp': 2, 'Vaporeon': 1, 'Nidoking': 3, 'Tyranitar': 5, 'Miltank': 1, 'Skarmory': 5, 'Forretress': 5, 'Suicune': 2, 'Misdreavus': 1, 'Umbreon': 2, 'Gengar': 3, 'Golem': 2, 'Mewtwo': 4, 'Mew': 5, 'Lugia': 2, 'Jolteon': 1, 'Celebi': 1, 'Qwilfish': 5, 'Nidoqueen': 5, 'Ampharos': 2, 
# ...

# %%
for pok in G.nodes :
    G.nodes[pok]['teams'] = apariciones[pok]

# %%
G.nodes.data()
# Out:
# NodeDataView({'Heracross': {'type1': 'Bug', 'type2': 'Fighting', 'teams': 2}, 'Raikou': {'type1': 'Electric', 'type2': 'None', 'teams': 9}, 'Starmie': {'type1': 'Water', 'type2': 'Psychic', 'teams': 3}, 'Porygon2': {'type1': 'Normal', 'type2': 'None', 'teams': 1}, 'Jumpluff': {'type1': 'Grass', 'type2': 'Flying', 'teams': 2}, 'Blissey': {'type1': 'Normal', 'type2': 'None', 'teams': 1}, 'Marowak': {'type1': 'Ground', 'type2': 'None', 'teams': 3}, 'Diglett': {'type1': 'Ground', 'type2': 'None', 'teams': 1}, 'Magby': {'type1': 'Fire', 'type2': 'None', 'teams': 2}, 'Chinchou': {'type1': 'Water', 'type2': 'Electric', 'teams': 2}, 'Exeggcute': {'type1': 'Grass', 'type2': 'Psychic', 'teams': 3}, 'Porygon': {'type1': 'Normal', 'type2': 'None', 'teams': 2}, 'Houndour': {'type1': 'Dark', 'type2': 'Fire', 'teams': 3}, 'Gastly': {'type1': 'Ghost', 'type2': 'Poison', 'teams': 1}, 'Staryu': {'type1': 'Water', 'type2': 'None', 'teams': 3}, 'Machop': {'type1': 'Fighting', 'type2': 'None', 'teams': 4
# ...

# %%
for pok in G.nodes :
    G.nodes[pok]['teams'] = apariciones[pok]

# %%
nx.write_gexf(G, "Gen2Graph.gexf", version="1.2draft")
