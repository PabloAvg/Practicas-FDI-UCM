# %%
import networkx as nx
import itertools as it

# %%
# Importo Beautiful Soup
from bs4 import BeautifulSoup
# Importo requests para pillar el código html de donde quiera
import requests

# Cogemos la Pokédex
webDex = requests.get('https://pokemondb.net/pokedex/national')
dexSoup  = BeautifulSoup(webDex.content, 'html.parser')

# %%
pokedex = {}
G= nx.Graph()
types = [['itype', 'grass'], ['itype', 'poison'], ['itype', 'fire'], ['itype', 'flying'], ['itype', 'water'], 
         ['itype', 'bug'], ['itype', 'normal'], ['itype', 'electric'], ['itype', 'ground'], ['itype', 'fairy'], 
         ['itype', 'fighting'], ['itype', 'psychic'], ['itype', 'rock'], ['itype', 'steel'], 
         ['itype', 'ice'], ['itype', 'ghost'], ['itype', 'dark'], ['itype', 'dragon']]

for name in dexSoup.find_all('a'):
    if name.get('class') == ['ent-name']:
        pok = name.get_text()
        pokedex[pok] = {'type1' : 'None', 'type2' : 'None'}
    if name.get('class') in types:
        if pokedex[pok]['type1'] == 'None':
            pokedex[pok]['type1'] = name.get_text()
        else:
            pokedex[pok]['type2'] = name.get_text()

# %%
print(pokedex)
# Out:
# {'Bulbasaur': {'type1': 'Grass', 'type2': 'Poison'}, 'Ivysaur': {'type1': 'Grass', 'type2': 'Poison'}, 'Venusaur': {'type1': 'Grass', 'type2': 'Poison'}, 'Charmander': {'type1': 'Fire', 'type2': 'None'}, 'Charmeleon': {'type1': 'Fire', 'type2': 'None'}, 'Charizard': {'type1': 'Fire', 'type2': 'Flying'}, 'Squirtle': {'type1': 'Water', 'type2': 'None'}, 'Wartortle': {'type1': 'Water', 'type2': 'None'}, 'Blastoise': {'type1': 'Water', 'type2': 'None'}, 'Caterpie': {'type1': 'Bug', 'type2': 'None'}, 'Metapod': {'type1': 'Bug', 'type2': 'None'}, 'Butterfree': {'type1': 'Bug', 'type2': 'Flying'}, 'Weedle': {'type1': 'Bug', 'type2': 'Poison'}, 'Kakuna': {'type1': 'Bug', 'type2': 'Poison'}, 'Beedrill': {'type1': 'Bug', 'type2': 'Poison'}, 'Pidgey': {'type1': 'Normal', 'type2': 'Flying'}, 'Pidgeotto': {'type1': 'Normal', 'type2': 'Flying'}, 'Pidgeot': {'type1': 'Normal', 'type2': 'Flying'}, 'Rattata': {'type1': 'Normal', 'type2': 'None'}, 'Raticate': {'type1': 'Normal', 'type2': 'None'}, 'Spe
# ...

# %%
teams = []

apariciones = {}

t1= []
 
t1.append('Terrakion')
t1.append('Charizard')
t1.append('Gardevoir')
 
teams.append(t1)
 
t2= []
 
t2.append('Slowbro')
t2.append('Heatran')
t2.append('Gardevoir')
 
teams.append(t2)
 
t3= []
 
t3.append('Latias')
t3.append('Mawile')
t3.append('Heatran')
 
teams.append(t3)
 
t4= []
 
t4.append('Mawile')
t4.append('Charizard')
t4.append('Manaphy')
 
teams.append(t4)
 
t5= []
 
t5.append('Gardevoir')
t5.append('Tyranitar')
t5.append('Heatran')
 
teams.append(t5)

t7= []
 
t7.append('Carvanha')
t7.append('Gothita')
t7.append('Mienfoo')
t7.append('Vullaby')
t7.append('Magnemite')
t7.append('Onix')
 
teams.append(t7)
 
t8= []
 
t8.append('Mienfoo')
t8.append('Pawniard')
t8.append('Ferroseed')
t8.append('Gothita')
t8.append('Ponyta')
t8.append('Staryu')
 
teams.append(t8)
 
t9= []
 
t9.append('Snivy')
t9.append('Spritzee')
t9.append('Gothita')
t9.append('Onix')
t9.append('Pawniard')
t9.append('Timburr')
 
teams.append(t9)
 
t10= []
 
t10.append('Diglett')
t10.append('Archen')
t10.append('Pawniard')
t10.append('Spritzee')
t10.append('Shellder')
t10.append('Mienfoo')
 
teams.append(t10)
 
t11= []
 
t11.append('Corphish')
t11.append('Diglett')
t11.append('Pawniard')
t11.append('Mienfoo')
t11.append('Foongus')
t11.append('Chinchou')
 
teams.append(t11)
 
t12= []
 
t12.append('Shellder')
t12.append('Diglett')
t12.append('Pawniard')
t12.append('Croagunk')
t12.append('Porygon')
t12.append('Pawniard')
 
teams.append(t12)
 
t13= []
 
t13.append('Drilbur')
t13.append('Foongus')
t13.append('Mienfoo')
t13.append('Tirtouga')
t13.append('Diglett')
t13.append('Foongus')
 
teams.append(t13)
 
t14= []
 
t14.append('Staryu')
t14.append('Pawniard')
t14.append('Tirtouga')
t14.append('Dwebble')
t14.append('Abra')
t14.append('Pumpkaboo')
 
teams.append(t14)
 
t15= []
 
t15.append('Pawniard')
t15.append('Timburr')
t15.append('Scraggy')
t15.append('Honedge')
t15.append('Chinchou')
t15.append('Timburr')
 
teams.append(t15)

t17= []
 
t17.append('Skarmory')
t17.append('Ferrothorn')
t17.append('Heatran')
t17.append('Bisharp')
t17.append('Excadrill')
t17.append('Scizor')
 
teams.append(t17)
 
t18= []
 
t18.append('Gyarados')
t18.append('Tentacruel')
t18.append('Keldeo')
t18.append('Swampert')
t18.append('Suicune')
t18.append('Rotom')
 
teams.append(t18)
 
t19= []
 
t19.append('Aerodactyl')
t19.append('Skarmory')
t19.append('Zapdos')
t19.append('Thundurus')
t19.append('Landorus')
t19.append('Tornadus')
 
teams.append(t19)
 
t20= []
 
t20.append('Garchomp')
t20.append('Kyurem')
t20.append('Latios')
t20.append('Latias')
t20.append('Hydreigon')
t20.append('Dragonite')
 
teams.append(t20)
 
t21= []
 
t21.append('Landorus')
t21.append('Tornadus')
t21.append('Thundurus')
t21.append('Skarmory')
t21.append('Gyarados')
t21.append('Zapdos')
 
teams.append(t21)
 
t22= []
 
t22.append('Ferrothorn')
t22.append('Skarmory')
t22.append('Heatran')
t22.append('Scizor')
t22.append('Magnezone')
t22.append('Excadrill')
 
teams.append(t22)
 
t23= []
 
t23.append('Politoed')
t23.append('Kingdra')
t23.append('Swampert')
t23.append('Rotom')
t23.append('Keldeo')
t23.append('Clefable')
 
teams.append(t23)
 
t24= []
 
t24.append('Gardevoir')
t24.append('Togekiss')
t24.append('Diancie')
t24.append('Klefki')
t24.append('Azumarill')
t24.append('Heracross')
 
teams.append(t24)
 
t25= []
 
t25.append('Galvantula')
t25.append('Volcarona')
t25.append('Scizor')
t25.append('Armaldo')
t25.append('Yanmega')
t25.append('Seismitoad')
 
teams.append(t25)
 
t26= []
 
t26.append('Mamoswine')
t26.append('Landorus')
t26.append('Excadrill')
t26.append('Garchomp')
t26.append('Hippowdon')
t26.append('Gardevoir')
 
teams.append(t26)
 
t27= []
 
t27.append('Slowbro')
t27.append('Jirachi')
t27.append('Mew')
t27.append('Latios')
t27.append('Victini')
t27.append('Chansey')
 
teams.append(t27)
 
t28= []
 
t28.append('Lopunny')
t28.append('Diggersby')
t28.append('Ditto')
t28.append('Porygon2')
t28.append('Staraptor')

t29= []
 
t29.append('Hitmonchan')
t29.append('Jynx')
t29.append('Garbodor')
t29.append('Rhydon')
t29.append('Swellow')
t29.append('Lanturn')
 
teams.append(t29)
 
t30= []
 
t30.append('Vileplume')
t30.append('Tauros')
t30.append('Rhydon')
t30.append('Lanturn')
t30.append('Mesprit')
t30.append('Gurdurr')
 
teams.append(t30)
 
t31= []
 
t31.append('Mesprit')
t31.append('Rotom')
t31.append('Garbodor')
t31.append('Combusken')
t31.append('Lanturn')
t31.append('Shiftry')
 
teams.append(t31)
 
t32= []
 
t32.append('Tauros')
t32.append('Grumpig')
t32.append('Steelix')
t32.append('Hitmonchan')
t32.append('Vileplume')
t32.append('Lanturn')
 
teams.append(t32)
 
t33= []
 
t33.append('Liepard')
t33.append('Mesprit')
t33.append('Ludicolo')
t33.append('Omastar')
t33.append('Kabutops')
t33.append('Garbodor')
 
teams.append(t33)
t34= []
 
t34.append('Diancie')
t34.append('Volcarona')
t34.append('Starmie')
t34.append('Ferrothorn')
t34.append('Landorus')
t34.append('Weavile')
 
teams.append(t34)
 
t35= []
 
t35.append('Metagross')
t35.append('Garchomp')
t35.append('Magnezone')
t35.append('Latios')
t35.append('Clefable')
t35.append('Keldeo')
 
teams.append(t35)
 
t36= []
 
t36.append('Charizard')
t36.append('Clefable')
t36.append('Slowbro')
t36.append('Tyranitar')
t36.append('Excadrill')
t36.append('Keldeo')
 
teams.append(t36)
 
t37= []
 
t37.append('Tyranitar')
t37.append('Gliscor')
t37.append('Rotom')
t37.append('Excadrill')
t37.append('Tornadus')
t37.append('Keldeo')
 
teams.append(t37)
 
t38= []
 
t38.append('Shuckle')
t38.append('Scizor')
t38.append('Azumarill')
t38.append('Hoopa')
t38.append('Thundurus')
t38.append('Bisharp')
 
teams.append(t38)
 
t39= []
 
t39.append('Quagsire')
t39.append('Altaria')
t39.append('Magnezone')
t39.append('Suicune')
t39.append('Zapdos')
t39.append('Chansey')
 
teams.append(t39)
 
t40= []
 
t40.append('Azumarill')
t40.append('Metagross')
t40.append('Latias')
t40.append('Garchomp')
t40.append('Bisharp')
t40.append('Thundurus')
 
teams.append(t40)
 
t41= []
 
t41.append('Clefable')
t41.append('Latios')
t41.append('Amoonguss')
t41.append('Magnezone')
t41.append('Gliscor')
t41.append('Slowbro')
 
teams.append(t41)
 
t42= []
 
t42.append('Clefable')
t42.append('Crawdaunt')
t42.append('Metagross')
t42.append('Garchomp')
t42.append('Rotom')
t42.append('Tornadus')
 
teams.append(t42)
 
t43= []
 
t43.append('Metagross')
t43.append('Clefable')
t43.append('Gliscor')
t43.append('Tyranitar')
t43.append('Skarmory')
t43.append('Amoonguss')
 
teams.append(t43)
 
t44= []
 
t44.append('Slowbro')
t44.append('Alakazam')
t44.append('Zapdos')
t44.append('Tyranitar')
t44.append('Gliscor')
t44.append('Ferrothorn')
 
teams.append(t44)
 
t45= []
 
t45.append('Alakazam')
t45.append('Manaphy')
t45.append('Tornadus')
t45.append('Ferrothorn')
t45.append('Heatran')
t45.append('Gliscor')
 
teams.append(t45)
 
t46= []
 
t46.append('Keldeo')
t46.append('Tyranitar')
t46.append('Gliscor')
t46.append('Ferrothorn')
t46.append('Tornadus')
t46.append('Slowbro')
 
teams.append(t46)
 
t47= []
 
t47.append('Scizor')
t47.append('Heatran')
t47.append('Starmie')
t47.append('Amoonguss')
t47.append('Gliscor')
t47.append('Weavile')
 
teams.append(t47)
 
t48= []
 
t48.append('Hydreigon')
t48.append('Jellicent')
t48.append('Heatran')
t48.append('Keldeo')
t48.append('Metagross')
t48.append('Landorus')
 
teams.append(t48)

t49= []
 
t49.append('Muk')
t49.append('Probopass')
t49.append('Leafeon')
t49.append('Vullaby')
t49.append('Clefairy')
t49.append('Mr. Mime')
 
teams.append(t49)
 
t50= []
 
t50.append('Articuno')
t50.append('Muk')
t50.append('Probopass')
t50.append('Lumineon')
t50.append('Grumpig')
t50.append('Leafeon')
 
teams.append(t50)
 
t51= []
 
t51.append('Rotom')
t51.append('Prinplup')
t51.append('Golem')
t51.append('Rapidash')
t51.append('Bouffalant')
t51.append('Mr. Mime')
 
teams.append(t51)
 
t52= []
 
t52.append('Dodrio')
t52.append('Cacturne')
t52.append('Mawile')
t52.append('Mr. Mime')
t52.append('Golem')
t52.append('Rotom')
 
teams.append(t52)
 
t53= []
 
t53.append('Stoutland')
t53.append('Mr. Mime')
t53.append('Muk')
t53.append('Zebstrika')
t53.append('Probopass')
t53.append('Prinplup')
 
teams.append(t53)
 
t54= []
 
t54.append('Mr. Mime')
t54.append('Dusknoir')
t54.append('Monferno')
t54.append('Rotom')
t54.append('Golem')
t54.append('Leafeon')
 
teams.append(t54)
 
t55= []
 
t55.append('Leafeon')
t55.append('Dodrio')
t55.append('Grumpig')
t55.append('Lumineon')
t55.append('Zebstrika')
t55.append('Golem')
 
teams.append(t55)
 
t56= []
 
t56.append('Crustle')
t56.append('Misdreavus')
t56.append('Stoutland')
t56.append('Monferno')
t56.append('Electrode')
t56.append('Floatzel')
 
teams.append(t56)
 
t57= []
 
t57.append('Monferno')
t57.append('Grumpig')
t57.append('Rotom')
t57.append('Bouffalant')
t57.append('Golem')
t57.append('Floatzel')
 
teams.append(t57)

t58= []
 
t58.append('Hoopa')
t58.append('Scrafty')
t58.append('Registeel')
t58.append('Flygon')
t58.append('Scyther')
t58.append('Rotom')
 
teams.append(t58)
 
t59= []
 
t59.append('Sceptile')
t59.append('Rotom')
t59.append('Slowking')
t59.append('Flygon')
t59.append('Registeel')
t59.append('Drapion')
 
teams.append(t59)
 
t60= []
 
t60.append('Sneasel')
t60.append('Virizion')
t60.append('Uxie')
t60.append('Diancie')
t60.append('Emboar')
t60.append('Flygon')
 
teams.append(t60)
t61= []
 
t61.append('Deoxys')
t61.append('Salamence')
t61.append('Arceus')
t61.append('Groudon')
t61.append('Xerneas')
t61.append('Darkrai')
 
teams.append(t61)
 
t62= []
 
t62.append('Deoxys')
t62.append('Salamence')
t62.append('Arceus')
t62.append('Groudon')
t62.append('Xerneas')
t62.append('Dialga')
 
teams.append(t62)
 
t63= []
 
t63.append('Groudon')
t63.append('Arceus')
t63.append('Rayquaza')
t63.append('Darkrai')
t63.append('Gengar')
t63.append('Excadrill')
 
teams.append(t63)
 
t64= []
 
t64.append('Groudon')
t64.append('Arceus')
t64.append('Cloyster')
t64.append('Xerneas')
t64.append('Salamence')
t64.append('Deoxys')
 
teams.append(t64)
 
t65= []
 
t65.append('Groudon')
t65.append('Arceus')
t65.append('Giratina')
t65.append('Darkrai')
t65.append('Salamence')
t65.append('Klefki')
 
teams.append(t65)
 
t66= []
 
t66.append('Yveltal')
t66.append('Skarmory')
t66.append('Arceus')
t66.append('Groudon')
t66.append('Diancie')
t66.append('Ho-oh')
 
teams.append(t66)
 
t67= []
 
t67.append('Empoleon')
t67.append('Arceus')
t67.append('Giratina')
t67.append('Blissey')
t67.append('Sableye')
t67.append('Lugia')
 
teams.append(t67)
t68= []
 
t68.append('Hydreigon')
t68.append('Hoopa')
t68.append('Empoleon')
t68.append('Conkeldurr')
t68.append('Swampert')
t68.append('Kyurem')
 
teams.append(t68)
 
t69= []
 
t69.append('Empoleon')
t69.append('Slowking')
t69.append('Nidoqueen')
t69.append('Whimsicott')
t69.append('Aerodactyl')
t69.append('Mienshao')
 
teams.append(t69)
 
t70= []
 
t70.append('Metagross')
t70.append('Aerodactyl')
t70.append('Slowking')
t70.append('Empoleon')
t70.append('Krookodile')
t70.append('Suicune')
 
teams.append(t70)
 
t71= []
 
t71.append('Aerodactyl')
t71.append('Florges')
t71.append('Bronzong')
t71.append('Tentacruel')
t71.append('Krookodile')
t71.append('Arcanine')
 
teams.append(t71)
 
t72= []
 
t72.append('Xatu')
t72.append('Forretress')
t72.append('Blissey')
t72.append('Chesnaught')
t72.append('Swampert')
t72.append('Kyurem')
 
teams.append(t72)
 
t73= []
 
t73.append('Reuniclus')
t73.append('Tentacruel')
t73.append('Bronzong')
t73.append('Conkeldurr')
t73.append('Swampert')
t73.append('Sceptile')
 
teams.append(t73)
 
t74= []
 
t74.append('Mienshao')
t74.append('Metagross')
t74.append('Seismitoad')
t74.append('Mandibuzz')
t74.append('Florges')
teams.append(t74)
t75= []
 
t75.append('Infernape')
t75.append('Klefki')
t75.append('Reuniclus')
t75.append('Hydreigon')
t75.append('Aerodactyl')
t75.append('Tentacruel')
 
teams.append(t75)
 
t76= []
 
t76.append('Sharpedo')
t76.append('Latias')
t76.append('Froslass')
t76.append('Cobalion')
t76.append('Mimikyu')
t76.append('Mamoswine')
 
teams.append(t76)
 
t77= []
 
t77.append('Xatu')
t77.append('Krookodile')
t77.append('Latias')
t77.append('Linoone')
t77.append('Scizor')
t77.append('Feraligatr')
 
teams.append(t77)
 
t78= []
 
t78.append('Tentacruel')
t78.append('Aerodactyl')
t78.append('Celebi')
t78.append('Hippowdon')
t78.append('Cobalion')
t78.append('Doublade')
 
teams.append(t78)
 
t79= []
 
t79.append('Alomomola')
t79.append('Quagsire')
t79.append('Nihilego')
t79.append('Blissey')
t79.append('Gligar')
t79.append('Altaria')
 
teams.append(t79)
 
t80= []
 
t80.append('Altaria')
t80.append('Magneton')
t80.append('Alomomola')
t80.append('Blissey')
t80.append('Gligar')
t80.append('Scizor')
 
teams.append(t80)
 
t81= []
 
t81.append('Rotom')
t81.append('Altaria')
t81.append('Tentacruel')
t81.append('Krookodile')
t81.append('Necrozma')
t81.append('Scizor')
 
teams.append(t81)

# %%
print(teams)
# Out:
# [['Terrakion', 'Charizard', 'Gardevoir'], ['Slowbro', 'Heatran', 'Gardevoir'], ['Latias', 'Mawile', 'Heatran'], ['Mawile', 'Charizard', 'Manaphy'], ['Gardevoir', 'Tyranitar', 'Heatran'], ['Carvanha', 'Gothita', 'Mienfoo', 'Vullaby', 'Magnemite', 'Onix'], ['Mienfoo', 'Pawniard', 'Ferroseed', 'Gothita', 'Ponyta', 'Staryu'], ['Snivy', 'Spritzee', 'Gothita', 'Onix', 'Pawniard', 'Timburr'], ['Diglett', 'Archen', 'Pawniard', 'Spritzee', 'Shellder', 'Mienfoo'], ['Corphish', 'Diglett', 'Pawniard', 'Mienfoo', 'Foongus', 'Chinchou'], ['Shellder', 'Diglett', 'Pawniard', 'Croagunk', 'Porygon', 'Pawniard'], ['Drilbur', 'Foongus', 'Mienfoo', 'Tirtouga', 'Diglett', 'Foongus'], ['Staryu', 'Pawniard', 'Tirtouga', 'Dwebble', 'Abra', 'Pumpkaboo'], ['Pawniard', 'Timburr', 'Scraggy', 'Honedge', 'Chinchou', 'Timburr'], ['Skarmory', 'Ferrothorn', 'Heatran', 'Bisharp', 'Excadrill', 'Scizor'], ['Gyarados', 'Tentacruel', 'Keldeo', 'Swampert', 'Suicune', 'Rotom'], ['Aerodactyl', 'Skarmory', 'Zapdos', 'Thunduru
# ...

# %%
print(len(teams))
# Out:
# 78

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Terrakion', 'Charizard', 1), ('Terrakion', 'Gardevoir', 1), ('Charizard', 'Gardevoir', 1), ('Charizard', 'Mawile', 1), ('Charizard', 'Manaphy', 1), ('Charizard', 'Clefable', 1), ('Charizard', 'Slowbro', 1), ('Charizard', 'Tyranitar', 1), ('Charizard', 'Excadrill', 1), ('Charizard', 'Keldeo', 1), ('Gardevoir', 'Slowbro', 1), ('Gardevoir', 'Heatran', 2), ('Gardevoir', 'Tyranitar', 1), ('Gardevoir', 'Togekiss', 1), ('Gardevoir', 'Diancie', 1), ('Gardevoir', 'Klefki', 1), ('Gardevoir', 'Azumarill', 1), ('Gardevoir', 'Heracross', 1), ('Gardevoir', 'Mamoswine', 1), ('Gardevoir', 'Landorus', 1), ('Gardevoir', 'Excadrill', 1), ('Gardevoir', 'Garchomp', 1), ('Gardevoir', 'Hippowdon', 1), ('Slowbro', 'Heatran', 1), ('Slowbro', 'Jirachi', 1), ('Slowbro', 'Mew', 1), ('Slowbro', 'Latios', 2), ('Slowbro', 'Victini', 1), ('Slowbro', 'Chansey', 1), ('Slowbro', 'Clefable', 2), ('Slowbro', 'Tyranitar', 3), ('Slowbro', 'Excadrill', 1), ('Slowbro', 'Keldeo', 2), ('Slowbro', 'Amoonguss', 
# ...

# %%
nx.draw(G)

# %%
print(apariciones)
# Out:
# {'Terrakion': 1, 'Charizard': 3, 'Gardevoir': 5, 'Slowbro': 6, 'Heatran': 8, 'Latias': 5, 'Mawile': 3, 'Manaphy': 2, 'Tyranitar': 6, 'Carvanha': 1, 'Gothita': 3, 'Mienfoo': 5, 'Vullaby': 2, 'Magnemite': 1, 'Onix': 2, 'Pawniard': 8, 'Ferroseed': 1, 'Ponyta': 1, 'Staryu': 2, 'Snivy': 1, 'Spritzee': 2, 'Timburr': 3, 'Diglett': 4, 'Archen': 1, 'Shellder': 2, 'Corphish': 1, 'Foongus': 3, 'Chinchou': 2, 'Croagunk': 1, 'Porygon': 1, 'Drilbur': 1, 'Tirtouga': 2, 'Dwebble': 1, 'Abra': 1, 'Pumpkaboo': 1, 'Scraggy': 1, 'Honedge': 1, 'Skarmory': 6, 'Ferrothorn': 6, 'Bisharp': 3, 'Excadrill': 6, 'Scizor': 8, 'Gyarados': 2, 'Tentacruel': 6, 'Keldeo': 7, 'Swampert': 5, 'Suicune': 3, 'Rotom': 12, 'Aerodactyl': 6, 'Zapdos': 4, 'Thundurus': 4, 'Landorus': 5, 'Tornadus': 6, 'Garchomp': 5, 'Kyurem': 3, 'Latios': 4, 'Hydreigon': 4, 'Dragonite': 1, 'Magnezone': 4, 'Politoed': 1, 'Kingdra': 1, 'Clefable': 6, 'Togekiss': 1, 'Diancie': 4, 'Klefki': 3, 'Azumarill': 3, 'Heracross': 1, 'Galvantula': 1, 'Volcaro
# ...

# %%
for pok in G.nodes :
    G.nodes[pok]['teams'] = apariciones[pok]

# %%
G.nodes.data()
# Out:
# NodeDataView({'Terrakion': {'type1': 'Rock', 'type2': 'Fighting', 'teams': 1}, 'Charizard': {'type1': 'Fire', 'type2': 'Flying', 'teams': 3}, 'Gardevoir': {'type1': 'Psychic', 'type2': 'Fairy', 'teams': 5}, 'Slowbro': {'type1': 'Water', 'type2': 'Psychic', 'teams': 6}, 'Heatran': {'type1': 'Fire', 'type2': 'Steel', 'teams': 8}, 'Latias': {'type1': 'Dragon', 'type2': 'Psychic', 'teams': 5}, 'Mawile': {'type1': 'Steel', 'type2': 'Fairy', 'teams': 3}, 'Manaphy': {'type1': 'Water', 'type2': 'None', 'teams': 2}, 'Tyranitar': {'type1': 'Rock', 'type2': 'Dark', 'teams': 6}, 'Carvanha': {'type1': 'Water', 'type2': 'Dark', 'teams': 1}, 'Gothita': {'type1': 'Psychic', 'type2': 'None', 'teams': 3}, 'Mienfoo': {'type1': 'Fighting', 'type2': 'None', 'teams': 5}, 'Vullaby': {'type1': 'Dark', 'type2': 'Flying', 'teams': 2}, 'Magnemite': {'type1': 'Electric', 'type2': 'Steel', 'teams': 1}, 'Onix': {'type1': 'Rock', 'type2': 'Ground', 'teams': 2}, 'Pawniard': {'type1': 'Dark', 'type2': 'Steel', 'team
# ...

# %%
for pok in G.nodes :
    G.nodes[pok]['teams'] = apariciones[pok]

# %%
nx.write_gexf(G, "Gen6Graph.gexf", version="1.2draft")
