# %%
import networkx as nx
import itertools as it
# Importo Beautiful Soup
from bs4 import BeautifulSoup
# Importo requests para pillar el código html de donde quiera
import requests

# %%
# Cogemos la Pokédex
webDex = requests.get('https://pokemondb.net/pokedex/national')
dexSoup  = BeautifulSoup(webDex.content, 'html.parser')

apariciones = {}
pokedex = {}
G = nx.Graph()
teams = []
types = [['itype', 'grass'], ['itype', 'poison'], ['itype', 'fire'], ['itype', 'flying'], ['itype', 'water'], 
         ['itype', 'bug'], ['itype', 'normal'], ['itype', 'electric'], ['itype', 'ground'], ['itype', 'fairy'], 
         ['itype', 'fighting'], ['itype', 'psychic'], ['itype', 'rock'], ['itype', 'steel'], 
         ['itype', 'ice'], ['itype', 'ghost'], ['itype', 'dark'], ['itype', 'dragon']]


for name in dexSoup.find_all('a'):
    if name.get('class') == ['ent-name']:
        pok = name.get_text()
        pokedex[pok] = {'type1' : 'None', 'type2' : 'None'}
    if name.get('class') in types:
        if pokedex[pok]['type1'] == 'None':
            pokedex[pok]['type1'] = name.get_text()
        else:
            pokedex[pok]['type2'] = name.get_text()

# %% [markdown]
# # 1vs1

# %%
t1= []
 
t1.append('Blaziken')
t1.append('Jolteon')
t1.append('Zapdos')
 
teams.append(t1)
 
t2= []
 
t2.append('Starmie')
t2.append('Aerodactyl')
t2.append('Entei')
 
teams.append(t2)
 
t3= []
 
t3.append('Registeel')
t3.append('Zapdos')
t3.append('Marowak')
 
teams.append(t3)
 
t4= []
 
t4.append('Sceptile')
t4.append('Marowak')
t4.append('Raikou')
 
teams.append(t4)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Blaziken', 'Jolteon', 1), ('Blaziken', 'Zapdos', 1), ('Jolteon', 'Zapdos', 1), ('Zapdos', 'Registeel', 1), ('Zapdos', 'Marowak', 1), ('Starmie', 'Aerodactyl', 1), ('Starmie', 'Entei', 1), ('Aerodactyl', 'Entei', 1), ('Registeel', 'Marowak', 1), ('Marowak', 'Sceptile', 1), ('Marowak', 'Raikou', 1), ('Sceptile', 'Raikou', 1)])

# %% [markdown]
# # LC

# %%
t5= []
 
t5.append('Voltorb')
t5.append('Diglett')
t5.append('Doduo')
t5.append('Shellder')
t5.append('Exeggcute')
t5.append('Oddish')
 
teams.append(t5)
 
t6= []
 
t6.append('Houndour')
t6.append('Shellder')
t6.append('Trapinch')
t6.append('Elekid')
t6.append('Anorith')
t6.append('Doduo')
 
teams.append(t6)
 
t7= []
 
t7.append('Abra')
t7.append('Diglett')
t7.append('Doduo')
t7.append('Larvitar')
t7.append('Meowth')
t7.append('Koffing')
 
teams.append(t7)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Blaziken', 'Jolteon', 2), ('Blaziken', 'Zapdos', 2), ('Jolteon', 'Zapdos', 2), ('Zapdos', 'Registeel', 2), ('Zapdos', 'Marowak', 2), ('Starmie', 'Aerodactyl', 2), ('Starmie', 'Entei', 2), ('Aerodactyl', 'Entei', 2), ('Registeel', 'Marowak', 2), ('Marowak', 'Sceptile', 2), ('Marowak', 'Raikou', 2), ('Sceptile', 'Raikou', 2), ('Voltorb', 'Diglett', 1), ('Voltorb', 'Doduo', 1), ('Voltorb', 'Shellder', 1), ('Voltorb', 'Exeggcute', 1), ('Voltorb', 'Oddish', 1), ('Diglett', 'Doduo', 2), ('Diglett', 'Shellder', 1), ('Diglett', 'Exeggcute', 1), ('Diglett', 'Oddish', 1), ('Diglett', 'Abra', 1), ('Diglett', 'Larvitar', 1), ('Diglett', 'Meowth', 1), ('Diglett', 'Koffing', 1), ('Doduo', 'Shellder', 2), ('Doduo', 'Exeggcute', 1), ('Doduo', 'Oddish', 1), ('Doduo', 'Houndour', 1), ('Doduo', 'Trapinch', 1), ('Doduo', 'Elekid', 1), ('Doduo', 'Anorith', 1), ('Doduo', 'Abra', 1), ('Doduo', 'Larvitar', 1), ('Doduo', 'Meowth', 1), ('Doduo', 'Koffing', 1), ('Shellder', 'Exeggcute', 1), ('Shellder', 'Oddish', 1), ('Shellder', 'Houndour', 1), ('Shellder', 'Trapinch', 1), ('Shellder', 'Elekid', 1), ('Shellder', 'Anorith', 1), ('Exeggcute', 'Oddish', 1), ('Houndour', 'Trapinch', 1), ('Houndour', 'Elekid', 1), ('Houndour', 'Anorith', 1), ('Trapinch', 'Elekid', 1), ('Trapinch', 'Anorith', 1), ('Elekid', 'Anorith', 1), ('Abra', 'Larvitar', 1), ('Abra', 'Meowth', 1), ('Abra', 'Koffing', 1), ('Larvitar', 'Meowth', 1), ('Larvitar', 'Koffing', 1), ('Meowth', 'Koffing', 1)])

# %% [markdown]
# # NU

# %%
t8= []
 
t8.append('Pidgeot')
t8.append('Hitmonchan')
t8.append('Magcargo')
t8.append('Roselia')
t8.append('Chimecho')
t8.append('Seaking')
 
teams.append(t8)
 
t9= []
 
t9.append('Hitmonchan')
t9.append('Flareon')
t9.append('Mawile')
t9.append('Sableye')
t9.append('Roselia')
t9.append('Pelipper')
 
teams.append(t9)
 
t10= []
 
t10.append('Seadra')
t10.append('Murkrow')
t10.append('Flareon')
t10.append('Dewgong')
t10.append('Hitmonchan')
t10.append('Vigoroth')
 
teams.append(t10)
 
t11= []
 
t11.append('Hitmonchan')
t11.append('Flareon')
t11.append('Lileep')
t11.append('Sableye')
t11.append('Chimecho')
t11.append('Dewgong')
 
teams.append(t11)
 
t12= []
 
t12.append('Hitmonchan')
t12.append('Haunter')
t12.append('Metang')
t12.append('Kecleon')
t12.append('Octillery')
t12.append('Pupitar')
 
teams.append(t12)
 
t13= []
 
t13.append('Vigoroth')
t13.append('Torkoal')
t13.append('Mawile')
t13.append('Golbat')
t13.append('Kingler')
t13.append('Cacturne')
 
teams.append(t13)
 
t14= []
 
t14.append('Torkoal')
t14.append('Piloswine')
t14.append('Dewgong')
t14.append('Hitmonchan')
t14.append('Arbok')
t14.append('Raticate')
 
teams.append(t14)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Blaziken', 'Jolteon', 3), ('Blaziken', 'Zapdos', 3), ('Jolteon', 'Zapdos', 3), ('Zapdos', 'Registeel', 3), ('Zapdos', 'Marowak', 3), ('Starmie', 'Aerodactyl', 3), ('Starmie', 'Entei', 3), ('Aerodactyl', 'Entei', 3), ('Registeel', 'Marowak', 3), ('Marowak', 'Sceptile', 3), ('Marowak', 'Raikou', 3), ('Sceptile', 'Raikou', 3), ('Voltorb', 'Diglett', 2), ('Voltorb', 'Doduo', 2), ('Voltorb', 'Shellder', 2), ('Voltorb', 'Exeggcute', 2), ('Voltorb', 'Oddish', 2), ('Diglett', 'Doduo', 4), ('Diglett', 'Shellder', 2), ('Diglett', 'Exeggcute', 2), ('Diglett', 'Oddish', 2), ('Diglett', 'Abra', 2), ('Diglett', 'Larvitar', 2), ('Diglett', 'Meowth', 2), ('Diglett', 'Koffing', 2), ('Doduo', 'Shellder', 4), ('Doduo', 'Exeggcute', 2), ('Doduo', 'Oddish', 2), ('Doduo', 'Houndour', 2), ('Doduo', 'Trapinch', 2), ('Doduo', 'Elekid', 2), ('Doduo', 'Anorith', 2), ('Doduo', 'Abra', 2), ('Doduo', 'Larvitar', 2), ('Doduo', 'Meowth', 2), ('Doduo', 'Koffing', 2), ('Shellder', 'Exeggcute', 2), ('Shellder', 'Oddish', 2), ('Shellder', 'Houndour', 2), ('Shellder', 'Trapinch', 2), ('Shellder', 'Elekid', 2), ('Shellder', 'Anorith', 2), ('Exeggcute', 'Oddish', 2), ('Houndour', 'Trapinch', 2), ('Houndour', 'Elekid', 2), ('Houndour', 'Anorith', 2), ('Trapinch', 'Elekid', 2), ('Trapinch', 'Anorith', 2), ('Elekid', 'Anorith', 2), ('Abra', 'Larvitar', 2), ('Abra', 'Meowth', 2), ('Abra', 'Koffing', 2), ('Larvitar', 'Meowth', 2), ('Larvitar', 'Koffing', 2), ('Meowth', 'Koffing', 2), ('Pidgeot', 'Hitmonchan', 1), ('Pidgeot', 'Magcargo', 1), ('Pidgeot', 'Roselia', 1), ('Pidgeot', 'Chimecho', 1), ('Pidgeot', 'Seaking', 1), ('Hitmonchan', 'Magcargo', 1), ('Hitmonchan', 'Roselia', 2), ('Hitmonchan', 'Chimecho', 2), ('Hitmonchan', 'Seaking', 1), ('Hitmonchan', 'Flareon', 3), ('Hitmonchan', 'Mawile', 1), ('Hitmonchan', 'Sableye', 2), ('Hitmonchan', 'Pelipper', 1), ('Hitmonchan', 'Seadra', 1), ('Hitmonchan', 'Murkrow', 1), ('Hitmonchan', 'Dewgong', 3), ('Hitmonchan', 'Vigoroth', 1), ('Hitmonchan', 'Lileep', 1), ('Hitmonchan', 'Haunter', 1), ('Hitmonchan', 'Metang', 1), ('Hitmonchan', 'Kecleon', 1), ('Hitmonchan', 'Octillery', 1), ('Hitmonchan', 'Pupitar', 1), ('Hitmonchan', 'Torkoal', 1), ('Hitmonchan', 'Piloswine', 1), ('Hitmonchan', 'Arbok', 1), ('Hitmonchan', 'Raticate', 1), ('Magcargo', 'Roselia', 1), ('Magcargo', 'Chimecho', 1), ('Magcargo', 'Seaking', 1), ('Roselia', 'Chimecho', 1), ('Roselia', 'Seaking', 1), ('Roselia', 'Flareon', 1), ('Roselia', 'Mawile', 1), ('Roselia', 'Sableye', 1), ('Roselia', 'Pelipper', 1), ('Chimecho', 'Seaking', 1), ('Chimecho', 'Flareon', 1), ('Chimecho', 'Lileep', 1), ('Chimecho', 'Sableye', 1), ('Chimecho', 'Dewgong', 1), ('Flareon', 'Mawile', 1), ('Flareon', 'Sableye', 2), ('Flareon', 'Pelipper', 1), ('Flareon', 'Seadra', 1), ('Flareon', 'Murkrow', 1), ('Flareon', 'Dewgong', 2), ('Flareon', 'Vigoroth', 1), ('Flareon', 'Lileep', 1), ('Mawile', 'Sableye', 1), ('Mawile', 'Pelipper', 1), ('Mawile', 'Vigoroth', 1), ('Mawile', 'Torkoal', 1), ('Mawile', 'Golbat', 1), ('Mawile', 'Kingler', 1), ('Mawile', 'Cacturne', 1), ('Sableye', 'Pelipper', 1), ('Sableye', 'Lileep', 1), ('Sableye', 'Dewgong', 1), ('Seadra', 'Murkrow', 1), ('Seadra', 'Dewgong', 1), ('Seadra', 'Vigoroth', 1), ('Murkrow', 'Dewgong', 1), ('Murkrow', 'Vigoroth', 1), ('Dewgong', 'Vigoroth', 1), ('Dewgong', 'Lileep', 1), ('Dewgong', 'Torkoal', 1), ('Dewgong', 'Piloswine', 1), ('Dewgong', 'Arbok', 1), ('Dewgong', 'Raticate', 1), ('Vigoroth', 'Torkoal', 1), ('Vigoroth', 'Golbat', 1), ('Vigoroth', 'Kingler', 1), ('Vigoroth', 'Cacturne', 1), ('Haunter', 'Metang', 1), ('Haunter', 'Kecleon', 1), ('Haunter', 'Octillery', 1), ('Haunter', 'Pupitar', 1), ('Metang', 'Kecleon', 1), ('Metang', 'Octillery', 1), ('Metang', 'Pupitar', 1), ('Kecleon', 'Octillery', 1), ('Kecleon', 'Pupitar', 1), ('Octillery', 'Pupitar', 1), ('Torkoal', 'Golbat', 1), ('Torkoal', 'Kingler', 1), ('Torkoal', 'Cacturne', 1), ('Torkoal', 'Piloswine', 1), ('Torkoal', 'Arbok', 1), ('Torkoal', 'Raticate', 1), ('G ...

# %% [markdown]
# # OU

# %%
t15= []
 
t15.append('Skarmory')
t15.append('Jolteon')
t15.append('Tyranitar')
t15.append('Gengar')
t15.append('Metagross')
t15.append('Starmie')
 
teams.append(t15)
 
t16= []
 
t16.append('Salamence')
t16.append('Zapdos')
t16.append('Swampert')
t16.append('Tyranitar')
t16.append('Metagross')
t16.append('Snorlax')
 
teams.append(t16)
 
t17= []
 
t17.append('Skarmory')
t17.append('Blissey')
t17.append('Tyranitar')
t17.append('Swampert')
t17.append('Gengar')
t17.append('Starmie')
 
teams.append(t17)
 
t18= []
 
t18.append('Suicune')
t18.append('Snorlax')
t18.append('Magneton')
t18.append('Salamence')
t18.append('Metagross')
t18.append('Heracross')
 
teams.append(t18)
 
t19= []
 
t19.append('Zapdos')
t19.append('Tyranitar')
t19.append('Skarmory')
t19.append('Celebi')
t19.append('Dugtrio')
t19.append('Swampert')
 
teams.append(t19)
 
t20= []
 
t20.append('Tyranitar')
t20.append('Celebi')
t20.append('Magneton')
t20.append('Swampert')
t20.append('Metagross')
t20.append('Aerodactyl')
 
teams.append(t20)
 
t21= []
 
t21.append('Tyranitar')
t21.append('Milotic')
t21.append('Blissey')
t21.append('Skarmory')
t21.append('Claydol')
t21.append('Dugtrio')
 
teams.append(t21)
 
t22= []
 
t22.append('Suicune')
t22.append('Dugtrio')
t22.append('Jirachi')
t22.append('Celebi')
t22.append('Porygon2')
t22.append('Raikou')
 
teams.append(t22)
 
t23= []
 
t23.append('Celebi')
t23.append('Swampert')
t23.append('Magneton')
t23.append('Skarmory')
t23.append('Tyranitar')
t23.append('Aerodactyl')
 
teams.append(t23)
 
t24= []
 
t24.append('Salamence')
t24.append('Celebi')
t24.append('Claydol')
t24.append('Magneton')
t24.append('Snorlax')
t24.append('Suicune')
 
teams.append(t24)
 
t25= []
 
t25.append('Tyranitar')
t25.append('Forretress')
t25.append('Dugtrio')
t25.append('Gengar')
t25.append('Swampert')
t25.append('Blissey')
 
teams.append(t25)
 
t26= []
 
t26.append('Tyranitar')
t26.append('Skarmory')
t26.append('Swampert')
t26.append('Blissey')
t26.append('Gengar')
t26.append('Moltres')
 
teams.append(t26)
 
t27= []
 
t27.append('Tyranitar')
t27.append('Skarmory')
t27.append('Moltres')
t27.append('Jirachi')
t27.append('Gengar')
t27.append('Flygon')
 
teams.append(t27)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Blaziken', 'Jolteon', 4), ('Blaziken', 'Zapdos', 4), ('Jolteon', 'Zapdos', 4), ('Jolteon', 'Skarmory', 1), ('Jolteon', 'Tyranitar', 1), ('Jolteon', 'Gengar', 1), ('Jolteon', 'Metagross', 1), ('Jolteon', 'Starmie', 1), ('Zapdos', 'Registeel', 4), ('Zapdos', 'Marowak', 4), ('Zapdos', 'Salamence', 1), ('Zapdos', 'Swampert', 2), ('Zapdos', 'Tyranitar', 2), ('Zapdos', 'Metagross', 1), ('Zapdos', 'Snorlax', 1), ('Zapdos', 'Skarmory', 1), ('Zapdos', 'Celebi', 1), ('Zapdos', 'Dugtrio', 1), ('Starmie', 'Aerodactyl', 4), ('Starmie', 'Entei', 4), ('Starmie', 'Skarmory', 2), ('Starmie', 'Tyranitar', 2), ('Starmie', 'Gengar', 2), ('Starmie', 'Metagross', 1), ('Starmie', 'Blissey', 1), ('Starmie', 'Swampert', 1), ('Aerodactyl', 'Entei', 4), ('Aerodactyl', 'Tyranitar', 2), ('Aerodactyl', 'Celebi', 2), ('Aerodactyl', 'Magneton', 2), ('Aerodactyl', 'Swampert', 2), ('Aerodactyl', 'Metagross', 1), ('Aerodactyl', 'Skarmory', 1), ('Registeel', 'Marowak', 4), ('Marowak', 'Sceptile', 4), ('Marowak', 'Raikou', 4), ('Sceptile', 'Raikou', 4), ('Raikou', 'Suicune', 1), ('Raikou', 'Dugtrio', 1), ('Raikou', 'Jirachi', 1), ('Raikou', 'Celebi', 1), ('Raikou', 'Porygon2', 1), ('Voltorb', 'Diglett', 3), ('Voltorb', 'Doduo', 3), ('Voltorb', 'Shellder', 3), ('Voltorb', 'Exeggcute', 3), ('Voltorb', 'Oddish', 3), ('Diglett', 'Doduo', 6), ('Diglett', 'Shellder', 3), ('Diglett', 'Exeggcute', 3), ('Diglett', 'Oddish', 3), ('Diglett', 'Abra', 3), ('Diglett', 'Larvitar', 3), ('Diglett', 'Meowth', 3), ('Diglett', 'Koffing', 3), ('Doduo', 'Shellder', 6), ('Doduo', 'Exeggcute', 3), ('Doduo', 'Oddish', 3), ('Doduo', 'Houndour', 3), ('Doduo', 'Trapinch', 3), ('Doduo', 'Elekid', 3), ('Doduo', 'Anorith', 3), ('Doduo', 'Abra', 3), ('Doduo', 'Larvitar', 3), ('Doduo', 'Meowth', 3), ('Doduo', 'Koffing', 3), ('Shellder', 'Exeggcute', 3), ('Shellder', 'Oddish', 3), ('Shellder', 'Houndour', 3), ('Shellder', 'Trapinch', 3), ('Shellder', 'Elekid', 3), ('Shellder', 'Anorith', 3), ('Exeggcute', 'Oddish', 3), ('Houndour', 'Trapinch', 3), ('Houndour', 'Elekid', 3), ('Houndour', 'Anorith', 3), ('Trapinch', 'Elekid', 3), ('Trapinch', 'Anorith', 3), ('Elekid', 'Anorith', 3), ('Abra', 'Larvitar', 3), ('Abra', 'Meowth', 3), ('Abra', 'Koffing', 3), ('Larvitar', 'Meowth', 3), ('Larvitar', 'Koffing', 3), ('Meowth', 'Koffing', 3), ('Pidgeot', 'Hitmonchan', 2), ('Pidgeot', 'Magcargo', 2), ('Pidgeot', 'Roselia', 2), ('Pidgeot', 'Chimecho', 2), ('Pidgeot', 'Seaking', 2), ('Hitmonchan', 'Magcargo', 2), ('Hitmonchan', 'Roselia', 4), ('Hitmonchan', 'Chimecho', 4), ('Hitmonchan', 'Seaking', 2), ('Hitmonchan', 'Flareon', 6), ('Hitmonchan', 'Mawile', 2), ('Hitmonchan', 'Sableye', 4), ('Hitmonchan', 'Pelipper', 2), ('Hitmonchan', 'Seadra', 2), ('Hitmonchan', 'Murkrow', 2), ('Hitmonchan', 'Dewgong', 6), ('Hitmonchan', 'Vigoroth', 2), ('Hitmonchan', 'Lileep', 2), ('Hitmonchan', 'Haunter', 2), ('Hitmonchan', 'Metang', 2), ('Hitmonchan', 'Kecleon', 2), ('Hitmonchan', 'Octillery', 2), ('Hitmonchan', 'Pupitar', 2), ('Hitmonchan', 'Torkoal', 2), ('Hitmonchan', 'Piloswine', 2), ('Hitmonchan', 'Arbok', 2), ('Hitmonchan', 'Raticate', 2), ('Magcargo', 'Roselia', 2), ('Magcargo', 'Chimecho', 2), ('Magcargo', 'Seaking', 2), ('Roselia', 'Chimecho', 2), ('Roselia', 'Seaking', 2), ('Roselia', 'Flareon', 2), ('Roselia', 'Mawile', 2), ('Roselia', 'Sableye', 2), ('Roselia', 'Pelipper', 2), ('Chimecho', 'Seaking', 2), ('Chimecho', 'Flareon', 2), ('Chimecho', 'Lileep', 2), ('Chimecho', 'Sableye', 2), ('Chimecho', 'Dewgong', 2), ('Flareon', 'Mawile', 2), ('Flareon', 'Sableye', 4), ('Flareon', 'Pelipper', 2), ('Flareon', 'Seadra', 2), ('Flareon', 'Murkrow', 2), ('Flareon', 'Dewgong', 4), ('Flareon', 'Vigoroth', 2), ('Flareon', 'Lileep', 2), ('Mawile', 'Sableye', 2), ('Mawile', 'Pelipper', 2), ('Mawile', 'Vigoroth', 2), ('Mawile', 'Torkoal', 2), ('Mawile', 'Golbat', 2), ('Mawile', 'Kingler', 2), ('Mawile', 'Cacturne', 2), ('Sableye', 'Pelipper', 2), ('Sableye', 'Lileep', 2), ('Sableye', 'Dewgong', 2), ('Seadra', ' ...

# %% [markdown]
# # PU

# %%
t28= []
 
t28.append('Lairon')
t28.append('Mightyena')
t28.append('Duskull')
t28.append('Tentacool')
t28.append('Minun')
t28.append('Furret')
 
teams.append(t28)
 
t29= []
 
t29.append('Furret')
t29.append('Minun')
t29.append('Grovyle')
t29.append('Sealeo')
t29.append('Gastly')
t29.append('Yanma')
 
teams.append(t29)
 
t30= []
 
t30.append('Furret')
t30.append('Minun')
t30.append('Sealeo')
t30.append('Lairon')
t30.append('Charmeleon')
t30.append('Dragonair')
 
teams.append(t30)
 
t31= []
 
t31.append('Omanyte')
t31.append('Wigglytuff')
t31.append('Shuckle')
t31.append('Wartortle')
t31.append('Mightyena')
t31.append('Shedinja')
 
teams.append(t31)
 
t32= []
 
t32.append('Furret')
t32.append('Omanyte')
t32.append('Houndour')
t32.append('Ivysaur')
t32.append('Minun')
t32.append('Dragonair')
 
teams.append(t32)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Blaziken', 'Jolteon', 5), ('Blaziken', 'Zapdos', 5), ('Jolteon', 'Zapdos', 5), ('Jolteon', 'Skarmory', 2), ('Jolteon', 'Tyranitar', 2), ('Jolteon', 'Gengar', 2), ('Jolteon', 'Metagross', 2), ('Jolteon', 'Starmie', 2), ('Zapdos', 'Registeel', 5), ('Zapdos', 'Marowak', 5), ('Zapdos', 'Salamence', 2), ('Zapdos', 'Swampert', 4), ('Zapdos', 'Tyranitar', 4), ('Zapdos', 'Metagross', 2), ('Zapdos', 'Snorlax', 2), ('Zapdos', 'Skarmory', 2), ('Zapdos', 'Celebi', 2), ('Zapdos', 'Dugtrio', 2), ('Starmie', 'Aerodactyl', 5), ('Starmie', 'Entei', 5), ('Starmie', 'Skarmory', 4), ('Starmie', 'Tyranitar', 4), ('Starmie', 'Gengar', 4), ('Starmie', 'Metagross', 2), ('Starmie', 'Blissey', 2), ('Starmie', 'Swampert', 2), ('Aerodactyl', 'Entei', 5), ('Aerodactyl', 'Tyranitar', 4), ('Aerodactyl', 'Celebi', 4), ('Aerodactyl', 'Magneton', 4), ('Aerodactyl', 'Swampert', 4), ('Aerodactyl', 'Metagross', 2), ('Aerodactyl', 'Skarmory', 2), ('Registeel', 'Marowak', 5), ('Marowak', 'Sceptile', 5), ('Marowak', 'Raikou', 5), ('Sceptile', 'Raikou', 5), ('Raikou', 'Suicune', 2), ('Raikou', 'Dugtrio', 2), ('Raikou', 'Jirachi', 2), ('Raikou', 'Celebi', 2), ('Raikou', 'Porygon2', 2), ('Voltorb', 'Diglett', 4), ('Voltorb', 'Doduo', 4), ('Voltorb', 'Shellder', 4), ('Voltorb', 'Exeggcute', 4), ('Voltorb', 'Oddish', 4), ('Diglett', 'Doduo', 8), ('Diglett', 'Shellder', 4), ('Diglett', 'Exeggcute', 4), ('Diglett', 'Oddish', 4), ('Diglett', 'Abra', 4), ('Diglett', 'Larvitar', 4), ('Diglett', 'Meowth', 4), ('Diglett', 'Koffing', 4), ('Doduo', 'Shellder', 8), ('Doduo', 'Exeggcute', 4), ('Doduo', 'Oddish', 4), ('Doduo', 'Houndour', 4), ('Doduo', 'Trapinch', 4), ('Doduo', 'Elekid', 4), ('Doduo', 'Anorith', 4), ('Doduo', 'Abra', 4), ('Doduo', 'Larvitar', 4), ('Doduo', 'Meowth', 4), ('Doduo', 'Koffing', 4), ('Shellder', 'Exeggcute', 4), ('Shellder', 'Oddish', 4), ('Shellder', 'Houndour', 4), ('Shellder', 'Trapinch', 4), ('Shellder', 'Elekid', 4), ('Shellder', 'Anorith', 4), ('Exeggcute', 'Oddish', 4), ('Houndour', 'Trapinch', 4), ('Houndour', 'Elekid', 4), ('Houndour', 'Anorith', 4), ('Houndour', 'Furret', 1), ('Houndour', 'Omanyte', 1), ('Houndour', 'Ivysaur', 1), ('Houndour', 'Minun', 1), ('Houndour', 'Dragonair', 1), ('Trapinch', 'Elekid', 4), ('Trapinch', 'Anorith', 4), ('Elekid', 'Anorith', 4), ('Abra', 'Larvitar', 4), ('Abra', 'Meowth', 4), ('Abra', 'Koffing', 4), ('Larvitar', 'Meowth', 4), ('Larvitar', 'Koffing', 4), ('Meowth', 'Koffing', 4), ('Pidgeot', 'Hitmonchan', 3), ('Pidgeot', 'Magcargo', 3), ('Pidgeot', 'Roselia', 3), ('Pidgeot', 'Chimecho', 3), ('Pidgeot', 'Seaking', 3), ('Hitmonchan', 'Magcargo', 3), ('Hitmonchan', 'Roselia', 6), ('Hitmonchan', 'Chimecho', 6), ('Hitmonchan', 'Seaking', 3), ('Hitmonchan', 'Flareon', 9), ('Hitmonchan', 'Mawile', 3), ('Hitmonchan', 'Sableye', 6), ('Hitmonchan', 'Pelipper', 3), ('Hitmonchan', 'Seadra', 3), ('Hitmonchan', 'Murkrow', 3), ('Hitmonchan', 'Dewgong', 9), ('Hitmonchan', 'Vigoroth', 3), ('Hitmonchan', 'Lileep', 3), ('Hitmonchan', 'Haunter', 3), ('Hitmonchan', 'Metang', 3), ('Hitmonchan', 'Kecleon', 3), ('Hitmonchan', 'Octillery', 3), ('Hitmonchan', 'Pupitar', 3), ('Hitmonchan', 'Torkoal', 3), ('Hitmonchan', 'Piloswine', 3), ('Hitmonchan', 'Arbok', 3), ('Hitmonchan', 'Raticate', 3), ('Magcargo', 'Roselia', 3), ('Magcargo', 'Chimecho', 3), ('Magcargo', 'Seaking', 3), ('Roselia', 'Chimecho', 3), ('Roselia', 'Seaking', 3), ('Roselia', 'Flareon', 3), ('Roselia', 'Mawile', 3), ('Roselia', 'Sableye', 3), ('Roselia', 'Pelipper', 3), ('Chimecho', 'Seaking', 3), ('Chimecho', 'Flareon', 3), ('Chimecho', 'Lileep', 3), ('Chimecho', 'Sableye', 3), ('Chimecho', 'Dewgong', 3), ('Flareon', 'Mawile', 3), ('Flareon', 'Sableye', 6), ('Flareon', 'Pelipper', 3), ('Flareon', 'Seadra', 3), ('Flareon', 'Murkrow', 3), ('Flareon', 'Dewgong', 6), ('Flareon', 'Vigoroth', 3), ('Flareon', 'Lileep', 3), ('Mawile', 'Sableye', 3), ('Mawile', 'Pelipper', 3), ('Mawile', 'Vigoroth', 3), ('Mawile', 'Torkoal', 3), ('Mawile', 'Golbat', 3), ('Mawil ...

# %% [markdown]
# # UBERS

# %%
t33= []
 
t33.append('Groudon')
t33.append('Lugia')
t33.append('Latias')
t33.append('Blissey')
t33.append('Magneton')
t33.append('Forretress')
 
teams.append(t33)
 
t34= []
 
t34.append('Latios')
t34.append('Kyogre')
t34.append('Omastar')
t34.append('Regice')
t34.append('Steelix')
t34.append('Deoxys')
 
teams.append(t34)
 
t35= []
 
t35.append('Groudon')
t35.append('Latias')
t35.append('Ho-oh')
t35.append('Blissey')
t35.append('Forretress')
t35.append('Regirock')
 
teams.append(t35)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Blaziken', 'Jolteon', 6), ('Blaziken', 'Zapdos', 6), ('Jolteon', 'Zapdos', 6), ('Jolteon', 'Skarmory', 3), ('Jolteon', 'Tyranitar', 3), ('Jolteon', 'Gengar', 3), ('Jolteon', 'Metagross', 3), ('Jolteon', 'Starmie', 3), ('Zapdos', 'Registeel', 6), ('Zapdos', 'Marowak', 6), ('Zapdos', 'Salamence', 3), ('Zapdos', 'Swampert', 6), ('Zapdos', 'Tyranitar', 6), ('Zapdos', 'Metagross', 3), ('Zapdos', 'Snorlax', 3), ('Zapdos', 'Skarmory', 3), ('Zapdos', 'Celebi', 3), ('Zapdos', 'Dugtrio', 3), ('Starmie', 'Aerodactyl', 6), ('Starmie', 'Entei', 6), ('Starmie', 'Skarmory', 6), ('Starmie', 'Tyranitar', 6), ('Starmie', 'Gengar', 6), ('Starmie', 'Metagross', 3), ('Starmie', 'Blissey', 3), ('Starmie', 'Swampert', 3), ('Aerodactyl', 'Entei', 6), ('Aerodactyl', 'Tyranitar', 6), ('Aerodactyl', 'Celebi', 6), ('Aerodactyl', 'Magneton', 6), ('Aerodactyl', 'Swampert', 6), ('Aerodactyl', 'Metagross', 3), ('Aerodactyl', 'Skarmory', 3), ('Registeel', 'Marowak', 6), ('Marowak', 'Sceptile', 6), ('Marowak', 'Raikou', 6), ('Sceptile', 'Raikou', 6), ('Raikou', 'Suicune', 3), ('Raikou', 'Dugtrio', 3), ('Raikou', 'Jirachi', 3), ('Raikou', 'Celebi', 3), ('Raikou', 'Porygon2', 3), ('Voltorb', 'Diglett', 5), ('Voltorb', 'Doduo', 5), ('Voltorb', 'Shellder', 5), ('Voltorb', 'Exeggcute', 5), ('Voltorb', 'Oddish', 5), ('Diglett', 'Doduo', 10), ('Diglett', 'Shellder', 5), ('Diglett', 'Exeggcute', 5), ('Diglett', 'Oddish', 5), ('Diglett', 'Abra', 5), ('Diglett', 'Larvitar', 5), ('Diglett', 'Meowth', 5), ('Diglett', 'Koffing', 5), ('Doduo', 'Shellder', 10), ('Doduo', 'Exeggcute', 5), ('Doduo', 'Oddish', 5), ('Doduo', 'Houndour', 5), ('Doduo', 'Trapinch', 5), ('Doduo', 'Elekid', 5), ('Doduo', 'Anorith', 5), ('Doduo', 'Abra', 5), ('Doduo', 'Larvitar', 5), ('Doduo', 'Meowth', 5), ('Doduo', 'Koffing', 5), ('Shellder', 'Exeggcute', 5), ('Shellder', 'Oddish', 5), ('Shellder', 'Houndour', 5), ('Shellder', 'Trapinch', 5), ('Shellder', 'Elekid', 5), ('Shellder', 'Anorith', 5), ('Exeggcute', 'Oddish', 5), ('Houndour', 'Trapinch', 5), ('Houndour', 'Elekid', 5), ('Houndour', 'Anorith', 5), ('Houndour', 'Furret', 2), ('Houndour', 'Omanyte', 2), ('Houndour', 'Ivysaur', 2), ('Houndour', 'Minun', 2), ('Houndour', 'Dragonair', 2), ('Trapinch', 'Elekid', 5), ('Trapinch', 'Anorith', 5), ('Elekid', 'Anorith', 5), ('Abra', 'Larvitar', 5), ('Abra', 'Meowth', 5), ('Abra', 'Koffing', 5), ('Larvitar', 'Meowth', 5), ('Larvitar', 'Koffing', 5), ('Meowth', 'Koffing', 5), ('Pidgeot', 'Hitmonchan', 4), ('Pidgeot', 'Magcargo', 4), ('Pidgeot', 'Roselia', 4), ('Pidgeot', 'Chimecho', 4), ('Pidgeot', 'Seaking', 4), ('Hitmonchan', 'Magcargo', 4), ('Hitmonchan', 'Roselia', 8), ('Hitmonchan', 'Chimecho', 8), ('Hitmonchan', 'Seaking', 4), ('Hitmonchan', 'Flareon', 12), ('Hitmonchan', 'Mawile', 4), ('Hitmonchan', 'Sableye', 8), ('Hitmonchan', 'Pelipper', 4), ('Hitmonchan', 'Seadra', 4), ('Hitmonchan', 'Murkrow', 4), ('Hitmonchan', 'Dewgong', 12), ('Hitmonchan', 'Vigoroth', 4), ('Hitmonchan', 'Lileep', 4), ('Hitmonchan', 'Haunter', 4), ('Hitmonchan', 'Metang', 4), ('Hitmonchan', 'Kecleon', 4), ('Hitmonchan', 'Octillery', 4), ('Hitmonchan', 'Pupitar', 4), ('Hitmonchan', 'Torkoal', 4), ('Hitmonchan', 'Piloswine', 4), ('Hitmonchan', 'Arbok', 4), ('Hitmonchan', 'Raticate', 4), ('Magcargo', 'Roselia', 4), ('Magcargo', 'Chimecho', 4), ('Magcargo', 'Seaking', 4), ('Roselia', 'Chimecho', 4), ('Roselia', 'Seaking', 4), ('Roselia', 'Flareon', 4), ('Roselia', 'Mawile', 4), ('Roselia', 'Sableye', 4), ('Roselia', 'Pelipper', 4), ('Chimecho', 'Seaking', 4), ('Chimecho', 'Flareon', 4), ('Chimecho', 'Lileep', 4), ('Chimecho', 'Sableye', 4), ('Chimecho', 'Dewgong', 4), ('Flareon', 'Mawile', 4), ('Flareon', 'Sableye', 8), ('Flareon', 'Pelipper', 4), ('Flareon', 'Seadra', 4), ('Flareon', 'Murkrow', 4), ('Flareon', 'Dewgong', 8), ('Flareon', 'Vigoroth', 4), ('Flareon', 'Lileep', 4), ('Mawile', 'Sableye', 4), ('Mawile', 'Pelipper', 4), ('Mawile', 'Vigoroth', 4), ('Mawile', 'Torkoal', 4), ('Mawile', 'Golbat', 4), ('M ...

# %% [markdown]
# # UU

# %%
t36= []
 
t36.append('Nidoking')
t36.append('Sharpedo')
t36.append('Kangaskhan')
t36.append('Scyther')
t36.append('Hypno')
t36.append('Omastar')
 
teams.append(t36)
 
t37= []
 
t37.append('Ninetales')
t37.append('Tentacruel')
t37.append('Lunatone')
t37.append('Shiftry')
t37.append('Kangaskhan')
t37.append('Quagsire')
 
teams.append(t37)
 
t38= []
 
t38.append('Nidoking')
t38.append('Omastar')
t38.append('Gorebyss')
t38.append('Scyther')
t38.append('Kangaskhan')
t38.append('Cradily')
 
teams.append(t38)
 
t39= []
 
t39.append('Kangaskhan')
t39.append('Muk')
t39.append('Hypno')
t39.append('Pinsir')
t39.append('Lunatone')
t39.append('Scyther')
 
teams.append(t39)
 
t40= []
 
t40.append('Omastar')
t40.append('Hypno')
t40.append('Gligar')
t40.append('Tentacruel')
t40.append('Kangaskhan')
t40.append('Sharpedo')
 
teams.append(t40)
 
t41= []
 
t41.append('Scyther')
t41.append('Electrode')
t41.append('Kabutops')
t41.append('Nidoking')
t41.append('Kangaskhan')
t41.append('Misdreavus')
 
teams.append(t41)
 
t42= []
 
t42.append('Walrein')
t42.append('Kangaskhan')
t42.append('Nidoqueen')
t42.append('Scyther')
t42.append('Hypno')
t42.append('Omastar')
 
teams.append(t42)
 
t43= []
 
t43.append('Walrein')
t43.append('Kangaskhan')
t43.append('Manectric')
t43.append('Hypno')
t43.append('Cradily')
t43.append('Scyther')
 
teams.append(t43)
 
t44= []
 
t44.append('Omastar')
t44.append('Lunatone')
t44.append('Muk')
t44.append('Kangaskhan')
t44.append('Walrein')
t44.append('Vileplume')
 
teams.append(t44)
 
t45= []
 
t45.append('Granbull')
t45.append('Kangaskhan')
t45.append('Gligar')
t45.append('Tentacruel')
t45.append('Ninetales')
t45.append('Golduck')
 
teams.append(t45)
 
t46= []
 
t46.append('Walrein')
t46.append('Kangaskhan')
t46.append('Granbull')
t46.append('Magmar')
t46.append('Lunatone')
t46.append('Muk')
 
teams.append(t46)
 
t47= []
 
t47.append('Kangaskhan')
t47.append('Slowking')
t47.append('Clefable')
t47.append('Tentacruel')
t47.append('Vileplume')
t47.append('Lunatone')
 
teams.append(t47)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Blaziken', 'Jolteon', 7), ('Blaziken', 'Zapdos', 7), ('Jolteon', 'Zapdos', 7), ('Jolteon', 'Skarmory', 4), ('Jolteon', 'Tyranitar', 4), ('Jolteon', 'Gengar', 4), ('Jolteon', 'Metagross', 4), ('Jolteon', 'Starmie', 4), ('Zapdos', 'Registeel', 7), ('Zapdos', 'Marowak', 7), ('Zapdos', 'Salamence', 4), ('Zapdos', 'Swampert', 8), ('Zapdos', 'Tyranitar', 8), ('Zapdos', 'Metagross', 4), ('Zapdos', 'Snorlax', 4), ('Zapdos', 'Skarmory', 4), ('Zapdos', 'Celebi', 4), ('Zapdos', 'Dugtrio', 4), ('Starmie', 'Aerodactyl', 7), ('Starmie', 'Entei', 7), ('Starmie', 'Skarmory', 8), ('Starmie', 'Tyranitar', 8), ('Starmie', 'Gengar', 8), ('Starmie', 'Metagross', 4), ('Starmie', 'Blissey', 4), ('Starmie', 'Swampert', 4), ('Aerodactyl', 'Entei', 7), ('Aerodactyl', 'Tyranitar', 8), ('Aerodactyl', 'Celebi', 8), ('Aerodactyl', 'Magneton', 8), ('Aerodactyl', 'Swampert', 8), ('Aerodactyl', 'Metagross', 4), ('Aerodactyl', 'Skarmory', 4), ('Registeel', 'Marowak', 7), ('Marowak', 'Sceptile', 7), ('Marowak', 'Raikou', 7), ('Sceptile', 'Raikou', 7), ('Raikou', 'Suicune', 4), ('Raikou', 'Dugtrio', 4), ('Raikou', 'Jirachi', 4), ('Raikou', 'Celebi', 4), ('Raikou', 'Porygon2', 4), ('Voltorb', 'Diglett', 6), ('Voltorb', 'Doduo', 6), ('Voltorb', 'Shellder', 6), ('Voltorb', 'Exeggcute', 6), ('Voltorb', 'Oddish', 6), ('Diglett', 'Doduo', 12), ('Diglett', 'Shellder', 6), ('Diglett', 'Exeggcute', 6), ('Diglett', 'Oddish', 6), ('Diglett', 'Abra', 6), ('Diglett', 'Larvitar', 6), ('Diglett', 'Meowth', 6), ('Diglett', 'Koffing', 6), ('Doduo', 'Shellder', 12), ('Doduo', 'Exeggcute', 6), ('Doduo', 'Oddish', 6), ('Doduo', 'Houndour', 6), ('Doduo', 'Trapinch', 6), ('Doduo', 'Elekid', 6), ('Doduo', 'Anorith', 6), ('Doduo', 'Abra', 6), ('Doduo', 'Larvitar', 6), ('Doduo', 'Meowth', 6), ('Doduo', 'Koffing', 6), ('Shellder', 'Exeggcute', 6), ('Shellder', 'Oddish', 6), ('Shellder', 'Houndour', 6), ('Shellder', 'Trapinch', 6), ('Shellder', 'Elekid', 6), ('Shellder', 'Anorith', 6), ('Exeggcute', 'Oddish', 6), ('Houndour', 'Trapinch', 6), ('Houndour', 'Elekid', 6), ('Houndour', 'Anorith', 6), ('Houndour', 'Furret', 3), ('Houndour', 'Omanyte', 3), ('Houndour', 'Ivysaur', 3), ('Houndour', 'Minun', 3), ('Houndour', 'Dragonair', 3), ('Trapinch', 'Elekid', 6), ('Trapinch', 'Anorith', 6), ('Elekid', 'Anorith', 6), ('Abra', 'Larvitar', 6), ('Abra', 'Meowth', 6), ('Abra', 'Koffing', 6), ('Larvitar', 'Meowth', 6), ('Larvitar', 'Koffing', 6), ('Meowth', 'Koffing', 6), ('Pidgeot', 'Hitmonchan', 5), ('Pidgeot', 'Magcargo', 5), ('Pidgeot', 'Roselia', 5), ('Pidgeot', 'Chimecho', 5), ('Pidgeot', 'Seaking', 5), ('Hitmonchan', 'Magcargo', 5), ('Hitmonchan', 'Roselia', 10), ('Hitmonchan', 'Chimecho', 10), ('Hitmonchan', 'Seaking', 5), ('Hitmonchan', 'Flareon', 15), ('Hitmonchan', 'Mawile', 5), ('Hitmonchan', 'Sableye', 10), ('Hitmonchan', 'Pelipper', 5), ('Hitmonchan', 'Seadra', 5), ('Hitmonchan', 'Murkrow', 5), ('Hitmonchan', 'Dewgong', 15), ('Hitmonchan', 'Vigoroth', 5), ('Hitmonchan', 'Lileep', 5), ('Hitmonchan', 'Haunter', 5), ('Hitmonchan', 'Metang', 5), ('Hitmonchan', 'Kecleon', 5), ('Hitmonchan', 'Octillery', 5), ('Hitmonchan', 'Pupitar', 5), ('Hitmonchan', 'Torkoal', 5), ('Hitmonchan', 'Piloswine', 5), ('Hitmonchan', 'Arbok', 5), ('Hitmonchan', 'Raticate', 5), ('Magcargo', 'Roselia', 5), ('Magcargo', 'Chimecho', 5), ('Magcargo', 'Seaking', 5), ('Roselia', 'Chimecho', 5), ('Roselia', 'Seaking', 5), ('Roselia', 'Flareon', 5), ('Roselia', 'Mawile', 5), ('Roselia', 'Sableye', 5), ('Roselia', 'Pelipper', 5), ('Chimecho', 'Seaking', 5), ('Chimecho', 'Flareon', 5), ('Chimecho', 'Lileep', 5), ('Chimecho', 'Sableye', 5), ('Chimecho', 'Dewgong', 5), ('Flareon', 'Mawile', 5), ('Flareon', 'Sableye', 10), ('Flareon', 'Pelipper', 5), ('Flareon', 'Seadra', 5), ('Flareon', 'Murkrow', 5), ('Flareon', 'Dewgong', 10), ('Flareon', 'Vigoroth', 5), ('Flareon', 'Lileep', 5), ('Mawile', 'Sableye', 5), ('Mawile', 'Pelipper', 5), ('Mawile', 'Vigoroth', 5), ('Mawile', 'Torkoal', 5), ('Mawile', 'Golbat', 5) ...

# %% [markdown]
# # ZU

# %%
t48= []
 
t48.append('Snorunt')
t48.append('Elekid')
t48.append('Gloom')
t48.append('Seaking')
t48.append('Growlithe')
t48.append('Nosepass')
 
teams.append(t48)
 
t49= []
 
t49.append('Voltorb')
t49.append('Cubone')
t49.append('Delcatty')
t49.append('Rhyhorn')
t49.append('Delibird')
t49.append('Gloom')
 
teams.append(t49)
 
t50= []
 
t50.append('Voltorb')
t50.append('Seaking')
t50.append('Horsea')
t50.append('Grimer')
t50.append('Taillow')
t50.append('Cubone')
 
teams.append(t50)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Blaziken', 'Jolteon', 8), ('Blaziken', 'Zapdos', 8), ('Jolteon', 'Zapdos', 8), ('Jolteon', 'Skarmory', 5), ('Jolteon', 'Tyranitar', 5), ('Jolteon', 'Gengar', 5), ('Jolteon', 'Metagross', 5), ('Jolteon', 'Starmie', 5), ('Zapdos', 'Registeel', 8), ('Zapdos', 'Marowak', 8), ('Zapdos', 'Salamence', 5), ('Zapdos', 'Swampert', 10), ('Zapdos', 'Tyranitar', 10), ('Zapdos', 'Metagross', 5), ('Zapdos', 'Snorlax', 5), ('Zapdos', 'Skarmory', 5), ('Zapdos', 'Celebi', 5), ('Zapdos', 'Dugtrio', 5), ('Starmie', 'Aerodactyl', 8), ('Starmie', 'Entei', 8), ('Starmie', 'Skarmory', 10), ('Starmie', 'Tyranitar', 10), ('Starmie', 'Gengar', 10), ('Starmie', 'Metagross', 5), ('Starmie', 'Blissey', 5), ('Starmie', 'Swampert', 5), ('Aerodactyl', 'Entei', 8), ('Aerodactyl', 'Tyranitar', 10), ('Aerodactyl', 'Celebi', 10), ('Aerodactyl', 'Magneton', 10), ('Aerodactyl', 'Swampert', 10), ('Aerodactyl', 'Metagross', 5), ('Aerodactyl', 'Skarmory', 5), ('Registeel', 'Marowak', 8), ('Marowak', 'Sceptile', 8), ('Marowak', 'Raikou', 8), ('Sceptile', 'Raikou', 8), ('Raikou', 'Suicune', 5), ('Raikou', 'Dugtrio', 5), ('Raikou', 'Jirachi', 5), ('Raikou', 'Celebi', 5), ('Raikou', 'Porygon2', 5), ('Voltorb', 'Diglett', 7), ('Voltorb', 'Doduo', 7), ('Voltorb', 'Shellder', 7), ('Voltorb', 'Exeggcute', 7), ('Voltorb', 'Oddish', 7), ('Voltorb', 'Cubone', 2), ('Voltorb', 'Delcatty', 1), ('Voltorb', 'Rhyhorn', 1), ('Voltorb', 'Delibird', 1), ('Voltorb', 'Gloom', 1), ('Voltorb', 'Seaking', 1), ('Voltorb', 'Horsea', 1), ('Voltorb', 'Grimer', 1), ('Voltorb', 'Taillow', 1), ('Diglett', 'Doduo', 14), ('Diglett', 'Shellder', 7), ('Diglett', 'Exeggcute', 7), ('Diglett', 'Oddish', 7), ('Diglett', 'Abra', 7), ('Diglett', 'Larvitar', 7), ('Diglett', 'Meowth', 7), ('Diglett', 'Koffing', 7), ('Doduo', 'Shellder', 14), ('Doduo', 'Exeggcute', 7), ('Doduo', 'Oddish', 7), ('Doduo', 'Houndour', 7), ('Doduo', 'Trapinch', 7), ('Doduo', 'Elekid', 7), ('Doduo', 'Anorith', 7), ('Doduo', 'Abra', 7), ('Doduo', 'Larvitar', 7), ('Doduo', 'Meowth', 7), ('Doduo', 'Koffing', 7), ('Shellder', 'Exeggcute', 7), ('Shellder', 'Oddish', 7), ('Shellder', 'Houndour', 7), ('Shellder', 'Trapinch', 7), ('Shellder', 'Elekid', 7), ('Shellder', 'Anorith', 7), ('Exeggcute', 'Oddish', 7), ('Houndour', 'Trapinch', 7), ('Houndour', 'Elekid', 7), ('Houndour', 'Anorith', 7), ('Houndour', 'Furret', 4), ('Houndour', 'Omanyte', 4), ('Houndour', 'Ivysaur', 4), ('Houndour', 'Minun', 4), ('Houndour', 'Dragonair', 4), ('Trapinch', 'Elekid', 7), ('Trapinch', 'Anorith', 7), ('Elekid', 'Anorith', 7), ('Elekid', 'Snorunt', 1), ('Elekid', 'Gloom', 1), ('Elekid', 'Seaking', 1), ('Elekid', 'Growlithe', 1), ('Elekid', 'Nosepass', 1), ('Abra', 'Larvitar', 7), ('Abra', 'Meowth', 7), ('Abra', 'Koffing', 7), ('Larvitar', 'Meowth', 7), ('Larvitar', 'Koffing', 7), ('Meowth', 'Koffing', 7), ('Pidgeot', 'Hitmonchan', 6), ('Pidgeot', 'Magcargo', 6), ('Pidgeot', 'Roselia', 6), ('Pidgeot', 'Chimecho', 6), ('Pidgeot', 'Seaking', 6), ('Hitmonchan', 'Magcargo', 6), ('Hitmonchan', 'Roselia', 12), ('Hitmonchan', 'Chimecho', 12), ('Hitmonchan', 'Seaking', 6), ('Hitmonchan', 'Flareon', 18), ('Hitmonchan', 'Mawile', 6), ('Hitmonchan', 'Sableye', 12), ('Hitmonchan', 'Pelipper', 6), ('Hitmonchan', 'Seadra', 6), ('Hitmonchan', 'Murkrow', 6), ('Hitmonchan', 'Dewgong', 18), ('Hitmonchan', 'Vigoroth', 6), ('Hitmonchan', 'Lileep', 6), ('Hitmonchan', 'Haunter', 6), ('Hitmonchan', 'Metang', 6), ('Hitmonchan', 'Kecleon', 6), ('Hitmonchan', 'Octillery', 6), ('Hitmonchan', 'Pupitar', 6), ('Hitmonchan', 'Torkoal', 6), ('Hitmonchan', 'Piloswine', 6), ('Hitmonchan', 'Arbok', 6), ('Hitmonchan', 'Raticate', 6), ('Magcargo', 'Roselia', 6), ('Magcargo', 'Chimecho', 6), ('Magcargo', 'Seaking', 6), ('Roselia', 'Chimecho', 6), ('Roselia', 'Seaking', 6), ('Roselia', 'Flareon', 6), ('Roselia', 'Mawile', 6), ('Roselia', 'Sableye', 6), ('Roselia', 'Pelipper', 6), ('Chimecho', 'Seaking', 6), ('Chimecho', 'Flareon', 6), ('Chimecho', 'Lileep', 6), ('Chimecho', 'Sableye' ...

# %%
for pok in G.nodes :
    G.nodes[pok]['teams'] = apariciones[pok]

# %%
nx.write_gexf(G, "Gen3Graph.gexf", version="1.2draft")
