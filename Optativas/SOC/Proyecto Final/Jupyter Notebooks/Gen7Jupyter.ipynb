# %%
import networkx as nx
import itertools as it
# Importo Beautiful Soup
from bs4 import BeautifulSoup
# Importo requests para pillar el código html de donde quiera
import requests

# %%
# Cogemos la Pokédex
webDex = requests.get('https://pokemondb.net/pokedex/national')
dexSoup  = BeautifulSoup(webDex.content, 'html.parser')

apariciones = {}
pokedex = {}
G = nx.Graph()
teams = []
types = [['itype', 'grass'], ['itype', 'poison'], ['itype', 'fire'], ['itype', 'flying'], ['itype', 'water'], 
         ['itype', 'bug'], ['itype', 'normal'], ['itype', 'electric'], ['itype', 'ground'], ['itype', 'fairy'], 
         ['itype', 'fighting'], ['itype', 'psychic'], ['itype', 'rock'], ['itype', 'steel'], 
         ['itype', 'ice'], ['itype', 'ghost'], ['itype', 'dark'], ['itype', 'dragon']]


for name in dexSoup.find_all('a'):
    if name.get('class') == ['ent-name']:
        pok = name.get_text()
        pokedex[pok] = {'type1' : 'None', 'type2' : 'None'}
    if name.get('class') in types:
        if pokedex[pok]['type1'] == 'None':
            pokedex[pok]['type1'] = name.get_text()
        else:
            pokedex[pok]['type2'] = name.get_text()

# %% [markdown]
# # 1vs1

# %%
t1= []
 
t1.append('Tapu Lele')
t1.append('Charizard')
t1.append('Pheromosa')
 
teams.append(t1)
 
t2= []
 
t2.append('Gyarados')
t2.append('Magearna')
t2.append('Charizard')
 
teams.append(t2)
 
t3= []
 
t3.append('Type: Null')
t3.append('Tyranitar')
t3.append('Mawile')
 
teams.append(t3)
 
t4= []
 
t4.append('Gyarados')
t4.append('Genesect')
t4.append('Zeraora')
 
teams.append(t4)
 
t5= []
 
t5.append('Altaria')
t5.append('Aegislash')
t5.append('Zeraora')
 
teams.append(t5)
 
t6= []
 
t6.append('Gyarados')
t6.append('Charizard')
t6.append('Magnezone')
 
teams.append(t6)
 
t7= []
 
t7.append('Dragonite')
t7.append('Charizard')
t7.append('Tapu Fini')
 
teams.append(t7)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Tapu Lele', 'Charizard', 1), ('Tapu Lele', 'Pheromosa', 1), ('Charizard', 'Pheromosa', 1), ('Charizard', 'Gyarados', 2), ('Charizard', 'Magearna', 1), ('Charizard', 'Magnezone', 1), ('Charizard', 'Dragonite', 1), ('Charizard', 'Tapu Fini', 1), ('Gyarados', 'Magearna', 1), ('Gyarados', 'Genesect', 1), ('Gyarados', 'Zeraora', 1), ('Gyarados', 'Magnezone', 1), ('Type: Null', 'Tyranitar', 1), ('Type: Null', 'Mawile', 1), ('Tyranitar', 'Mawile', 1), ('Genesect', 'Zeraora', 1), ('Zeraora', 'Altaria', 1), ('Zeraora', 'Aegislash', 1), ('Altaria', 'Aegislash', 1), ('Dragonite', 'Tapu Fini', 1)])

# %% [markdown]
# # LC

# %%
t7= []
 
t7.append('Surskit')
t7.append('Bunnelby')
t7.append('Pawniard')
t7.append('Gastly')
t7.append('Magnemite')
t7.append('Abra')
 
teams.append(t7)
 
t8= []
 
t8.append('Timburr')
t8.append('Onix')
t8.append('Vullaby')
t8.append('Pawniard')
t8.append('Mareanie')
t8.append('Abra')
 
teams.append(t8)
 
t9= []
 
t9.append('Mienfoo')
t9.append('Diglett')
t9.append('Vullaby')
t9.append('Clamperl')
t9.append('Foongus')
t9.append('Onix')
 
teams.append(t9)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Tapu Lele', 'Charizard', 2), ('Tapu Lele', 'Pheromosa', 2), ('Charizard', 'Pheromosa', 2), ('Charizard', 'Gyarados', 4), ('Charizard', 'Magearna', 2), ('Charizard', 'Magnezone', 2), ('Charizard', 'Dragonite', 2), ('Charizard', 'Tapu Fini', 2), ('Gyarados', 'Magearna', 2), ('Gyarados', 'Genesect', 2), ('Gyarados', 'Zeraora', 2), ('Gyarados', 'Magnezone', 2), ('Type: Null', 'Tyranitar', 2), ('Type: Null', 'Mawile', 2), ('Tyranitar', 'Mawile', 2), ('Genesect', 'Zeraora', 2), ('Zeraora', 'Altaria', 2), ('Zeraora', 'Aegislash', 2), ('Altaria', 'Aegislash', 2), ('Dragonite', 'Tapu Fini', 2), ('Surskit', 'Bunnelby', 1), ('Surskit', 'Pawniard', 1), ('Surskit', 'Gastly', 1), ('Surskit', 'Magnemite', 1), ('Surskit', 'Abra', 1), ('Bunnelby', 'Pawniard', 1), ('Bunnelby', 'Gastly', 1), ('Bunnelby', 'Magnemite', 1), ('Bunnelby', 'Abra', 1), ('Pawniard', 'Gastly', 1), ('Pawniard', 'Magnemite', 1), ('Pawniard', 'Abra', 2), ('Pawniard', 'Timburr', 1), ('Pawniard', 'Onix', 1), ('Pawniard', 'Vullaby', 1), ('Pawniard', 'Mareanie', 1), ('Gastly', 'Magnemite', 1), ('Gastly', 'Abra', 1), ('Magnemite', 'Abra', 1), ('Abra', 'Timburr', 1), ('Abra', 'Onix', 1), ('Abra', 'Vullaby', 1), ('Abra', 'Mareanie', 1), ('Timburr', 'Onix', 1), ('Timburr', 'Vullaby', 1), ('Timburr', 'Mareanie', 1), ('Onix', 'Vullaby', 2), ('Onix', 'Mareanie', 1), ('Onix', 'Mienfoo', 1), ('Onix', 'Diglett', 1), ('Onix', 'Clamperl', 1), ('Onix', 'Foongus', 1), ('Vullaby', 'Mareanie', 1), ('Vullaby', 'Mienfoo', 1), ('Vullaby', 'Diglett', 1), ('Vullaby', 'Clamperl', 1), ('Vullaby', 'Foongus', 1), ('Mienfoo', 'Diglett', 1), ('Mienfoo', 'Clamperl', 1), ('Mienfoo', 'Foongus', 1), ('Diglett', 'Clamperl', 1), ('Diglett', 'Foongus', 1), ('Clamperl', 'Foongus', 1)])

# %% [markdown]
# # OU

# %%
t10= []
 
t10.append('Venusaur')
t10.append('Chansey')
t10.append('Zapdos')
t10.append('Rhydon')
t10.append('Mew')
t10.append('Melmetal')
 
teams.append(t10)
 
t11= []
 
t11.append('Charizard')
t11.append('Mew')
t11.append('Eevee')
t11.append('Sandslash')
t11.append('Muk')
t11.append('Melmetal')
 
teams.append(t11)
 
t12= []
 
t12.append('Gyarados')
t12.append('Dragonite')
t12.append('Mew')
t12.append('Clefable')
t12.append('Melmetal')
t12.append('Snorlax')
 
teams.append(t12)
 
t13= []
 
t13.append('Dragonite')
t13.append('Poliwrath')
t13.append('Beedrill')
t13.append('Mew')
t13.append('Rhydon')
t13.append('Melmetal')
 
teams.append(t13)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Tapu Lele', 'Charizard', 3), ('Tapu Lele', 'Pheromosa', 3), ('Charizard', 'Pheromosa', 3), ('Charizard', 'Gyarados', 6), ('Charizard', 'Magearna', 3), ('Charizard', 'Magnezone', 3), ('Charizard', 'Dragonite', 3), ('Charizard', 'Tapu Fini', 3), ('Charizard', 'Mew', 1), ('Charizard', 'Eevee', 1), ('Charizard', 'Sandslash', 1), ('Charizard', 'Muk', 1), ('Charizard', 'Melmetal', 1), ('Gyarados', 'Magearna', 3), ('Gyarados', 'Genesect', 3), ('Gyarados', 'Zeraora', 3), ('Gyarados', 'Magnezone', 3), ('Gyarados', 'Dragonite', 1), ('Gyarados', 'Mew', 1), ('Gyarados', 'Clefable', 1), ('Gyarados', 'Melmetal', 1), ('Gyarados', 'Snorlax', 1), ('Type: Null', 'Tyranitar', 3), ('Type: Null', 'Mawile', 3), ('Tyranitar', 'Mawile', 3), ('Genesect', 'Zeraora', 3), ('Zeraora', 'Altaria', 3), ('Zeraora', 'Aegislash', 3), ('Altaria', 'Aegislash', 3), ('Dragonite', 'Tapu Fini', 3), ('Dragonite', 'Mew', 2), ('Dragonite', 'Clefable', 1), ('Dragonite', 'Melmetal', 2), ('Dragonite', 'Snorlax', 1), ('Dragonite', 'Poliwrath', 1), ('Dragonite', 'Beedrill', 1), ('Dragonite', 'Rhydon', 1), ('Surskit', 'Bunnelby', 2), ('Surskit', 'Pawniard', 2), ('Surskit', 'Gastly', 2), ('Surskit', 'Magnemite', 2), ('Surskit', 'Abra', 2), ('Bunnelby', 'Pawniard', 2), ('Bunnelby', 'Gastly', 2), ('Bunnelby', 'Magnemite', 2), ('Bunnelby', 'Abra', 2), ('Pawniard', 'Gastly', 2), ('Pawniard', 'Magnemite', 2), ('Pawniard', 'Abra', 4), ('Pawniard', 'Timburr', 2), ('Pawniard', 'Onix', 2), ('Pawniard', 'Vullaby', 2), ('Pawniard', 'Mareanie', 2), ('Gastly', 'Magnemite', 2), ('Gastly', 'Abra', 2), ('Magnemite', 'Abra', 2), ('Abra', 'Timburr', 2), ('Abra', 'Onix', 2), ('Abra', 'Vullaby', 2), ('Abra', 'Mareanie', 2), ('Timburr', 'Onix', 2), ('Timburr', 'Vullaby', 2), ('Timburr', 'Mareanie', 2), ('Onix', 'Vullaby', 4), ('Onix', 'Mareanie', 2), ('Onix', 'Mienfoo', 2), ('Onix', 'Diglett', 2), ('Onix', 'Clamperl', 2), ('Onix', 'Foongus', 2), ('Vullaby', 'Mareanie', 2), ('Vullaby', 'Mienfoo', 2), ('Vullaby', 'Diglett', 2), ('Vullaby', 'Clamperl', 2), ('Vullaby', 'Foongus', 2), ('Mienfoo', 'Diglett', 2), ('Mienfoo', 'Clamperl', 2), ('Mienfoo', 'Foongus', 2), ('Diglett', 'Clamperl', 2), ('Diglett', 'Foongus', 2), ('Clamperl', 'Foongus', 2), ('Venusaur', 'Chansey', 1), ('Venusaur', 'Zapdos', 1), ('Venusaur', 'Rhydon', 1), ('Venusaur', 'Mew', 1), ('Venusaur', 'Melmetal', 1), ('Chansey', 'Zapdos', 1), ('Chansey', 'Rhydon', 1), ('Chansey', 'Mew', 1), ('Chansey', 'Melmetal', 1), ('Zapdos', 'Rhydon', 1), ('Zapdos', 'Mew', 1), ('Zapdos', 'Melmetal', 1), ('Rhydon', 'Mew', 2), ('Rhydon', 'Melmetal', 2), ('Rhydon', 'Poliwrath', 1), ('Rhydon', 'Beedrill', 1), ('Mew', 'Melmetal', 4), ('Mew', 'Eevee', 1), ('Mew', 'Sandslash', 1), ('Mew', 'Muk', 1), ('Mew', 'Clefable', 1), ('Mew', 'Snorlax', 1), ('Mew', 'Poliwrath', 1), ('Mew', 'Beedrill', 1), ('Melmetal', 'Eevee', 1), ('Melmetal', 'Sandslash', 1), ('Melmetal', 'Muk', 1), ('Melmetal', 'Clefable', 1), ('Melmetal', 'Snorlax', 1), ('Melmetal', 'Poliwrath', 1), ('Melmetal', 'Beedrill', 1), ('Eevee', 'Sandslash', 1), ('Eevee', 'Muk', 1), ('Sandslash', 'Muk', 1), ('Clefable', 'Snorlax', 1), ('Poliwrath', 'Beedrill', 1)])

# %% [markdown]
# # Monotype

# %%
t14= []
 
t14.append('Dragonite')
t14.append('Thundurus')
t14.append('Landorus')
t14.append('Tornadus')
t14.append('Aerodactyl')
t14.append('Celesteela')
 
teams.append(t14)
 
t15= []
 
t15.append('Steelix')
t15.append('Gastrodon')
t15.append('Excadrill')
t15.append('Garchomp')
t15.append('Landorus')
t15.append('Nidoking')
 
teams.append(t15)
 
t16= []
 
t16.append('Diancie')
t16.append('Tapu Koko')
t16.append('Klefki')
t16.append('Azumarill')
t16.append('Tapu Bulu')
t16.append('Mimikyu')
 
teams.append(t16)
 
t17= []
 
t17.append('Sableye')
t17.append('Mandibuzz')
t17.append('Tyranitar')
t17.append('Greninja')
t17.append('Muk')
t17.append('Hydreigon')
 
teams.append(t17)
 
t18= []
 
t18.append('Toxapex')
t18.append('Greninja')
t18.append('Keldeo')
t18.append('Swampert')
t18.append('Rotom')
t18.append('Sharpedo')
 
teams.append(t18)
 
t19= []
 
t19.append('Venusaur')
t19.append('Nidoking')
t19.append('Salazzle')
t19.append('Toxapex')
t19.append('Muk')
t19.append('Crobat')
 
teams.append(t19)
 
t20= []
 
t20.append('Celebi')
t20.append('Decidueye')
t20.append('Whimsicott')
t20.append('Venusaur')
t20.append('Breloom')
t20.append('Ferrothorn')
 
teams.append(t20)
 
t21= []
 
t21.append('Jirachi')
t21.append('Heatran')
t21.append('Ferrothorn')
t21.append('Excadrill')
t21.append('Celesteela')
t21.append('Scizor')
 
teams.append(t21)
 
t22= []
 
t22.append('Metagross')
t22.append('Gallade')
t22.append('Latios')
t22.append('Latias')
t22.append('Victini')
t22.append('Alakazam')
 
teams.append(t22)
 
t23= []
 
t23.append('Dragonite')
t23.append('Latios')
t23.append('Kommo-o')
t23.append('Garchomp')
t23.append('Altaria')
t23.append('Kyurem')
 
teams.append(t23)
 
t24= []
 
t24.append('Venusaur')
t24.append('Toxapex')
t24.append('Crobat')
t24.append('Muk')
t24.append('Nihilego')
t24.append('Nidoking')
 
teams.append(t24)
 
t25= []
 
t25.append('Zeraora')
t25.append('Raichu')
t25.append('Rotom')
t25.append('Zapdos')
t25.append('Tapu Koko')
t25.append('Golem')
 
teams.append(t25)
 
t26= []
 
t26.append('Krookodile')
t26.append('Mandibuzz')
t26.append('Tyranitar')
t26.append('Hydreigon')
t26.append('Greninja')
t26.append('Muk')
 
teams.append(t26)
 
t27= []
 
t27.append('Slowbro')
t27.append('Celebi')
t27.append('Mew')
t27.append('Latias')
t27.append('Metagross')
t27.append('Victini')
 
teams.append(t27)
 
t28= []
 
t28.append('Excadrill')
t28.append('Hippowdon')
t28.append('Garchomp')
t28.append('Landorus')
t28.append('Gastrodon')
t28.append('Nidoking')
 
teams.append(t28)
 
t29= []
 
t29.append('Raichu')
t29.append('Tapu Koko')
t29.append('Rotom')
t29.append('Golem')
t29.append('Thundurus')
t29.append('Zeraora')
 
teams.append(t29)
 
t30= []
 
t30.append('Suicune')
t30.append('Toxapex')
t30.append('Swampert')
t30.append('Greninja')
t30.append('Keldeo')
t30.append('Mantine')
 
teams.append(t30)
 
t31= []
 
t31.append('Diancie')
t31.append('Tapu Koko')
t31.append('Tapu Bulu')
t31.append('Mimikyu')
t31.append('Clefable')
t31.append('Azumarill')
 
teams.append(t31)
 
t32= []
 
t32.append('Garchomp')
t32.append('Latios')
t32.append('Kyurem')
t32.append('Dragalge')
t32.append('Kommo-o')
t32.append('Dragonite')
 
teams.append(t32)
 
t33= []
 
t33.append('Volcarona')
t33.append('Pinsir')
t33.append('Heracross')
t33.append('Scizor')
t33.append('Galvantula')
t33.append('Armaldo')
 
teams.append(t33)
 
t34= []
 
t34.append('Lopunny')
t34.append('Chansey')
t34.append('Porygon2')
t34.append('Staraptor')
t34.append('Diggersby')
t34.append('Ditto')
 
teams.append(t34)
 
t35= []
 
t35.append('Aerodactyl')
t35.append('Charizard')
t35.append('Dragonite')
t35.append('Landorus')
t35.append('Thundurus')
t35.append('Celesteela')
 
teams.append(t35)
 
t36= []
 
t36.append('Celesteela')
t36.append('Excadrill')
t36.append('Scizor')
t36.append('Skarmory')
t36.append('Heatran')
t36.append('Ferrothorn')
 
teams.append(t36)
 
t37= []
 
t37.append('Gengar')
t37.append('Mimikyu')
t37.append('Blacephalon')
t37.append('Marowak')
t37.append('Decidueye')
t37.append('Sableye')
 
teams.append(t37)
 
t38= []
 
t38.append('Scizor')
t38.append('Volcarona')
t38.append('Heracross')
t38.append('Armaldo')
t38.append('Araquanid')
t38.append('Yanmega')
 
teams.append(t38)
 
t39= []
 
t39.append('Diancie')
t39.append('Terrakion')
t39.append('Tyranitar')
t39.append('Golem')
t39.append('Shuckle')
t39.append('Cradily')
 
teams.append(t39)
 
t40= []
 
t40.append('Charizard')
t40.append('Volcarona')
t40.append('Torkoal')
t40.append('Infernape')
t40.append('Heatran')
t40.append('Blacephalon')
 
teams.append(t40)
 
t41= []
 
t41.append('Meloetta')
t41.append('Diggersby')
t41.append('Staraptor')
t41.append('Ditto')
t41.append('Chansey')
t41.append('Porygon2')
 
teams.append(t41)
 
t42= []
 
t42.append('Gallade')
t42.append('Cobalion')
t42.append('Keldeo')
t42.append('Terrakion')
t42.append('Kommo-o')
t42.append('Heracross')
 
teams.append(t42)
 
t43= []
 
t43.append('Weavile')
t43.append('Ninetales')
t43.append('Mamoswine')
t43.append('Sandslash')
t43.append('Lapras')
t43.append('Kyurem')
 
teams.append(t43)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Tapu Lele', 'Charizard', 4), ('Tapu Lele', 'Pheromosa', 4), ('Charizard', 'Pheromosa', 4), ('Charizard', 'Gyarados', 8), ('Charizard', 'Magearna', 4), ('Charizard', 'Magnezone', 4), ('Charizard', 'Dragonite', 5), ('Charizard', 'Tapu Fini', 4), ('Charizard', 'Mew', 2), ('Charizard', 'Eevee', 2), ('Charizard', 'Sandslash', 2), ('Charizard', 'Muk', 2), ('Charizard', 'Melmetal', 2), ('Charizard', 'Aerodactyl', 1), ('Charizard', 'Landorus', 1), ('Charizard', 'Thundurus', 1), ('Charizard', 'Celesteela', 1), ('Charizard', 'Volcarona', 1), ('Charizard', 'Torkoal', 1), ('Charizard', 'Infernape', 1), ('Charizard', 'Heatran', 1), ('Charizard', 'Blacephalon', 1), ('Gyarados', 'Magearna', 4), ('Gyarados', 'Genesect', 4), ('Gyarados', 'Zeraora', 4), ('Gyarados', 'Magnezone', 4), ('Gyarados', 'Dragonite', 2), ('Gyarados', 'Mew', 2), ('Gyarados', 'Clefable', 2), ('Gyarados', 'Melmetal', 2), ('Gyarados', 'Snorlax', 2), ('Type: Null', 'Tyranitar', 4), ('Type: Null', 'Mawile', 4), ('Tyranitar', 'Mawile', 4), ('Tyranitar', 'Sableye', 1), ('Tyranitar', 'Mandibuzz', 2), ('Tyranitar', 'Greninja', 2), ('Tyranitar', 'Muk', 2), ('Tyranitar', 'Hydreigon', 2), ('Tyranitar', 'Krookodile', 1), ('Tyranitar', 'Diancie', 1), ('Tyranitar', 'Terrakion', 1), ('Tyranitar', 'Golem', 1), ('Tyranitar', 'Shuckle', 1), ('Tyranitar', 'Cradily', 1), ('Genesect', 'Zeraora', 4), ('Zeraora', 'Altaria', 4), ('Zeraora', 'Aegislash', 4), ('Zeraora', 'Raichu', 2), ('Zeraora', 'Rotom', 2), ('Zeraora', 'Zapdos', 1), ('Zeraora', 'Tapu Koko', 2), ('Zeraora', 'Golem', 2), ('Zeraora', 'Thundurus', 1), ('Altaria', 'Aegislash', 4), ('Altaria', 'Dragonite', 1), ('Altaria', 'Latios', 1), ('Altaria', 'Kommo-o', 1), ('Altaria', 'Garchomp', 1), ('Altaria', 'Kyurem', 1), ('Dragonite', 'Tapu Fini', 4), ('Dragonite', 'Mew', 4), ('Dragonite', 'Clefable', 2), ('Dragonite', 'Melmetal', 4), ('Dragonite', 'Snorlax', 2), ('Dragonite', 'Poliwrath', 2), ('Dragonite', 'Beedrill', 2), ('Dragonite', 'Rhydon', 2), ('Dragonite', 'Thundurus', 2), ('Dragonite', 'Landorus', 2), ('Dragonite', 'Tornadus', 1), ('Dragonite', 'Aerodactyl', 2), ('Dragonite', 'Celesteela', 2), ('Dragonite', 'Latios', 2), ('Dragonite', 'Kommo-o', 2), ('Dragonite', 'Garchomp', 2), ('Dragonite', 'Kyurem', 2), ('Dragonite', 'Dragalge', 1), ('Surskit', 'Bunnelby', 3), ('Surskit', 'Pawniard', 3), ('Surskit', 'Gastly', 3), ('Surskit', 'Magnemite', 3), ('Surskit', 'Abra', 3), ('Bunnelby', 'Pawniard', 3), ('Bunnelby', 'Gastly', 3), ('Bunnelby', 'Magnemite', 3), ('Bunnelby', 'Abra', 3), ('Pawniard', 'Gastly', 3), ('Pawniard', 'Magnemite', 3), ('Pawniard', 'Abra', 6), ('Pawniard', 'Timburr', 3), ('Pawniard', 'Onix', 3), ('Pawniard', 'Vullaby', 3), ('Pawniard', 'Mareanie', 3), ('Gastly', 'Magnemite', 3), ('Gastly', 'Abra', 3), ('Magnemite', 'Abra', 3), ('Abra', 'Timburr', 3), ('Abra', 'Onix', 3), ('Abra', 'Vullaby', 3), ('Abra', 'Mareanie', 3), ('Timburr', 'Onix', 3), ('Timburr', 'Vullaby', 3), ('Timburr', 'Mareanie', 3), ('Onix', 'Vullaby', 6), ('Onix', 'Mareanie', 3), ('Onix', 'Mienfoo', 3), ('Onix', 'Diglett', 3), ('Onix', 'Clamperl', 3), ('Onix', 'Foongus', 3), ('Vullaby', 'Mareanie', 3), ('Vullaby', 'Mienfoo', 3), ('Vullaby', 'Diglett', 3), ('Vullaby', 'Clamperl', 3), ('Vullaby', 'Foongus', 3), ('Mienfoo', 'Diglett', 3), ('Mienfoo', 'Clamperl', 3), ('Mienfoo', 'Foongus', 3), ('Diglett', 'Clamperl', 3), ('Diglett', 'Foongus', 3), ('Clamperl', 'Foongus', 3), ('Venusaur', 'Chansey', 2), ('Venusaur', 'Zapdos', 2), ('Venusaur', 'Rhydon', 2), ('Venusaur', 'Mew', 2), ('Venusaur', 'Melmetal', 2), ('Venusaur', 'Nidoking', 2), ('Venusaur', 'Salazzle', 1), ('Venusaur', 'Toxapex', 2), ('Venusaur', 'Muk', 2), ('Venusaur', 'Crobat', 2), ('Venusaur', 'Celebi', 1), ('Venusaur', 'Decidueye', 1), ('Venusaur', 'Whimsicott', 1), ('Venusaur', 'Breloom', 1), ('Venusaur', 'Ferrothorn', 1), ('Venusaur', 'Nihilego', 1), ('Chansey', 'Zapdos', 2), ('Chansey', 'Rhydon', 2), ('Chansey', 'Mew', 2), ('Chansey', 'Melmetal', 2), ('Chansey', 'Lopunny', 1), ...

# %% [markdown]
# # NU

# %%
t44= []
 
t44.append('Vikavolt')
t44.append('Incineroar')
t44.append('Vaporeon')
t44.append('Whimsicott')
t44.append('Steelix')
t44.append('Passimian')
 
teams.append(t44)
 
t45= []
 
t45.append('Comfey')
t45.append('Xatu')
t45.append('Incineroar')
t45.append('Sceptile')
t45.append('Steelix')
t45.append('Passimian')
 
teams.append(t45)
 
t46= []
 
t46.append('Braviary')
t46.append('Comfey')
t46.append('Rhydon')
t46.append('Weezing')
t46.append('Dhelmise')
t46.append('Togedemaru')
 
teams.append(t46)
 
t47= []
 
t47.append('Steelix')
t47.append('Gallade')
t47.append('Aerodactyl')
t47.append('Slowking')
t47.append('Dhelmise')
t47.append('Incineroar')
 
teams.append(t47)
 
t48= []
 
t48.append('Seismitoad')
t48.append('Sigilyph')
t48.append('Togedemaru')
t48.append('Incineroar')
t48.append('Dhelmise')
t48.append('Comfey')
 
teams.append(t48)
 
t49= []
 
t49.append('Togedemaru')
t49.append('Pangoro')
t49.append('Slowking')
t49.append('Rhydon')
t49.append('Whimsicott')
t49.append('Garbodor')
 
teams.append(t49)
 
t50= []
 
t50.append('Vaporeon')
t50.append('Silvally')
t50.append('Whimsicott')
t50.append('Rhydon')
t50.append('Incineroar')
t50.append('Rotom')
 
teams.append(t50)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Tapu Lele', 'Charizard', 5), ('Tapu Lele', 'Pheromosa', 5), ('Charizard', 'Pheromosa', 5), ('Charizard', 'Gyarados', 10), ('Charizard', 'Magearna', 5), ('Charizard', 'Magnezone', 5), ('Charizard', 'Dragonite', 7), ('Charizard', 'Tapu Fini', 5), ('Charizard', 'Mew', 3), ('Charizard', 'Eevee', 3), ('Charizard', 'Sandslash', 3), ('Charizard', 'Muk', 3), ('Charizard', 'Melmetal', 3), ('Charizard', 'Aerodactyl', 2), ('Charizard', 'Landorus', 2), ('Charizard', 'Thundurus', 2), ('Charizard', 'Celesteela', 2), ('Charizard', 'Volcarona', 2), ('Charizard', 'Torkoal', 2), ('Charizard', 'Infernape', 2), ('Charizard', 'Heatran', 2), ('Charizard', 'Blacephalon', 2), ('Gyarados', 'Magearna', 5), ('Gyarados', 'Genesect', 5), ('Gyarados', 'Zeraora', 5), ('Gyarados', 'Magnezone', 5), ('Gyarados', 'Dragonite', 3), ('Gyarados', 'Mew', 3), ('Gyarados', 'Clefable', 3), ('Gyarados', 'Melmetal', 3), ('Gyarados', 'Snorlax', 3), ('Type: Null', 'Tyranitar', 5), ('Type: Null', 'Mawile', 5), ('Tyranitar', 'Mawile', 5), ('Tyranitar', 'Sableye', 2), ('Tyranitar', 'Mandibuzz', 4), ('Tyranitar', 'Greninja', 4), ('Tyranitar', 'Muk', 4), ('Tyranitar', 'Hydreigon', 4), ('Tyranitar', 'Krookodile', 2), ('Tyranitar', 'Diancie', 2), ('Tyranitar', 'Terrakion', 2), ('Tyranitar', 'Golem', 2), ('Tyranitar', 'Shuckle', 2), ('Tyranitar', 'Cradily', 2), ('Genesect', 'Zeraora', 5), ('Zeraora', 'Altaria', 5), ('Zeraora', 'Aegislash', 5), ('Zeraora', 'Raichu', 4), ('Zeraora', 'Rotom', 4), ('Zeraora', 'Zapdos', 2), ('Zeraora', 'Tapu Koko', 4), ('Zeraora', 'Golem', 4), ('Zeraora', 'Thundurus', 2), ('Altaria', 'Aegislash', 5), ('Altaria', 'Dragonite', 2), ('Altaria', 'Latios', 2), ('Altaria', 'Kommo-o', 2), ('Altaria', 'Garchomp', 2), ('Altaria', 'Kyurem', 2), ('Dragonite', 'Tapu Fini', 5), ('Dragonite', 'Mew', 6), ('Dragonite', 'Clefable', 3), ('Dragonite', 'Melmetal', 6), ('Dragonite', 'Snorlax', 3), ('Dragonite', 'Poliwrath', 3), ('Dragonite', 'Beedrill', 3), ('Dragonite', 'Rhydon', 3), ('Dragonite', 'Thundurus', 4), ('Dragonite', 'Landorus', 4), ('Dragonite', 'Tornadus', 2), ('Dragonite', 'Aerodactyl', 4), ('Dragonite', 'Celesteela', 4), ('Dragonite', 'Latios', 4), ('Dragonite', 'Kommo-o', 4), ('Dragonite', 'Garchomp', 4), ('Dragonite', 'Kyurem', 4), ('Dragonite', 'Dragalge', 2), ('Surskit', 'Bunnelby', 4), ('Surskit', 'Pawniard', 4), ('Surskit', 'Gastly', 4), ('Surskit', 'Magnemite', 4), ('Surskit', 'Abra', 4), ('Bunnelby', 'Pawniard', 4), ('Bunnelby', 'Gastly', 4), ('Bunnelby', 'Magnemite', 4), ('Bunnelby', 'Abra', 4), ('Pawniard', 'Gastly', 4), ('Pawniard', 'Magnemite', 4), ('Pawniard', 'Abra', 8), ('Pawniard', 'Timburr', 4), ('Pawniard', 'Onix', 4), ('Pawniard', 'Vullaby', 4), ('Pawniard', 'Mareanie', 4), ('Gastly', 'Magnemite', 4), ('Gastly', 'Abra', 4), ('Magnemite', 'Abra', 4), ('Abra', 'Timburr', 4), ('Abra', 'Onix', 4), ('Abra', 'Vullaby', 4), ('Abra', 'Mareanie', 4), ('Timburr', 'Onix', 4), ('Timburr', 'Vullaby', 4), ('Timburr', 'Mareanie', 4), ('Onix', 'Vullaby', 8), ('Onix', 'Mareanie', 4), ('Onix', 'Mienfoo', 4), ('Onix', 'Diglett', 4), ('Onix', 'Clamperl', 4), ('Onix', 'Foongus', 4), ('Vullaby', 'Mareanie', 4), ('Vullaby', 'Mienfoo', 4), ('Vullaby', 'Diglett', 4), ('Vullaby', 'Clamperl', 4), ('Vullaby', 'Foongus', 4), ('Mienfoo', 'Diglett', 4), ('Mienfoo', 'Clamperl', 4), ('Mienfoo', 'Foongus', 4), ('Diglett', 'Clamperl', 4), ('Diglett', 'Foongus', 4), ('Clamperl', 'Foongus', 4), ('Venusaur', 'Chansey', 3), ('Venusaur', 'Zapdos', 3), ('Venusaur', 'Rhydon', 3), ('Venusaur', 'Mew', 3), ('Venusaur', 'Melmetal', 3), ('Venusaur', 'Nidoking', 4), ('Venusaur', 'Salazzle', 2), ('Venusaur', 'Toxapex', 4), ('Venusaur', 'Muk', 4), ('Venusaur', 'Crobat', 4), ('Venusaur', 'Celebi', 2), ('Venusaur', 'Decidueye', 2), ('Venusaur', 'Whimsicott', 2), ('Venusaur', 'Breloom', 2), ('Venusaur', 'Ferrothorn', 2), ('Venusaur', 'Nihilego', 2), ('Chansey', 'Zapdos', 3), ('Chansey', 'Rhydon', 3), ('Chansey', 'Mew', 3), ('Chansey', 'Melmetal', 3), ('Chansey', 'Lopunny', 2) ...

# %% [markdown]
# # OU

# %%
t51= []
 
t51.append('Serperior')
t51.append('Tapu Fini')
t51.append('Scizor')
t51.append('Heatran')
t51.append('Landorus')
t51.append('Kyurem')
 
teams.append(t51)
 
t52= []
 
t52.append('Clefable')
t52.append('Ferrothorn')
t52.append('Heatran')
t52.append('Landorus')
t52.append('Latias')
t52.append('Rotom')
 
teams.append(t52)
 
t53= []
 
t53.append('Swampert')
t53.append('Tornadus')
t53.append('Greninja')
t53.append('Ferrothorn')
t53.append('Manaphy')
t53.append('Pelipper')
 
teams.append(t53)
 
t54= []
 
t54.append('Skarmory')
t54.append('Lopunny')
t54.append('Reuniclus')
t54.append('Chansey')
t54.append('Gliscor')
t54.append('Toxapex')
 
teams.append(t54)
 
t55= []
 
t55.append('Medicham')
t55.append('Tornadus')
t55.append('Landorus')
t55.append('Greninja')
t55.append('Rotom')
t55.append('Magearna')
 
teams.append(t55)
 
t56= []
 
t56.append('Gliscor')
t56.append('Lopunny')
t56.append('Magearna')
t56.append('Tangrowth')
t56.append('Tornadus')
t56.append('Toxapex')
 
teams.append(t56)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Tapu Lele', 'Charizard', 6), ('Tapu Lele', 'Pheromosa', 6), ('Charizard', 'Pheromosa', 6), ('Charizard', 'Gyarados', 12), ('Charizard', 'Magearna', 6), ('Charizard', 'Magnezone', 6), ('Charizard', 'Dragonite', 9), ('Charizard', 'Tapu Fini', 6), ('Charizard', 'Mew', 4), ('Charizard', 'Eevee', 4), ('Charizard', 'Sandslash', 4), ('Charizard', 'Muk', 4), ('Charizard', 'Melmetal', 4), ('Charizard', 'Aerodactyl', 3), ('Charizard', 'Landorus', 3), ('Charizard', 'Thundurus', 3), ('Charizard', 'Celesteela', 3), ('Charizard', 'Volcarona', 3), ('Charizard', 'Torkoal', 3), ('Charizard', 'Infernape', 3), ('Charizard', 'Heatran', 3), ('Charizard', 'Blacephalon', 3), ('Gyarados', 'Magearna', 6), ('Gyarados', 'Genesect', 6), ('Gyarados', 'Zeraora', 6), ('Gyarados', 'Magnezone', 6), ('Gyarados', 'Dragonite', 4), ('Gyarados', 'Mew', 4), ('Gyarados', 'Clefable', 4), ('Gyarados', 'Melmetal', 4), ('Gyarados', 'Snorlax', 4), ('Magearna', 'Medicham', 1), ('Magearna', 'Tornadus', 2), ('Magearna', 'Landorus', 1), ('Magearna', 'Greninja', 1), ('Magearna', 'Rotom', 1), ('Magearna', 'Gliscor', 1), ('Magearna', 'Lopunny', 1), ('Magearna', 'Tangrowth', 1), ('Magearna', 'Toxapex', 1), ('Type: Null', 'Tyranitar', 6), ('Type: Null', 'Mawile', 6), ('Tyranitar', 'Mawile', 6), ('Tyranitar', 'Sableye', 3), ('Tyranitar', 'Mandibuzz', 6), ('Tyranitar', 'Greninja', 6), ('Tyranitar', 'Muk', 6), ('Tyranitar', 'Hydreigon', 6), ('Tyranitar', 'Krookodile', 3), ('Tyranitar', 'Diancie', 3), ('Tyranitar', 'Terrakion', 3), ('Tyranitar', 'Golem', 3), ('Tyranitar', 'Shuckle', 3), ('Tyranitar', 'Cradily', 3), ('Genesect', 'Zeraora', 6), ('Zeraora', 'Altaria', 6), ('Zeraora', 'Aegislash', 6), ('Zeraora', 'Raichu', 6), ('Zeraora', 'Rotom', 6), ('Zeraora', 'Zapdos', 3), ('Zeraora', 'Tapu Koko', 6), ('Zeraora', 'Golem', 6), ('Zeraora', 'Thundurus', 3), ('Altaria', 'Aegislash', 6), ('Altaria', 'Dragonite', 3), ('Altaria', 'Latios', 3), ('Altaria', 'Kommo-o', 3), ('Altaria', 'Garchomp', 3), ('Altaria', 'Kyurem', 3), ('Dragonite', 'Tapu Fini', 6), ('Dragonite', 'Mew', 8), ('Dragonite', 'Clefable', 4), ('Dragonite', 'Melmetal', 8), ('Dragonite', 'Snorlax', 4), ('Dragonite', 'Poliwrath', 4), ('Dragonite', 'Beedrill', 4), ('Dragonite', 'Rhydon', 4), ('Dragonite', 'Thundurus', 6), ('Dragonite', 'Landorus', 6), ('Dragonite', 'Tornadus', 3), ('Dragonite', 'Aerodactyl', 6), ('Dragonite', 'Celesteela', 6), ('Dragonite', 'Latios', 6), ('Dragonite', 'Kommo-o', 6), ('Dragonite', 'Garchomp', 6), ('Dragonite', 'Kyurem', 6), ('Dragonite', 'Dragalge', 3), ('Tapu Fini', 'Serperior', 1), ('Tapu Fini', 'Scizor', 1), ('Tapu Fini', 'Heatran', 1), ('Tapu Fini', 'Landorus', 1), ('Tapu Fini', 'Kyurem', 1), ('Surskit', 'Bunnelby', 5), ('Surskit', 'Pawniard', 5), ('Surskit', 'Gastly', 5), ('Surskit', 'Magnemite', 5), ('Surskit', 'Abra', 5), ('Bunnelby', 'Pawniard', 5), ('Bunnelby', 'Gastly', 5), ('Bunnelby', 'Magnemite', 5), ('Bunnelby', 'Abra', 5), ('Pawniard', 'Gastly', 5), ('Pawniard', 'Magnemite', 5), ('Pawniard', 'Abra', 10), ('Pawniard', 'Timburr', 5), ('Pawniard', 'Onix', 5), ('Pawniard', 'Vullaby', 5), ('Pawniard', 'Mareanie', 5), ('Gastly', 'Magnemite', 5), ('Gastly', 'Abra', 5), ('Magnemite', 'Abra', 5), ('Abra', 'Timburr', 5), ('Abra', 'Onix', 5), ('Abra', 'Vullaby', 5), ('Abra', 'Mareanie', 5), ('Timburr', 'Onix', 5), ('Timburr', 'Vullaby', 5), ('Timburr', 'Mareanie', 5), ('Onix', 'Vullaby', 10), ('Onix', 'Mareanie', 5), ('Onix', 'Mienfoo', 5), ('Onix', 'Diglett', 5), ('Onix', 'Clamperl', 5), ('Onix', 'Foongus', 5), ('Vullaby', 'Mareanie', 5), ('Vullaby', 'Mienfoo', 5), ('Vullaby', 'Diglett', 5), ('Vullaby', 'Clamperl', 5), ('Vullaby', 'Foongus', 5), ('Mienfoo', 'Diglett', 5), ('Mienfoo', 'Clamperl', 5), ('Mienfoo', 'Foongus', 5), ('Diglett', 'Clamperl', 5), ('Diglett', 'Foongus', 5), ('Clamperl', 'Foongus', 5), ('Venusaur', 'Chansey', 4), ('Venusaur', 'Zapdos', 4), ('Venusaur', 'Rhydon', 4), ('Venusaur', 'Mew', 4), ('Venusaur', 'Melmetal', 4), ('Venusaur', 'Nidoking', 6), ('Venusa ...

# %% [markdown]
# # PU

# %%
t58= []
 
t58.append('Carracosta')
t58.append('Victreebel')
t58.append('Mudsdale')
t58.append('Dodrio')
t58.append('Hitmonchan')
t58.append('Rotom')
 
teams.append(t58)
 
t59= []
 
t59.append('Abomasnow')
t59.append('Sandslash')
t59.append('Mudsdale')
t59.append('Silvally')
t59.append('Oricorio')
t59.append('Persian')
 
teams.append(t59)
 
t60= []
 
t60.append('Torterra')
t60.append('Poliwrath')
t60.append('Spiritomb')
t60.append('Silvally')
t60.append('Articuno')
t60.append('Audino')
 
teams.append(t60)
 
t61= []
 
t61.append('Eelektross')
t61.append('Mudsdale')
t61.append('Musharna')
t61.append('Cryogonal')
t61.append('Simisear')
t61.append('Gurdurr')
 
teams.append(t61)
 
t62= []
 
t62.append('Leafeon')
t62.append('Ferroseed')
t62.append('Dodrio')
t62.append('Lanturn')
t62.append('Silvally')
t62.append('Musharna')
 
teams.append(t62)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Tapu Lele', 'Charizard', 7), ('Tapu Lele', 'Pheromosa', 7), ('Charizard', 'Pheromosa', 7), ('Charizard', 'Gyarados', 14), ('Charizard', 'Magearna', 7), ('Charizard', 'Magnezone', 7), ('Charizard', 'Dragonite', 11), ('Charizard', 'Tapu Fini', 7), ('Charizard', 'Mew', 5), ('Charizard', 'Eevee', 5), ('Charizard', 'Sandslash', 5), ('Charizard', 'Muk', 5), ('Charizard', 'Melmetal', 5), ('Charizard', 'Aerodactyl', 4), ('Charizard', 'Landorus', 4), ('Charizard', 'Thundurus', 4), ('Charizard', 'Celesteela', 4), ('Charizard', 'Volcarona', 4), ('Charizard', 'Torkoal', 4), ('Charizard', 'Infernape', 4), ('Charizard', 'Heatran', 4), ('Charizard', 'Blacephalon', 4), ('Gyarados', 'Magearna', 7), ('Gyarados', 'Genesect', 7), ('Gyarados', 'Zeraora', 7), ('Gyarados', 'Magnezone', 7), ('Gyarados', 'Dragonite', 5), ('Gyarados', 'Mew', 5), ('Gyarados', 'Clefable', 5), ('Gyarados', 'Melmetal', 5), ('Gyarados', 'Snorlax', 5), ('Magearna', 'Medicham', 2), ('Magearna', 'Tornadus', 4), ('Magearna', 'Landorus', 2), ('Magearna', 'Greninja', 2), ('Magearna', 'Rotom', 2), ('Magearna', 'Gliscor', 2), ('Magearna', 'Lopunny', 2), ('Magearna', 'Tangrowth', 2), ('Magearna', 'Toxapex', 2), ('Type: Null', 'Tyranitar', 7), ('Type: Null', 'Mawile', 7), ('Tyranitar', 'Mawile', 7), ('Tyranitar', 'Sableye', 4), ('Tyranitar', 'Mandibuzz', 8), ('Tyranitar', 'Greninja', 8), ('Tyranitar', 'Muk', 8), ('Tyranitar', 'Hydreigon', 8), ('Tyranitar', 'Krookodile', 4), ('Tyranitar', 'Diancie', 4), ('Tyranitar', 'Terrakion', 4), ('Tyranitar', 'Golem', 4), ('Tyranitar', 'Shuckle', 4), ('Tyranitar', 'Cradily', 4), ('Genesect', 'Zeraora', 7), ('Zeraora', 'Altaria', 7), ('Zeraora', 'Aegislash', 7), ('Zeraora', 'Raichu', 8), ('Zeraora', 'Rotom', 8), ('Zeraora', 'Zapdos', 4), ('Zeraora', 'Tapu Koko', 8), ('Zeraora', 'Golem', 8), ('Zeraora', 'Thundurus', 4), ('Altaria', 'Aegislash', 7), ('Altaria', 'Dragonite', 4), ('Altaria', 'Latios', 4), ('Altaria', 'Kommo-o', 4), ('Altaria', 'Garchomp', 4), ('Altaria', 'Kyurem', 4), ('Dragonite', 'Tapu Fini', 7), ('Dragonite', 'Mew', 10), ('Dragonite', 'Clefable', 5), ('Dragonite', 'Melmetal', 10), ('Dragonite', 'Snorlax', 5), ('Dragonite', 'Poliwrath', 5), ('Dragonite', 'Beedrill', 5), ('Dragonite', 'Rhydon', 5), ('Dragonite', 'Thundurus', 8), ('Dragonite', 'Landorus', 8), ('Dragonite', 'Tornadus', 4), ('Dragonite', 'Aerodactyl', 8), ('Dragonite', 'Celesteela', 8), ('Dragonite', 'Latios', 8), ('Dragonite', 'Kommo-o', 8), ('Dragonite', 'Garchomp', 8), ('Dragonite', 'Kyurem', 8), ('Dragonite', 'Dragalge', 4), ('Tapu Fini', 'Serperior', 2), ('Tapu Fini', 'Scizor', 2), ('Tapu Fini', 'Heatran', 2), ('Tapu Fini', 'Landorus', 2), ('Tapu Fini', 'Kyurem', 2), ('Surskit', 'Bunnelby', 6), ('Surskit', 'Pawniard', 6), ('Surskit', 'Gastly', 6), ('Surskit', 'Magnemite', 6), ('Surskit', 'Abra', 6), ('Bunnelby', 'Pawniard', 6), ('Bunnelby', 'Gastly', 6), ('Bunnelby', 'Magnemite', 6), ('Bunnelby', 'Abra', 6), ('Pawniard', 'Gastly', 6), ('Pawniard', 'Magnemite', 6), ('Pawniard', 'Abra', 12), ('Pawniard', 'Timburr', 6), ('Pawniard', 'Onix', 6), ('Pawniard', 'Vullaby', 6), ('Pawniard', 'Mareanie', 6), ('Gastly', 'Magnemite', 6), ('Gastly', 'Abra', 6), ('Magnemite', 'Abra', 6), ('Abra', 'Timburr', 6), ('Abra', 'Onix', 6), ('Abra', 'Vullaby', 6), ('Abra', 'Mareanie', 6), ('Timburr', 'Onix', 6), ('Timburr', 'Vullaby', 6), ('Timburr', 'Mareanie', 6), ('Onix', 'Vullaby', 12), ('Onix', 'Mareanie', 6), ('Onix', 'Mienfoo', 6), ('Onix', 'Diglett', 6), ('Onix', 'Clamperl', 6), ('Onix', 'Foongus', 6), ('Vullaby', 'Mareanie', 6), ('Vullaby', 'Mienfoo', 6), ('Vullaby', 'Diglett', 6), ('Vullaby', 'Clamperl', 6), ('Vullaby', 'Foongus', 6), ('Mienfoo', 'Diglett', 6), ('Mienfoo', 'Clamperl', 6), ('Mienfoo', 'Foongus', 6), ('Diglett', 'Clamperl', 6), ('Diglett', 'Foongus', 6), ('Clamperl', 'Foongus', 6), ('Venusaur', 'Chansey', 5), ('Venusaur', 'Zapdos', 5), ('Venusaur', 'Rhydon', 5), ('Venusaur', 'Mew', 5), ('Venusaur', 'Melmetal', 5), ('Venusaur', 'Nidoking', 8), ('Ven ...

# %% [markdown]
# # RU

# %%
t63= []
 
t63.append('Registeel')
t63.append('Mandibuzz')
t63.append('Vaporeon')
t63.append('Necrozma')
t63.append('Ditto')
t63.append('Nidoqueen')
 
teams.append(t63)
 
t64= []
 
t64.append('Donphan')
t64.append('Metagross')
t64.append('Virizion')
t64.append('Barbaracle')
t64.append('Noivern')
t64.append('Goodra')
 
teams.append(t64)
 
t65= []
 
t65.append('Xatu')
t65.append('Registeel')
t65.append('Virizion')
t65.append('Noivern')
t65.append('Blastoise')
t65.append('Florges')
 
teams.append(t65)
 
t66= []
 
t66.append('Raikou')
t66.append('Uxie')
t66.append('Machamp')
t66.append('Mismagius')
t66.append('Abomasnow')
t66.append('Forretress')
 
teams.append(t66)
 
t67= []
 
t67.append('Cresselia')
t67.append('Registeel')
t67.append('Tyrantrum')
t67.append('Blastoise')
t67.append('Roserade')
t67.append('Machamp')
 
teams.append(t67)
 
t68= []
 
t68.append('Zygarde')
t68.append('Bronzong')
t68.append('Mantine')
t68.append('Necrozma')
t68.append('Abomasnow')
t68.append('Florges')
 
teams.append(t68)
 
t69= []
 
t69.append('Araquanid')
t69.append('Toxicroak')
t69.append('Gardevoir')
t69.append('Honchkrow')
t69.append('Nidoqueen')
t69.append('Blastoise')
 
teams.append(t69)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Tapu Lele', 'Charizard', 8), ('Tapu Lele', 'Pheromosa', 8), ('Charizard', 'Pheromosa', 8), ('Charizard', 'Gyarados', 16), ('Charizard', 'Magearna', 8), ('Charizard', 'Magnezone', 8), ('Charizard', 'Dragonite', 13), ('Charizard', 'Tapu Fini', 8), ('Charizard', 'Mew', 6), ('Charizard', 'Eevee', 6), ('Charizard', 'Sandslash', 6), ('Charizard', 'Muk', 6), ('Charizard', 'Melmetal', 6), ('Charizard', 'Aerodactyl', 5), ('Charizard', 'Landorus', 5), ('Charizard', 'Thundurus', 5), ('Charizard', 'Celesteela', 5), ('Charizard', 'Volcarona', 5), ('Charizard', 'Torkoal', 5), ('Charizard', 'Infernape', 5), ('Charizard', 'Heatran', 5), ('Charizard', 'Blacephalon', 5), ('Gyarados', 'Magearna', 8), ('Gyarados', 'Genesect', 8), ('Gyarados', 'Zeraora', 8), ('Gyarados', 'Magnezone', 8), ('Gyarados', 'Dragonite', 6), ('Gyarados', 'Mew', 6), ('Gyarados', 'Clefable', 6), ('Gyarados', 'Melmetal', 6), ('Gyarados', 'Snorlax', 6), ('Magearna', 'Medicham', 3), ('Magearna', 'Tornadus', 6), ('Magearna', 'Landorus', 3), ('Magearna', 'Greninja', 3), ('Magearna', 'Rotom', 3), ('Magearna', 'Gliscor', 3), ('Magearna', 'Lopunny', 3), ('Magearna', 'Tangrowth', 3), ('Magearna', 'Toxapex', 3), ('Type: Null', 'Tyranitar', 8), ('Type: Null', 'Mawile', 8), ('Tyranitar', 'Mawile', 8), ('Tyranitar', 'Sableye', 5), ('Tyranitar', 'Mandibuzz', 10), ('Tyranitar', 'Greninja', 10), ('Tyranitar', 'Muk', 10), ('Tyranitar', 'Hydreigon', 10), ('Tyranitar', 'Krookodile', 5), ('Tyranitar', 'Diancie', 5), ('Tyranitar', 'Terrakion', 5), ('Tyranitar', 'Golem', 5), ('Tyranitar', 'Shuckle', 5), ('Tyranitar', 'Cradily', 5), ('Genesect', 'Zeraora', 8), ('Zeraora', 'Altaria', 8), ('Zeraora', 'Aegislash', 8), ('Zeraora', 'Raichu', 10), ('Zeraora', 'Rotom', 10), ('Zeraora', 'Zapdos', 5), ('Zeraora', 'Tapu Koko', 10), ('Zeraora', 'Golem', 10), ('Zeraora', 'Thundurus', 5), ('Altaria', 'Aegislash', 8), ('Altaria', 'Dragonite', 5), ('Altaria', 'Latios', 5), ('Altaria', 'Kommo-o', 5), ('Altaria', 'Garchomp', 5), ('Altaria', 'Kyurem', 5), ('Dragonite', 'Tapu Fini', 8), ('Dragonite', 'Mew', 12), ('Dragonite', 'Clefable', 6), ('Dragonite', 'Melmetal', 12), ('Dragonite', 'Snorlax', 6), ('Dragonite', 'Poliwrath', 6), ('Dragonite', 'Beedrill', 6), ('Dragonite', 'Rhydon', 6), ('Dragonite', 'Thundurus', 10), ('Dragonite', 'Landorus', 10), ('Dragonite', 'Tornadus', 5), ('Dragonite', 'Aerodactyl', 10), ('Dragonite', 'Celesteela', 10), ('Dragonite', 'Latios', 10), ('Dragonite', 'Kommo-o', 10), ('Dragonite', 'Garchomp', 10), ('Dragonite', 'Kyurem', 10), ('Dragonite', 'Dragalge', 5), ('Tapu Fini', 'Serperior', 3), ('Tapu Fini', 'Scizor', 3), ('Tapu Fini', 'Heatran', 3), ('Tapu Fini', 'Landorus', 3), ('Tapu Fini', 'Kyurem', 3), ('Surskit', 'Bunnelby', 7), ('Surskit', 'Pawniard', 7), ('Surskit', 'Gastly', 7), ('Surskit', 'Magnemite', 7), ('Surskit', 'Abra', 7), ('Bunnelby', 'Pawniard', 7), ('Bunnelby', 'Gastly', 7), ('Bunnelby', 'Magnemite', 7), ('Bunnelby', 'Abra', 7), ('Pawniard', 'Gastly', 7), ('Pawniard', 'Magnemite', 7), ('Pawniard', 'Abra', 14), ('Pawniard', 'Timburr', 7), ('Pawniard', 'Onix', 7), ('Pawniard', 'Vullaby', 7), ('Pawniard', 'Mareanie', 7), ('Gastly', 'Magnemite', 7), ('Gastly', 'Abra', 7), ('Magnemite', 'Abra', 7), ('Abra', 'Timburr', 7), ('Abra', 'Onix', 7), ('Abra', 'Vullaby', 7), ('Abra', 'Mareanie', 7), ('Timburr', 'Onix', 7), ('Timburr', 'Vullaby', 7), ('Timburr', 'Mareanie', 7), ('Onix', 'Vullaby', 14), ('Onix', 'Mareanie', 7), ('Onix', 'Mienfoo', 7), ('Onix', 'Diglett', 7), ('Onix', 'Clamperl', 7), ('Onix', 'Foongus', 7), ('Vullaby', 'Mareanie', 7), ('Vullaby', 'Mienfoo', 7), ('Vullaby', 'Diglett', 7), ('Vullaby', 'Clamperl', 7), ('Vullaby', 'Foongus', 7), ('Mienfoo', 'Diglett', 7), ('Mienfoo', 'Clamperl', 7), ('Mienfoo', 'Foongus', 7), ('Diglett', 'Clamperl', 7), ('Diglett', 'Foongus', 7), ('Clamperl', 'Foongus', 7), ('Venusaur', 'Chansey', 6), ('Venusaur', 'Zapdos', 6), ('Venusaur', 'Rhydon', 6), ('Venusaur', 'Mew', 6), ('Venusaur', 'Melmetal', 6), ('Venusaur', 'Nido ...

# %% [markdown]
# # Ubers

# %%
t70= []
 
t70.append('Salamence')
t70.append('Kyogre')
t70.append('Xerneas')
t70.append('Arceus')
t70.append('Groudon')
t70.append('Necrozma')
 
teams.append(t70)
 
t71= []
 
t71.append('Kyogre')
t71.append('Groudon')
t71.append('Arceus')
t71.append('Yveltal')
t71.append('Salamence')
t71.append('Necrozma')
 
teams.append(t71)
 
t72= []
 
t72.append('Mewtwo')
t72.append('Groudon')
t72.append('Arceus')
t72.append('Yveltal')
t72.append('Necrozma')
t72.append('Marshadow')
 
teams.append(t72)
 
t73= []
 
t73.append('Scizor')
t73.append('Groudon')
t73.append('Kyogre')
t73.append('Giratina')
t73.append('Arceus')
t73.append('Yveltal')
 
teams.append(t73)
 
t74= []
 
t74.append('Mewtwo')
t74.append('Magearna')
t74.append('Arceus')
t74.append('Toxapex')
t74.append('Giratina')
t74.append('Groudon')
 
teams.append(t74)
 
t75= []
 
t75.append('Gengar')
t75.append('Groudon')
t75.append('Arceus')
t75.append('Yveltal')
t75.append('Zygarde')
t75.append('Necrozma')
 
teams.append(t75)
 
t76= []
 
t76.append('Mewtwo')
t76.append('Ho-oh')
t76.append('Groudon')
t76.append('Arceus')
t76.append('Ferrothorn')
t76.append('Zygarde')
 
teams.append(t76)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Tapu Lele', 'Charizard', 9), ('Tapu Lele', 'Pheromosa', 9), ('Charizard', 'Pheromosa', 9), ('Charizard', 'Gyarados', 18), ('Charizard', 'Magearna', 9), ('Charizard', 'Magnezone', 9), ('Charizard', 'Dragonite', 15), ('Charizard', 'Tapu Fini', 9), ('Charizard', 'Mew', 7), ('Charizard', 'Eevee', 7), ('Charizard', 'Sandslash', 7), ('Charizard', 'Muk', 7), ('Charizard', 'Melmetal', 7), ('Charizard', 'Aerodactyl', 6), ('Charizard', 'Landorus', 6), ('Charizard', 'Thundurus', 6), ('Charizard', 'Celesteela', 6), ('Charizard', 'Volcarona', 6), ('Charizard', 'Torkoal', 6), ('Charizard', 'Infernape', 6), ('Charizard', 'Heatran', 6), ('Charizard', 'Blacephalon', 6), ('Gyarados', 'Magearna', 9), ('Gyarados', 'Genesect', 9), ('Gyarados', 'Zeraora', 9), ('Gyarados', 'Magnezone', 9), ('Gyarados', 'Dragonite', 7), ('Gyarados', 'Mew', 7), ('Gyarados', 'Clefable', 7), ('Gyarados', 'Melmetal', 7), ('Gyarados', 'Snorlax', 7), ('Magearna', 'Medicham', 4), ('Magearna', 'Tornadus', 8), ('Magearna', 'Landorus', 4), ('Magearna', 'Greninja', 4), ('Magearna', 'Rotom', 4), ('Magearna', 'Gliscor', 4), ('Magearna', 'Lopunny', 4), ('Magearna', 'Tangrowth', 4), ('Magearna', 'Toxapex', 5), ('Magearna', 'Mewtwo', 1), ('Magearna', 'Arceus', 1), ('Magearna', 'Giratina', 1), ('Magearna', 'Groudon', 1), ('Type: Null', 'Tyranitar', 9), ('Type: Null', 'Mawile', 9), ('Tyranitar', 'Mawile', 9), ('Tyranitar', 'Sableye', 6), ('Tyranitar', 'Mandibuzz', 12), ('Tyranitar', 'Greninja', 12), ('Tyranitar', 'Muk', 12), ('Tyranitar', 'Hydreigon', 12), ('Tyranitar', 'Krookodile', 6), ('Tyranitar', 'Diancie', 6), ('Tyranitar', 'Terrakion', 6), ('Tyranitar', 'Golem', 6), ('Tyranitar', 'Shuckle', 6), ('Tyranitar', 'Cradily', 6), ('Genesect', 'Zeraora', 9), ('Zeraora', 'Altaria', 9), ('Zeraora', 'Aegislash', 9), ('Zeraora', 'Raichu', 12), ('Zeraora', 'Rotom', 12), ('Zeraora', 'Zapdos', 6), ('Zeraora', 'Tapu Koko', 12), ('Zeraora', 'Golem', 12), ('Zeraora', 'Thundurus', 6), ('Altaria', 'Aegislash', 9), ('Altaria', 'Dragonite', 6), ('Altaria', 'Latios', 6), ('Altaria', 'Kommo-o', 6), ('Altaria', 'Garchomp', 6), ('Altaria', 'Kyurem', 6), ('Dragonite', 'Tapu Fini', 9), ('Dragonite', 'Mew', 14), ('Dragonite', 'Clefable', 7), ('Dragonite', 'Melmetal', 14), ('Dragonite', 'Snorlax', 7), ('Dragonite', 'Poliwrath', 7), ('Dragonite', 'Beedrill', 7), ('Dragonite', 'Rhydon', 7), ('Dragonite', 'Thundurus', 12), ('Dragonite', 'Landorus', 12), ('Dragonite', 'Tornadus', 6), ('Dragonite', 'Aerodactyl', 12), ('Dragonite', 'Celesteela', 12), ('Dragonite', 'Latios', 12), ('Dragonite', 'Kommo-o', 12), ('Dragonite', 'Garchomp', 12), ('Dragonite', 'Kyurem', 12), ('Dragonite', 'Dragalge', 6), ('Tapu Fini', 'Serperior', 4), ('Tapu Fini', 'Scizor', 4), ('Tapu Fini', 'Heatran', 4), ('Tapu Fini', 'Landorus', 4), ('Tapu Fini', 'Kyurem', 4), ('Surskit', 'Bunnelby', 8), ('Surskit', 'Pawniard', 8), ('Surskit', 'Gastly', 8), ('Surskit', 'Magnemite', 8), ('Surskit', 'Abra', 8), ('Bunnelby', 'Pawniard', 8), ('Bunnelby', 'Gastly', 8), ('Bunnelby', 'Magnemite', 8), ('Bunnelby', 'Abra', 8), ('Pawniard', 'Gastly', 8), ('Pawniard', 'Magnemite', 8), ('Pawniard', 'Abra', 16), ('Pawniard', 'Timburr', 8), ('Pawniard', 'Onix', 8), ('Pawniard', 'Vullaby', 8), ('Pawniard', 'Mareanie', 8), ('Gastly', 'Magnemite', 8), ('Gastly', 'Abra', 8), ('Magnemite', 'Abra', 8), ('Abra', 'Timburr', 8), ('Abra', 'Onix', 8), ('Abra', 'Vullaby', 8), ('Abra', 'Mareanie', 8), ('Timburr', 'Onix', 8), ('Timburr', 'Vullaby', 8), ('Timburr', 'Mareanie', 8), ('Onix', 'Vullaby', 16), ('Onix', 'Mareanie', 8), ('Onix', 'Mienfoo', 8), ('Onix', 'Diglett', 8), ('Onix', 'Clamperl', 8), ('Onix', 'Foongus', 8), ('Vullaby', 'Mareanie', 8), ('Vullaby', 'Mienfoo', 8), ('Vullaby', 'Diglett', 8), ('Vullaby', 'Clamperl', 8), ('Vullaby', 'Foongus', 8), ('Mienfoo', 'Diglett', 8), ('Mienfoo', 'Clamperl', 8), ('Mienfoo', 'Foongus', 8), ('Diglett', 'Clamperl', 8), ('Diglett', 'Foongus', 8), ('Clamperl', 'Foongus', 8), ('Venusaur', 'Chansey', 7), ('Venusaur', ' ...

# %% [markdown]
# # UU

# %%
t77= []
 
t77.append('Infernape')
t77.append('Klefki')
t77.append('Reuniclus')
t77.append('Hydreigon')
t77.append('Aerodactyl')
t77.append('Tentacruel')
 
teams.append(t77)
 
t78= []
 
t78.append('Sharpedo')
t78.append('Latias')
t78.append('Froslass')
t78.append('Cobalion')
t78.append('Mimikyu')
t78.append('Mamoswine')
 
teams.append(t78)
 
t79= []
 
t79.append('Xatu')
t79.append('Krookodile')
t79.append('Latias')
t79.append('Linoone')
t79.append('Scizor')
t79.append('Feraligatr')
 
teams.append(t79)
 
t80= []
 
t80.append('Tentacruel')
t80.append('Aerodactyl')
t80.append('Celebi')
t80.append('Hippowdon')
t80.append('Cobalion')
t80.append('Doublade')
 
teams.append(t80)
 
t81= []
 
t81.append('Alomomola')
t81.append('Quagsire')
t81.append('Nihilego')
t81.append('Blissey')
t81.append('Gligar')
t81.append('Altaria')
 
teams.append(t81)
 
t82= []
 
t82.append('Altaria')
t82.append('Magneton')
t82.append('Alomomola')
t82.append('Blissey')
t82.append('Gligar')
t82.append('Scizor')
 
teams.append(t82)
 
t83= []
 
t83.append('Rotom')
t83.append('Altaria')
t83.append('Tentacruel')
t83.append('Krookodile')
t83.append('Necrozma')
t83.append('Scizor')
 
teams.append(t83)

# %%
for team in teams:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        

edgeList = []
for team in teams:
    edgeList.append([x for x in it.combinations(team, 2)])
    
for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Tapu Lele', 'Charizard', 10), ('Tapu Lele', 'Pheromosa', 10), ('Charizard', 'Pheromosa', 10), ('Charizard', 'Gyarados', 20), ('Charizard', 'Magearna', 10), ('Charizard', 'Magnezone', 10), ('Charizard', 'Dragonite', 17), ('Charizard', 'Tapu Fini', 10), ('Charizard', 'Mew', 8), ('Charizard', 'Eevee', 8), ('Charizard', 'Sandslash', 8), ('Charizard', 'Muk', 8), ('Charizard', 'Melmetal', 8), ('Charizard', 'Aerodactyl', 7), ('Charizard', 'Landorus', 7), ('Charizard', 'Thundurus', 7), ('Charizard', 'Celesteela', 7), ('Charizard', 'Volcarona', 7), ('Charizard', 'Torkoal', 7), ('Charizard', 'Infernape', 7), ('Charizard', 'Heatran', 7), ('Charizard', 'Blacephalon', 7), ('Gyarados', 'Magearna', 10), ('Gyarados', 'Genesect', 10), ('Gyarados', 'Zeraora', 10), ('Gyarados', 'Magnezone', 10), ('Gyarados', 'Dragonite', 8), ('Gyarados', 'Mew', 8), ('Gyarados', 'Clefable', 8), ('Gyarados', 'Melmetal', 8), ('Gyarados', 'Snorlax', 8), ('Magearna', 'Medicham', 5), ('Magearna', 'Tornadus', 10), ('Magearna', 'Landorus', 5), ('Magearna', 'Greninja', 5), ('Magearna', 'Rotom', 5), ('Magearna', 'Gliscor', 5), ('Magearna', 'Lopunny', 5), ('Magearna', 'Tangrowth', 5), ('Magearna', 'Toxapex', 7), ('Magearna', 'Mewtwo', 2), ('Magearna', 'Arceus', 2), ('Magearna', 'Giratina', 2), ('Magearna', 'Groudon', 2), ('Type: Null', 'Tyranitar', 10), ('Type: Null', 'Mawile', 10), ('Tyranitar', 'Mawile', 10), ('Tyranitar', 'Sableye', 7), ('Tyranitar', 'Mandibuzz', 14), ('Tyranitar', 'Greninja', 14), ('Tyranitar', 'Muk', 14), ('Tyranitar', 'Hydreigon', 14), ('Tyranitar', 'Krookodile', 7), ('Tyranitar', 'Diancie', 7), ('Tyranitar', 'Terrakion', 7), ('Tyranitar', 'Golem', 7), ('Tyranitar', 'Shuckle', 7), ('Tyranitar', 'Cradily', 7), ('Genesect', 'Zeraora', 10), ('Zeraora', 'Altaria', 10), ('Zeraora', 'Aegislash', 10), ('Zeraora', 'Raichu', 14), ('Zeraora', 'Rotom', 14), ('Zeraora', 'Zapdos', 7), ('Zeraora', 'Tapu Koko', 14), ('Zeraora', 'Golem', 14), ('Zeraora', 'Thundurus', 7), ('Altaria', 'Aegislash', 10), ('Altaria', 'Dragonite', 7), ('Altaria', 'Latios', 7), ('Altaria', 'Kommo-o', 7), ('Altaria', 'Garchomp', 7), ('Altaria', 'Kyurem', 7), ('Altaria', 'Alomomola', 2), ('Altaria', 'Quagsire', 1), ('Altaria', 'Nihilego', 1), ('Altaria', 'Blissey', 2), ('Altaria', 'Gligar', 2), ('Altaria', 'Magneton', 1), ('Altaria', 'Scizor', 2), ('Altaria', 'Rotom', 1), ('Altaria', 'Tentacruel', 1), ('Altaria', 'Krookodile', 1), ('Altaria', 'Necrozma', 1), ('Dragonite', 'Tapu Fini', 10), ('Dragonite', 'Mew', 16), ('Dragonite', 'Clefable', 8), ('Dragonite', 'Melmetal', 16), ('Dragonite', 'Snorlax', 8), ('Dragonite', 'Poliwrath', 8), ('Dragonite', 'Beedrill', 8), ('Dragonite', 'Rhydon', 8), ('Dragonite', 'Thundurus', 14), ('Dragonite', 'Landorus', 14), ('Dragonite', 'Tornadus', 7), ('Dragonite', 'Aerodactyl', 14), ('Dragonite', 'Celesteela', 14), ('Dragonite', 'Latios', 14), ('Dragonite', 'Kommo-o', 14), ('Dragonite', 'Garchomp', 14), ('Dragonite', 'Kyurem', 14), ('Dragonite', 'Dragalge', 7), ('Tapu Fini', 'Serperior', 5), ('Tapu Fini', 'Scizor', 5), ('Tapu Fini', 'Heatran', 5), ('Tapu Fini', 'Landorus', 5), ('Tapu Fini', 'Kyurem', 5), ('Surskit', 'Bunnelby', 9), ('Surskit', 'Pawniard', 9), ('Surskit', 'Gastly', 9), ('Surskit', 'Magnemite', 9), ('Surskit', 'Abra', 9), ('Bunnelby', 'Pawniard', 9), ('Bunnelby', 'Gastly', 9), ('Bunnelby', 'Magnemite', 9), ('Bunnelby', 'Abra', 9), ('Pawniard', 'Gastly', 9), ('Pawniard', 'Magnemite', 9), ('Pawniard', 'Abra', 18), ('Pawniard', 'Timburr', 9), ('Pawniard', 'Onix', 9), ('Pawniard', 'Vullaby', 9), ('Pawniard', 'Mareanie', 9), ('Gastly', 'Magnemite', 9), ('Gastly', 'Abra', 9), ('Magnemite', 'Abra', 9), ('Abra', 'Timburr', 9), ('Abra', 'Onix', 9), ('Abra', 'Vullaby', 9), ('Abra', 'Mareanie', 9), ('Timburr', 'Onix', 9), ('Timburr', 'Vullaby', 9), ('Timburr', 'Mareanie', 9), ('Onix', 'Vullaby', 18), ('Onix', 'Mareanie', 9), ('Onix', 'Mienfoo', 9), ('Onix', 'Diglett', 9), ('Onix', 'Clamperl', 9), ('Onix', 'Foongus', 9), ('Vullaby', 'Mareani ...

# %%
for pok in G.nodes :
    G.nodes[pok]['teams'] = apariciones[pok]

# %%
nx.write_gexf(G, "Gen7Graph.gexf", version="1.2draft")
