# %% [markdown]
# # Proyecto final - Obtención de datos
# #### Pablo Álvarez García, Antonio Fernández Martín y Álvaro Corrochano López

# %% [markdown]
# # Web Scrapping

# %%
# Importo Beautiful Soup
from bs4 import BeautifulSoup
# Importo requests para pillar el código html de donde quiera
import requests

# %%
web = requests.get('https://www.metagamevgc.com/team-compendium/2019/12/16/vgc-2020-sword-and-shield-team-compendium')
soup = BeautifulSoup(web.content, 'html.parser')

# %%
# Cogemos la Pokédex
webDex = requests.get('https://pokemondb.net/pokedex/national')
dexSoup  = BeautifulSoup(webDex.content, 'html.parser')

# %%
pokedex = {}
types = [['itype', 'grass'], ['itype', 'poison'], ['itype', 'fire'], ['itype', 'flying'], ['itype', 'water'], 
         ['itype', 'bug'], ['itype', 'normal'], ['itype', 'electric'], ['itype', 'ground'], ['itype', 'fairy'], 
         ['itype', 'fighting'], ['itype', 'psychic'], ['itype', 'rock'], ['itype', 'steel'], 
         ['itype', 'ice'], ['itype', 'ghost'], ['itype', 'dark'], ['itype', 'dragon']]

for name in dexSoup.find_all('a'):
    if name.get('class') == ['ent-name']:
        pok = name.get_text()
        pokedex[pok] = {'type1' : 'None', 'type2' : 'None'}
    if name.get('class') in types:
        if pokedex[pok]['type1'] == 'None':
            pokedex[pok]['type1'] = name.get_text()
        else:
            pokedex[pok]['type2'] = name.get_text()

# %%
types = [['type-grass'], ['type-water'], ['type-ghost'], ['type-rock'], ['type-fire'], ['type-ground'], ['type-normal'], 
        ['type-flying'], ['type-fighting'], ['type-bug'], ['type-dragon'], ['type-dark'], ['type-fairy'], ['type-electric'],
         ['type-ice'], ['type-psychic'], ['type-steel'], ['type-poison']]


pokepasteList = []
teamList = []

for paste in soup.find_all('a'):
    if paste.get_text().lower() == 'pokepaste' :
        pokepasteList.append(paste.get('href'))

        team = []

        pag = requests.get(paste.get('href'))
        pokesoup = BeautifulSoup(pag.content, 'html.parser')

        for pok in pokesoup.find_all('pre'):
            pokplit = pok.get_text().split(' ')
            pokplit = pokplit[0].split('-')

            if pokplit[0] in pokedex :
                team.append(pokplit[0])

        teamList.append(team)

# %%
print(len(teamList))
# Out:
# 64

# %%
for team in teamList:
    print(len(team))
# Out:
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 0
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6

# %%
print(len(pokepasteList))
for link in pokepasteList:
    print(link)
# Out:
# 64
# https://pokepast.es/a8394695fa2dd781
# https://pokepast.es/22f95fff7e1256b1
# https://pokepast.es/7086cc0c2c13c136
# https://pokepast.es/c3a98a31b461241f
# https://pokepast.es/a3ef93cdf0f97bdc
# https://pokepast.es/7b57982bc1c880ba
# https://pokepast.es/464b95e5d28d660e
# https://pokepast.es/de987aa62e2c7697
# https://pokepast.es/af2e8abc639ebec9
# https://pokepast.es/bd829ff6e51d280d
# https://pokepast.es/9cb3e92b5ccad33c
# https://pokepast.es/164facfc3c6c09d6
# https://pokepast.es/aab39445891fa427
# https://pokepast.es/61148c81c1a261f1
# https://pokepast.es/799d70c61dd19b8a
# https://pokepast.es/2b17b4b53999a333
# https://pokepast.es/1c915d5702a31138
# https://pokepast.es/e712c43f45faae1e
# https://pokepast.es/ed1461a98d00bdea
# https://pokepast.es/03541366ba299453
# https://pokepast.es/de235819f4d7582d
# https://pokepast.es/482b387b16d4b5ac
# https://pokepast.es/409884f19d420632
# https://pokepast.es/86d980254a647d6e
# https://pokepast.es/364231897a3d453a
# https://pokepast.es/106d83859807628f
# https://pokepast.es/beff1a6aae2c66cc
# https://pokepast.es/83680db67a08530f
# https://pokepast.es/a1d9193082a54b17
# https://pokepast.es/feb52f23c051a39f
# https://pokepast.es/d2bdba59a6199f5c
# https://pokepast.es/fb403a09979b3d38
# https://pokepast.es/106148d954613083
# https://pokepast.es/06028755e6c66a98
# https://pokepast.es/5c7b7a83406fcdb3
# https://pokepast.es/ea4dc4ed2e99744d
# https://pokepast.es/ecaa9274e88d1d47
# https://pokepast.es/48b420847531e384
# https://pokepast.es/22dd2647ab6e4b1b
# https://pokepast.es/1aa51339400cce36
# https://pokepast.es/9ab209ba0ed57799
# https://pokepast.es/7f2de385a5111f98
# https://pokepast.es/a4bda7213c819fa1
# https://t.co/BpbgRbJWls?amp=1
# https://pokepast.es/2c824217bbbe1f95
# https://t.co/7pEx6Msc6f?amp=1
# https://pokepast.es/e6da4eb4054888a5
# https://pokepast.es/9845a5175b7b8055
# https://pokepast.es/6a44c7948d8ac33f
# https://pokepast.es/f32705ee5f0810a7
# https://pokepast.es/d808daf68a69763e
# https://pokepast.es/e6d00f9008ffc676
# https://pokepast.es/22a2a4e2fdc1725a
# https://pokepast.es/678321d448095201
# https://pokepast.es/84bd291ccfc16d95
# https://pokepast.es/42914d882c50ad79
# https://pokepast.es/6c1c460f73341715
# https://pokepast.es/8d14de50747ecce7
# https://pokepast.es/d3acccf48c8a6d67
# https://pokepast.es/dd48f85c7d42d41d
# https://pokepast.es/9ab97a209faa3fb0
# https://pokepast.es/425e172c43d20f41
# https://pokepast.es/cc441b3d7d0640d4
# https://pokepast.es/067417eb02130c86

# %% [markdown]
# # Construcción de la red

# %%
import networkx as nx
import itertools as it

# %%
G = nx.Graph()

# %%
apariciones = {}
for team in teamList:
    for pok in team:
        if(pok in apariciones):
            apariciones[pok] += 1
        else:
            apariciones[pok] = 1
        G.add_node(pok, type1 = pokedex[pok]['type1'], type2 = pokedex[pok]['type2'])
        
        
edgeList = []
for team in teamList:
    edgeList.append([x for x in it.combinations(team, 2)])

for perm in edgeList :
    for pokPair in perm :
        if G.has_edge(pokPair[0], pokPair[1]):
            G[pokPair[0]][pokPair[1]]['weight'] += 1
        else:
            G.add_edge(pokPair[0], pokPair[1], weight = 1)
G.edges.data('weight')
# Out:
# EdgeDataView([('Tyranitar', 'Excadrill', 2), ('Tyranitar', 'Braviary', 2), ('Tyranitar', 'Hydreigon', 1), ('Tyranitar', 'Mimikyu', 1), ('Tyranitar', 'Rotom', 3), ('Tyranitar', 'Arcanine', 1), ('Tyranitar', 'Whimsicott', 1), ('Tyranitar', 'Dragapult', 2), ('Tyranitar', 'Gastrodon', 2), ('Tyranitar', 'Corviknight', 2), ('Tyranitar', 'Indeedee', 3), ('Tyranitar', 'Hatterene', 1), ('Tyranitar', 'Incineroar', 3), ('Tyranitar', 'Urshifu', 3), ('Tyranitar', 'Alakazam', 1), ('Tyranitar', 'Slowbro', 2), ('Tyranitar', 'Torkoal', 1), ('Tyranitar', 'Luxray', 1), ('Tyranitar', 'Talonflame', 1), ('Tyranitar', 'Amoonguss', 2), ('Tyranitar', 'Sylveon', 1), ('Tyranitar', 'Togekiss', 3), ('Tyranitar', 'Volcarona', 1), ('Tyranitar', 'Hitmontop', 1), ('Tyranitar', 'Rillaboom', 5), ('Tyranitar', 'Cinderace', 1), ('Tyranitar', 'Porygon2', 2), ('Tyranitar', 'Lapras', 1), ('Excadrill', 'Braviary', 2), ('Excadrill', 'Hydreigon', 2), ('Excadrill', 'Mimikyu', 1), ('Excadrill', 'Rotom', 2), ('Excadrill', 'Grimmsnarl', 1), ('Excadrill', 'Togekiss', 1), ('Excadrill', 'Gyarados', 1), ('Excadrill', 'Indeedee', 1), ('Excadrill', 'Hatterene', 1), ('Excadrill', 'Incineroar', 1), ('Excadrill', 'Cinderace', 1), ('Excadrill', 'Whimsicott', 1), ('Excadrill', 'Primarina', 1), ('Excadrill', 'Conkeldurr', 1), ('Excadrill', 'Dragapult', 1), ('Braviary', 'Hydreigon', 1), ('Braviary', 'Mimikyu', 2), ('Braviary', 'Rotom', 1), ('Braviary', 'Arcanine', 1), ('Braviary', 'Dracovish', 1), ('Braviary', 'Darmanitan', 1), ('Braviary', 'Milotic', 1), ('Braviary', 'Indeedee', 1), ('Braviary', 'Hatterene', 1), ('Braviary', 'Incineroar', 1), ('Hydreigon', 'Mimikyu', 1), ('Hydreigon', 'Rotom', 3), ('Hydreigon', 'Grimmsnarl', 1), ('Hydreigon', 'Togekiss', 1), ('Hydreigon', 'Gyarados', 1), ('Hydreigon', 'Sylveon', 1), ('Hydreigon', 'Gastrodon', 1), ('Hydreigon', 'Corviknight', 1), ('Hydreigon', 'Amoonguss', 1), ('Mimikyu', 'Rotom', 1), ('Mimikyu', 'Arcanine', 1), ('Mimikyu', 'Dracovish', 1), ('Mimikyu', 'Darmanitan', 1), ('Mimikyu', 'Milotic', 1), ('Mimikyu', 'Politoed', 1), ('Mimikyu', 'Rillaboom', 1), ('Mimikyu', 'Scizor', 1), ('Mimikyu', 'Toxtricity', 1), ('Mimikyu', 'Kingdra', 1), ('Rotom', 'Grimmsnarl', 1), ('Rotom', 'Togekiss', 3), ('Rotom', 'Gyarados', 1), ('Rotom', 'Volcarona', 1), ('Rotom', 'Hitmontop', 1), ('Rotom', 'Rillaboom', 3), ('Rotom', 'Dragapult', 1), ('Rotom', 'Dusclops', 1), ('Rotom', 'Incineroar', 1), ('Rotom', 'Indeedee', 1), ('Rotom', 'Slowbro', 1), ('Rotom', 'Gastrodon', 2), ('Rotom', 'Sylveon', 1), ('Rotom', 'Corviknight', 1), ('Rotom', 'Amoonguss', 1), ('Arcanine', 'Dracovish', 1), ('Arcanine', 'Darmanitan', 1), ('Arcanine', 'Milotic', 1), ('Arcanine', 'Whimsicott', 4), ('Arcanine', 'Dragapult', 1), ('Arcanine', 'Gastrodon', 2), ('Arcanine', 'Corviknight', 2), ('Arcanine', 'Primarina', 4), ('Arcanine', 'Ferrothorn', 2), ('Arcanine', 'Incineroar', 1), ('Arcanine', 'Dusclops', 3), ('Arcanine', 'Charizard', 1), ('Arcanine', 'Duraludon', 2), ('Arcanine', 'Rillaboom', 1), ('Arcanine', 'Clefairy', 1), ('Arcanine', 'Sylveon', 3), ('Arcanine', 'Diggersby', 1), ('Arcanine', 'Lapras', 3), ('Arcanine', 'Terrakion', 1), ('Arcanine', 'Amoonguss', 2), ('Arcanine', 'Goodra', 1), ('Arcanine', 'Comfey', 1), ('Arcanine', 'Urshifu', 2), ('Arcanine', 'Alcremie', 1), ('Arcanine', 'Conkeldurr', 1), ('Arcanine', 'Scrafty', 1), ('Arcanine', 'Durant', 1), ('Arcanine', 'Gothitelle', 1), ('Arcanine', 'Gigalith', 1), ('Arcanine', 'Gengar', 2), ('Arcanine', 'Dracozolt', 1), ('Arcanine', 'Talonflame', 1), ('Arcanine', 'Tsareena', 1), ('Dracovish', 'Darmanitan', 1), ('Dracovish', 'Milotic', 1), ('Dracovish', 'Indeedee', 1), ('Dracovish', 'Whimsicott', 1), ('Dracovish', 'Urshifu', 2), ('Dracovish', 'Cinderace', 2), ('Dracovish', 'Togekiss', 2), ('Dracovish', 'Rillaboom', 1), ('Dracovish', 'Bisharp', 1), ('Dracovish', 'Dusclops', 1), ('Dracovish', 'Porygon', 1), ('Dracovish', 'Talonflame', 1), ('Dracovish', 'Corviknight', 1), ('Dracovish', 'Clefairy', 1), ('Darmanitan', 'Milotic', 1), ('Miloti ...

# %%
#for team in teamList:
#    for pok in team:
#        G.add_node(pok)

# %%
#edgeList = []
#for team in teamList:
#    edgeList.append([x for x in it.permutations(team, 2)])

# %%
#for perm in edgeList :
#    for pokPair in perm :
#        G.add_edge(pokPair[0], pokPair[1])

# %%
nx.draw(G)

# %%
for pok in G.nodes :
    G.nodes[pok]['teams'] = apariciones[pok]

# %%
nx.write_gexf(G, "Gen8.gexf", version="1.2draft")

# %%
#apar = {}
#for team in teamList:
#    for pok in team:
#        if pok in apar :
#            apar[pok] = apar[pok] + 1
#        else :
#            apar[pok] = 1

# %%
#print(apar)
# Out:
# {'Tyranitar': 10, 'Excadrill': 4, 'Braviary': 3, 'Hydreigon': 3, 'Mimikyu': 3, 'Rotom': 6, 'Arcanine': 11, 'Dracovish': 4, 'Darmanitan': 1, 'Milotic': 2, 'Grimmsnarl': 2, 'Togekiss': 15, 'Gyarados': 2, 'Whimsicott': 11, 'Dragapult': 11, 'Gastrodon': 6, 'Corviknight': 9, 'Politoed': 13, 'Kingdra': 10, 'Duraludon': 7, 'Rillaboom': 16, 'Scizor': 3, 'Toxtricity': 1, 'Amoonguss': 19, 'Talonflame': 7, 'Porygon2': 12, 'Rhyperior': 2, 'Urshifu': 13, 'Snorlax': 2, 'Magnezone': 2, 'Hitmontop': 2, 'Ludicolo': 1, 'Escavalier': 1, 'Volcarona': 4, 'Dusclops': 13, 'Conkeldurr': 3, 'Toxicroak': 1, 'Mandibuzz': 1, 'Clefairy': 4, 'Hatterene': 7, 'Indeedee': 12, 'Marowak': 7, 'Gigalith': 2, 'Alakazam': 3, 'Azumarill': 5, 'Dhelmise': 2, 'Slowbro': 6, 'Venusaur': 3, 'Torkoal': 4, 'Incineroar': 12, 'Terrakion': 3, 'Chandelure': 1, 'Cobalion': 2, 'Primarina': 8, 'Ferrothorn': 4, 'Charizard': 3, 'Riolu': 3, 'Cinderace': 8, 'Luxray': 2, 'Kangaskhan': 1, 'Mudsdale': 1, 'Bisharp': 2, 'Mienshao': 1, 'Sylveon': 6, 'Lapras': 5, 'Dragalge': 1, 'Weezing': 1, 'Krookodile': 1, 'Raichu': 2, 'Diggersby': 1, 'Poliwrath': 1, 'Gothitelle': 2, 'Goodra': 1, 'Comfey': 1, 'Alcremie': 1, 'Scrafty': 1, 'Porygon': 2, 'Weavile': 1, 'Coalossal': 2, 'Virizion': 1, 'Sneasel': 1, 'Durant': 1, 'Gengar': 2, 'Dracozolt': 1, 'Tsareena': 1}
